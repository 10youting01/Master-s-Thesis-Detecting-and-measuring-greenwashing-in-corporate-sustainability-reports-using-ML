# %%
import json
import re
import string
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from collections import Counter

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
# def density_threshold(data):
    # thresholds = []
    # threshold = 0.0
    # for item in data:
    #     if item.get("text_density") is not None:
    #         thresholds.append(item.get("text_density"))
    # thresholds.sort()
    # if len(thresholds) > 0:
    #     # get 75th percentile
    #     threshold = thresholds[int(len(thresholds) * 0.75)]
    # return threshold

def density_threshold(data):
    densities = [item.get("text_density", 0) for item in data if item.get("text_density") is not None]
    print(len(densities))
    return np.percentile(densities, 75) if densities else 0.0

# %%
def remove_punctuation(text):
    punctuation_pattern = f"[{re.escape(string.punctuation)}]"  # 自動轉義所有標點
    return re.sub(punctuation_pattern, " ", text)  # 替換為空格

# %%
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    words = text.split()
    return ' '.join(word for word in words if word.lower() not in stop_words)

# %%
def apply_stemming(text):
    return ' '.join(stemmer.stem(word) for word in text.split())

# %%
def apply_lemmatization(text):
    return ' '.join(lemmatizer.lemmatize(word) for word in text.split())

# %%
lemmatizer = WordNetLemmatizer()

def remove_frequent_words(valid_text):
    cnt = Counter()
    for word in valid_text.split():
        cnt[lemmatizer.lemmatize(word)] += 1  # 進行詞形還原
    return cnt.most_common(10)

# %%
def preprocess_text(json_path):
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    threshold = density_threshold(data)
    # print(threshold)

    # Filter out invalid text
    valid_text = []
    for item in data:
        text = item.get("all_text", "").strip().lower()
        # print(text)

        # filter out empty text
        if not text or item.get("text_num") == 0:
            continue
        # print(text)

        # filter out text with low text density
        # if item.get("text_density") < threshold:
        #     continue
        # print(text)

        # remove non-alphanumeric characters
        text = remove_punctuation(text)
        # print(text)

        # remove stopwords
        text = remove_stopwords(text)
        # print(text)

        # apply stemming
        text = apply_stemming(text)

        # apply lemmatization
        text = apply_lemmatization(text)

        valid_text.append(text)

    # remove frequent words
    if valid_text:
        most_common_words = remove_frequent_words(' '.join(valid_text))
        freqword = set([w for (w, wc) in most_common_words])
        valid_text = [' '.join([word for word in text.split() if word not in freqword]) for text in valid_text]

    return valid_text if valid_text else ["No valid text found."]

# %%
# 測試程式
json_path = "/home/francia/research_hub/csr_project/CSR_report_processed_v4/NASDAQ/NASDAQ_AAL_2007/dense_regions.json"
processed_regions = preprocess_text(json_path)
# Out:
# 719

# %%
processed_regions
# Out:
# ['r commit preserv wonder world 2007 respons prepar corpor',
#  'pr sli bieta ohi fianc riist fel fot ‘er peed de ee pace seat ae pe oh sess ft tte',
#  'dear friend',
#  'continu evalu perform come run safe depend effici oper likewis mind respons respons err opportun u evalu live respons share find mani stakehold',
#  'last year’ inaugur err focus primarili company’ carbon footprint year’ examin broader footprint ensur comprehens transpar err global initi gri level c requir sustain framework read gri requir appendix',
#  'alway — inde entir industri — made import stride reduc impact activ environ much progress trace increas effici today u aviat industri consum 3 percent less 2000 carri 20 percent passeng cargo last year’ commit build progress date share aggress plan improv effici 20 percent 2020 recent month — along belong air transport associ — laid even ambiti goal increas effici 30 percent 2025 base year measur 2005 two year data collect iam plea announc track meet goal',
#  '‘the less burn less carbon emit atmospher eye toward conserv reduc process updat fleet hope take moment read section detail transform',
#  '‘there much corpor reduc footprint key success engag custom employe supplier sharehold effort stake cleaner environ role play demonstr protect environ share simultan preserv mani benefit air travel',
#  'thank interest compani respons',
#  'sincer',
#  'gerard arpey chairman presid ceo corpor',
#  'tabl content',
#  '',
#  'commit respons',
#  'fleet renew',
#  'energi conserv',
#  '',
#  'resourc conserv',
#  'nois reduct',
#  'look ahead',
#  'close comment',
#  'appendix gri index',
#  'appendix b govern',
#  'appendix c organ profil',
#  'appendix greenhous ga inventori methodolog',
#  'appendix e wast inventori',
#  'appendix f 2007 fleet inventori',
#  'corpor respons',
#  '',
#  'scope boundari initi respons err publish year ago disclos 2006 greenhous ga ghg focus key initi way within compani 2007 err expand scope consid broader footprint impact commun environ err calendar year 2006 ghg scope direct adjust 30 3 million 30 6 million metric ton scope 2 indirect adjust 0 2 million 0 4 million metric ton origin due addit data collect regard purchas electr usag ground support equip avail new factor data methan nitrou',
#  'complet meet global initi gri level c sustain requir amr‘ two subsidiari eagl gri level c sustain requir includ disclosur specif govern organiz inform well disclosur least 10 perform metric cover relev econom societ area oper former subsidiari beacon advisor consid prepar err believ materi impact amr’ footprint oxid combust 2009 continu expand combin public corpor citizenship 2008 data result corpor sustain first tripl bottom line includ societ econom perform compani stakehold engag cere particip long sought engag intern extern stakehold employe supplier custom regul airport commun sharehold 1999 join cere pronounc',
#  'constraint associ data collect limit abil select area summar data estim amount preserv transpar also includ statement regard materi impact result insuffici inform',
#  'scope',
#  '“series” engag cere nation network investor organ public interest group work compani like u stakehold like encourag practic solut sustain challeng',
#  'request becam benefactor cere stakehold advisori team — repres sampl stakehold compos individu volunt',
#  'investor nonprofit peer compani collect team work discus review sustain initi',
#  'throughout past year work jointli cere stakehold advisori team evalu 2006 err discus sustain practic throughout compani creat 2007 err partnership cere individu effort stakehold advisori team member continu vital success amr’ sustain effort input improv focu help u maintain maximum transpar ensur greater futur success valu look forward input regard futur endeavor',
#  'throughout we’v identifi content address gri standard disclosur look',
#  'conserv greenhous ga ghg reduct may vital health planet conserv vital company’ financi health happili two work hand hand — everi gallon save result lower expens fewer ghg',
#  'see appendix page 46 gri index refer',
#  'ly prof jay valenzuela lead coordin lo angel intern airport see awar spread beyond workplac',
#  'person',
#  'awar',
#  '500 employe train coordin airport facil specialist assist oversight american’ complianc locat around system key employe daili routin includ littl diplomaci plenti public relat small mountain paperwork ton detail sweat',
#  'jay valenzuela full time lead coordin lec lo angel intern airport lax boil employee’ awar',
#  '“a lec maintain awar employe extent mind regardless they’r deal lot law rule much common sen ” jay say “especi southern california keep everyone’ awar level high meet may stringent rule aa system ”',
#  'jay never expect role start 1975 flight attend he’ work reserv passeng servic cargo safeti manag role he’ lec massiv lax oper seven year',
#  '“ learn someth new everi day — it’ challeng fulfil there’ much know aspect compani i’v come see work affect person work affect everyon deal issu home ” jay say',
#  '“more peopl look way recycl especi e wast peopl awar chemic mix even they’d never mix thing like bleach ammonia home mayb kept tray room they’d never ”',
#  'littl exampl like add awar level chang way compani oper jay tell peopl work expect unexpect',
#  '“there’ alway someth come haven’t seen determin situat think ” say “the key know station common sen guid peopl right solut ”',
#  'jay cite plenti exampl demonstr employe awar reach beyond workplac describ got call recent employe whose car leak thought freon park lot antifreez import thing jay employe contact knew air issu major concern lax',
#  'jay love employe call type question look advic regard issu home',
#  '“it goe back employee’ awar level never green consciou that’ unawar effect action option avail right thing ” jay say “when one person awar interact employe spread awar whether employe consciou awar chang thing ”',
#  'commit respons',
#  '',
#  'prnesam ge',
#  'wn mental dee',
#  'c',
#  'py ky z zz “ay',
#  '',
#  'although challeng time industri must maintain commit respons fact increas commit aggress effici standard expand explain throughout',
#  'polici commit safeguard earth environ ongo develop implement sustain busi practic ceo employe respons ensur complianc polici station function manag locat subsidiari shall implement polici procedur compli polici statement',
#  'see appendix b page 49 corpor govern inform',
#  'format respons chosen reflect commit sustain busi practic primari distribut electron form hope reader find necessari print entir document make screen read easier page landscap orient maxim view comput screen must print plea consid print page need alway print doubl side',
#  'commit follow principl',
#  '¢ complianc law regul ¢ commit safeguard earth’ environ adopt sustain busi practic technolog procedur take pollut prevent conserv natur resourc account e establish program commun appropri inform affect employe custom contractor public regulatori author emerg respons author',
#  'wom la e lalla le',
#  'tal footpr ft fli gener ircra ‘',
#  'today creat effici fleet tomorrow environmen',
#  'fleet renew evolut american’ profil',
#  'boe 727',
#  'tabl',
#  'biggest footprint left visibl properti fli — make decis reduc impact even challeng despit econom',
#  'alon account 99 percent direct greenhous ga ghg follow signific abil affect impact come form put air restrict strive strike balanc implement project reduc footprint econom resourc effect maintain safeti reliabl critic busi',
#  'econom realiti face commerci — rise cost intens competit slow economi name',
#  'point histor timelin fleet includ effici avail time today midst effort replac 300 age md 80 — far',
#  'cic bla alat',
#  'narrow bodi boe 727 md 80 boe 737 800',
#  'first purchas',
#  'current amass retir',
#  'wide bodi dc 10 30 md 11 boe 777',
#  'dc 10 30',
#  'oy bop es oe metric ton per',
#  'burn burn yer gallon hour — gallon seat hour pound seat hour flight hour',
#  '161 7 120 5 declin',
#  '265 0 230 4 201 6',
#  'md 11',
#  'boe 777',
#  'workhors 655 fleet — state art boe 737 800',
#  '737 800 advanc version 737 famili boe first introduc 1967 sinc 737 built type today 737 800 bear littl resembl earli model design evolut revolut — like new engin updat wing design addit winglet — kept popular forefront industri',
#  'perspect benefit new obviou 737 800 burn 28 percent less md 80 larger cabin seat passeng result 35 percent reduct seat mile basi',
#  'modern narrow bodi fleet press need pursu greater effici gain afford new 737 800 fleet alreadi includ 77 effici way earli 2008',
#  'effici boe 737 800 burn 28 percent less md 80 larger cabin seat passeng result ina 35 percent reduct seat mile basi',
#  'announc replac 76 md 80 new 737 800 deliv 2009 2010 time evalu altern wide bodi continu renew fleet',
#  'scrap md 80 immedi mani factor play',
#  'dollar sen reduct ghg fleet connect directli reduct jet consumpt everi pound jet carbon dioxid cut 2 8 pound enabl u justifi gain sound econom program busi case chang must also incorpor cost associ integr new fleet',
#  '‘the signific cost ad new cours price tag consid case famili own two car replac vehicl would place hefti burden famili budget lender local bank may will lend enough money replac one car',
#  'purchas typic stagger minim monthli car expens give local bank greater assur car loan repaid',
#  'similarli ifw attempt replac fleet 300 md 80 737 800 financ simpli would avail carri list price 65 million impli fleet replac cost almost 20 billion price tag high lender cautiou natur phase approach purchas new need',
#  'new come chang throughout system carri singl passeng prepar inspect test fli pilot flight attend mainten personnel need train specif must begin month advanc part warehous need restock staff train new inventori fortun 737 alreadi present fleet cost less signific would entir new introduct time expens must also dedic retir old unlik car get trade often must revert origin purchas condit',
#  'dollar sen',
#  'commit preserv wonder world',
#  '‘the logist involv swap md 80 fleet mean limit quickli phase new introduct two three new month maximum manag given size current md 80 fleet mean — best — fleet replac timelin around eight year',
#  'time buy typic remain fleet 30 year md 80 fleet whose averag age 18 year first began enter fleet 1983 sever year life would begin phase middl next decad normal time time normal',
#  'price oil continu hit record level past year industri struggl difficult dilemma high bill mean less money avail invest new order lower bill new invest need made 2006 price jet pas 80 per barrel opt invest',
#  'boe 737 carri list price 65 million impli 737 fleet replac cost almost 20 billion price tag high lender cautiou',
#  '',
#  'fleet renew',
#  'figur',
#  '‘the 737 800 despit price tag accompani integr cost effici level overcom obstacl make good busi sen fleet effici gain help reduc cost vulner volatil market face today effect hedg u futur volatil',
#  'domest jet price',
#  '3 30 3 00 2 70 2 40 2 10 80 50 20 0 90 0 60 0 30 jan 92 jan 94 jan 96 jan 98 jan 00 jan 02 jan 04 jan 06 jan 08',
#  'per gallon',
#  'fleet',
#  'becom smaller part cost equat offset new predict cost ofa loan payment new',
#  'place order ‘the product capac major manufactur also limit — — put new air unlik consum look new car dealer showroom display readi purchas manufactur take time complex requir assembl million part constraint boeing’ product line produc 30 737 per month commit purchas possibl simpli purchas one come product line',
#  'secur spot product line often sign contract purchas 10 year advanc contract boe includ order 737 800 begin 2013 fortun flexibl purchas agreement enabl u advanc 76 737 800 order bring fleet 2009 2010',
#  'effici overcom cost obstacl effici gain 737 800 overcom cost obstacl make good busi sen',
#  'fleet futur fleet futur today’ draw board engin manufactur continu updat design achiev greater effici 737 800’ effici advantag enabl retir md 80 new design someday make 737 800 date',
#  'entir new model rare manufactur spend year design new model boe 787 airbu a350 wide bodi model current make initi break market next gener latest model break market incorpor latest engin design composit materi engin effici drive effici lighter composit materi mean weigh less therefor requir less fli',
#  'anew design narrow bodi class succeed 737 800 isn’t expect anoth decad come like includ similar advanc design well improv provid even greater effici',
#  'sustain industri respons question creat sustain industri goe beyond machin part success rest answer lie peopl',
#  'greener go forward commit 737 800 best way reduc carbon footprint today expect technolog advanc futur continu move u path way consum yet buy car get 80 mile per gallon cannot buy free know must buy best current avail new engin updat design altern next gener — studi industri develop focu safeti reliabl maintain flexibl agil make best decis point time',
#  'respons question creat sustain industri goe beyond machin part success rest answer lie peopl',
#  'peopl see throughout take u new height effici sustain way imagin today',
#  'ee',
#  '',
#  '«mall corner oper increas effici alg yer',
#  'energi conserv',
#  'transport relat far signific resourc oper measur volum weight relev metric transport relat 99 percent measur btu primarili jet consum also gasolin diesel fleet vehicl ground support equip',
#  'much combin eagl 3 billion gallon jet 2007 may sound like larg number first consid less volum u car truck two week allow u carri 121 million passeng almost 700 000 ton cargo averag distanc 861 mile',
#  'conserv greenhous ga ghg reduct may vital health planet conserv vital company’ financi health happili two work hand hand — everi gallon save result lower expens fewer ghg',
#  'jet v domest gasolin volum',
#  '2007 jet eagl 2007 gasolin u car truck',
#  'qd 2 2',
#  'comparison 3 billion gallon eagl 2007 less volum u car truck two week',
#  'figur',
#  '© oe s ae',
#  'rea neg en s © ae',
#  'procedur manual',
#  'timothi tyran former mechan flight oper specialist notic engin oil leak check procedur md 80 fleet’ isotop inspect card seem unnecessarili lengthi leak check run time procedur call run engin 3 minut idl anoth 3 minut 85 percent core engin final 5 minut back idl',
#  '“ sat cockpit watch flow gaug number roll like vega slot machin thought ‘were length run high engin power set realli necessari ’ burn ton ton money ” tim say',
#  'suggest oil leak check could adequ account singl 5 minut engin run idl e power plant oper engin team review idea found would work would save 50 000 100 000 year depend price today tim’ idea evolv standard procedur 7 900 leak check isotop inspect perform year',
#  '‘the busi case sustain undeni commit safe improv effici air ground 2007 improv effici 0 1861 gallon per revenu ton mile rtm 0 1855 gallon per rtm usag 2007 3 13 billion gallon base 16 86 billion rtm compar 3 18 billion gallon 17 08 billion rtm 2006',
#  'mu mooatsteyarcsl et',
#  '2 e n 2 o',
#  'gallon per rtm',
#  '2005',
#  'jet —e gallon jet per rtm',
#  'figur 2',
#  'measur',
#  'expect announc fleet chang help maintain trend next year replac mani md 80 fleet effici 737 retir a300 fleet',
#  'new part chang afoot within fleet initi smart program 2005 respons rise cost energi smart proven cost effect benefici program larg base recommend employe companywid improv effici',
#  'smart program end 2007 annual run rate 96 million gallon mean initi implement would addit 96 million gallon next year smart save 918 496 metric ton coze 20 275 short u ton nitrogen oxid',
#  'within industri expert gener standard measur call revenu ton mile rtm combin passeng cargo weight distanc flown rtm best measur much “produces” year',
#  'pollut express unit u short ton unit state fuelsmart make differ unit kilogram metric ton outsid unit state sinc cose gener intern protocol u compani metric unit metric ton 2 204 pound 000 kilogram short u ton 2 000',
#  'pound roughli 907 kilogram',
#  '¥',
#  'figur 3',
#  '2007 smart save sourc',
#  'program ad 4 7 million gallon run rate provid support acceler program 2009 wash program also demonstr extend commit provid opportun u work local author properli treat return wastewat wash station local system',
#  'e winglet design chang produc substanti reduct burn — correspond ghg',
#  'major initi contribut smart run rate present tabl closer look save initi',
#  'e cleaner engin turbin power fleet run effici clean three year program place test effici gain run high pressur water engin everi six month far',
#  'engin wash three year program place test effici gain run high pressur water engin everi six month far program ad 4 7 million gallon run rate provid support acceler program 2009',
#  '© s ae',
#  'rea neg en w s © ae',
#  'wast weight',
#  'past year smart team focus take extra equip reduc consumpt norm gonzalez narrow bodi qualiti inspector tulsa okla mainten base took idea step suggest logo light left right horizont stabil well associ wire could remov 737 fleet',
#  '“the light simpli take space reason ” gonzalez say “it seem like easi solut idea someth simpl could save larg amount ”',
#  'late 2005 first winglet instal 737 800 757 200 aerodynam modif wing structur result save 3 percent 737 winglet instal repres approxim 25 million gallon annual run rate instal complet 737 800 757 program complet end 2008 new 737 800 come winglet',
#  'e weight reduct weigh less carri less weight requir less everi pound shed save 12 000 gallon per year weight save initi look act includ carri less water remov unus oven purchas lighter cater cart lighter lcd screen replac heavi monitor replac heavi wall liner cargo compart liner made lighter composit materi initi possibl trim 600 pound fleet type result million save',
#  'reserv reduct flight dispatch carri necessari reach destin plu addit plan left arriv usual measur minut eagl flight alway carri reserv requir feder govern sometim two hour worth addit smart program eagl educ flight dispatch pilot reduc reserv day good weather level includ excess beyond need account unexpect event level provid substanti benefit reduc burn 000 pound extra carri averag eagl flight 40 pound must burn order carri reduc reserv appropri save 6 gallon per flight without compromis safeti 600 eagl flight take daili small reduct add',
#  '¥',
#  'ground support equip gse eagl heavili reliant ground support equip gse fulfil critic function move well bag cargo termin cargo facil correspondingli focu improv via smart initi limit relat issu invest electr gse substanti grow almost 2 800 piec make 24 2 percent gse fleet ‘the new electr unit less expens oper maintain produc fewer tarmac ‘the benefit electr gse go beyond save reduc',
#  'oper new york’ john f kennedi intern airport jfk receiv latest deliveri electr gse age ga power unit replac 67 electr bag tractor two electr belt loader chang jfk requir infrastructur upgrad accommod charg station new equip provid greater reliabl superior cold weather perform unit also switch load unload',
#  'high speed tug taxi gate hangar costli proposit factor requir run jet engin high speed tug five largest station soon arriv tow speed compat taxi tug lift move without engin tug save 3 2 million gallon 913 53 metric ton cose 42 24 u ton everi year',
#  '',
#  'pollut nox mean reduct smog nonattain area surround major airport electr gse aren’t complet free impact divert outsid nonattain area electr produc focus electr gse deliveri busiest station benefit gain shortest time possibl',
#  'person profil',
#  'save',
#  'last may work flight dublin ireland flight attend elizabeth van cleav notic three pull tray tabl middl galley 767 extra',
#  'suppli galley one specif cover area previous held oven tray tabl could elizabeth submit smart suggest remov mid galley pull tray tabl 767 fleet',
#  '“everi littl bit extra weight contribut consumpt someth isn’t remov ” elizabeth say',
#  'smart team took elizabeth’ suggest care consid whether idea could implement safe effect employe gener save idea engin depart approv suggest incorpor current cabin improv project mid galley pull tray remov 767 fleet reduc weight',
#  'base manag dan stefani describ elizabeth profession flight attend “she courteou respect great work true team player ” say',
#  'thank elizabeth dedic take extra step make better effici',
#  'megawatt hour',
#  '600 000 500 000 400 000 300 000 200 000 100 000',
#  'purchas electr',
#  'purchas natur ga',
#  'non transport relat energi direct energi sourc princip effort focus reduc energi associ transport howev macro footprint also shape part import less signific energi sourc energi sourc includ natur ga process steam gener comfort heat electr purchas util small quantiti oil provid backup electr less energi help minim amp impact emit less air pollut includ ghg also preserv natur resourc futur gener',
#  'energi 2007 598 000 megawatt hour electr 15 9 million therm natur ga direct energi essenti flat compar typic effect mean reduc util consumpt new technolog requir capit invest matter good busi seek outsid fund reduc invest 2006 airport fund util compani rebat',
#  'energi conserv reduc energi consumpt effort touch depart locat employe 2005 form util manag council bring employe togeth evalu potenti project could reduc util approxim 90 percent amr’ direct util cost realiz 10 locat includ major airport locat mainten facil headquart campu thu amr’ util manag council member repres locat key headquart depart',
#  'therm million',
#  '2006 — 2007',
#  'figur 5',
#  'amr’ impact less energi help minim amr’ impact emit less air pollut includ ghg also preserv natur resourc futur gener',
#  'whenev possibl date focus project quick return invest relamp light modif work project complet seven site save nearli 8 million',
#  'item council previous consid abl justifi time includ photovolta solar electr panel wind gener headquart campu cogener electr mainten facil',
#  'conserv team employe util manag council implement wide rang project includ e increas offic temperatur slightli summer month reduc cool need e retrofit light energi effici bulb offic mainten locat well airport termin e rewrap pipe insul',
#  '’ titluss bd',
#  'emissions”',
#  'lh commerci aviat domest',
#  '',
#  '2007 distribut ghg u',
#  'corn',
#  'ghg individu gener electr transport account nearli third domest ghg remain third domest ghg produc',
#  'solid wast combust 0 4',
#  'natur ga mobil marin non energi',
#  'mobil aviat stationari oil stationari ga mobil road stationari coal',
#  'aggreg industri agricultur commerci residenti sourc',
#  'recent u protect agenc epa data indic mobil aviat sourc contribut approxim 2 9 percent',
#  'figur',
#  '— 2007 distribut ghg',
#  '—',
#  'nation’ ghg approxim 9 percent transport sourc note epa estim aviat categori includ oper conduct commerci carrier eagl',
#  '',
#  'u transport sector',
#  'bi aviat marin',
#  'figur 2',
#  'greenhous ga individu gener electr transport account nearli third domest ghg aviat sourc contribut 2 9 percent u ghg 9 percent transport sourc',
#  'see appendix page 51 forum descript deriv ghg factor',
#  'tabl',
#  '2007 ghg result amr’ ghg calendar year 2007 slightli decreas 2006 total ghg attribut primarili approxim 98 percent carbon dioxid co jet combust',
#  'summari ghg',
#  'scope direct metric ton coe',
#  '2005',
#  '2006',
#  '31 2 million',
#  '30 6 million',
#  '30 million',
#  'scope 2 indirect metric ton coe',
#  'total scope scope 2 metric ton coe',
#  'intens ratio scope metric ton covz per 000 revenu ton mile',
#  '0 4 million',
#  '0 4 million',
#  '0 4 million',
#  '31 6 million',
#  '31 0 million',
#  '30 5 million',
#  'defin scope',
#  'scope direct attribut primarili co jet combust relat oper sourc scope direct materi cumul ghg howev includ ghg inventori complet',
#  'scope 2 indirect remain essenti flat respect prior year account co associ electr purchas electr util',
#  'scope 3 includ ghg inventori due quantiti jet comparison materi jet singl relev factor drive ghg exclus scope 3 consid materi effect result present err',
#  'ghg protocol defin direct indirect refer base sourc direct indirect direct indirect divid three broad categori scope',
#  'scope includ direct ghg jet combust primari sourc scope 2 indirect associ consumpt purchas electr heat steam',
#  'primarili result electr purchas scope 3 reflect indirect result activ outsid control organ',
#  'person',
#  'profil f q x bl q savi n g',
#  'support sever initi equip employe tool choic help reduc scope 3 indirect ghg tool includ follow e ride share employe carpool regularli co worker receiv prefer park headquart offic e discount mass transit locat abl negoti discount employe local mass transit',
#  'one peopl respons promot program reserv repres airlines’ southern reserv offic kirsten walker inform center administr coordin',
#  'kirsten work increas particip american’ program sinc earli 2006 even honor north texa clean air coalit employe transport coordin year 2006 award recogn kirsten’ american’ effort promot awar day emphas employe offic involv',
#  'energi effici save go beyond busi flight individu employe particip varieti program produc reduct company’ impact help creat better work life balanc',
#  'flexibl work schedul take employe heavi commut hour reduc time spent languish slow move traffic telecommut full time day two week cut commut mile e rideshaar american’ carpool program e public transport support promot e american’ home base repres telecommut reduc work week four day week program',
#  'e compress work week posit employe abl complet work week fewer five day instanc employe work four 10 hour day e telecommut posit allow work home satellit offic although exampl within compani employe telecommut full time reserv also possibl employe work home coupl time week remain time offic',
#  'activ focu make employe awar opportun avail also provid particip encourag incent like coupon area busi memorabilia giveaway flight museum long term particip also earn reward',
#  '“it’ realli part job love ” kirsten say “it allow help peopl whether it’ person vocat way benefit everyon ”',
#  'big pictur order compar ghg product ghg industri expert comparison call intens ratio intens ratio compar ghg industri standard measur product lower intens ratio denot greater effici sinc fewer ghg emit per standard measur product',
#  '2007 ghg absolut basi intens ratio basi decreas slightli less 2 percent chang categori compar 2006 continu evalu implement new initi reduc ghg greater progress ghg reduct hamper increas sever weather event hub continu air traffic control congest',
#  'ghg polici manag plan commit reduc ghg futur within constraint provid safe reliabl afford transport custom 2006 err announc goal improv effici 20 percent 2005 2020 earlier year laid ambiti goal increas effici 30 percent 2025 achiev challeng goal mean continu improv oper effici approxim 5 percent everi year 20 year',
#  'pace meet new effici commit ye despit challeng face 2007 intens ratio improv annual rate 7 percent sinc baselin year 2005',
#  'futur reduct requir invest fleet replac stakehold also invest help make industri effici engin manufactur must invest new technolog supplier must invest product cleaner govern',
#  'total ghg',
#  'q c 2 —e n c 2 2 5 £',
#  'metric ton co e per 000',
#  'revenu ton mile',
#  'se',
#  's',
#  'lm total scope 2 ghg co e',
#  '—¢ — intens ratio figur 3',
#  'agenc must invest effici nation intern air traffic control system',
#  'air regul air pollut ghg summar page oper sourc includ jet combust jet combust test cell combust site electr gener well steam gener comfort heat consumpt compani own vehicl ground support equip process paint clean mainten base',
#  'vast major nitrou oxid nox carbon monoxid co sulfur dioxid 10 micromet smaller particul matter pm10 associ jet combust associ transport',
#  'gener clean air act state local air inventori requir',
#  'non transport air tulsa okla kansa citi mo fort worth texa allianc mainten base',
#  '2007 non ghg',
#  'u ton',
#  '284 065',
#  '662 776',
#  'sa o 28 850 13278 © 68 500',
#  'co mvoc gopm10 bno b hap non voc',
#  'figur 4',
#  'mainten base includ natur ga oil combust process steam comfort heat backup sourc electr gener paint chemic usag associ maintain inflamm effect clean without residu — make practic addit approv feder aviat administr aviat industri beyond hcfc 141b',
#  'ozon deplet substanc reduc ozon deplet substanc odss nearli 17 percent sinc 2005 97 percent substanc design class 2 odss clean air act lower ozon deplet potenti design class odss',
#  'class 2 odss primarili mainten station hydrochlorofluorocarbon hcfc hcfc 141b class 2 od longer manufactur still limit applic hot brake need inspect hcfc 141b wide avail properti — spray applic',
#  'dichlorofluoroethan may one popular industri solvent ever howev forev',
#  'ozon deplet substanc reduct',
#  '2007 distribut ozon deplet',
#  'substanc class',
#  'ao class odss class 2 odss',
#  'figur 5',
#  'figur 6',
#  'halon way sole remain class ozon deplet substanc od halon found small portabl fire extinguish instal fleet renew plan contribut reduct odss new equip lavatori fire extinguish non halon equival',
#  'result montreal protocol domest product import hcfc 141b end 2002 global respons deplet earth ozon layer treati rule establish elimin odss worldwid first refriger solvent call chlorofluorocarbon cfc halogen fire suppress class odss phase current industri phase less damag class 2 odss howev legal restrict buy stock sell remain domest suppli hcfc 141b hcfc phase equal hcfc 141b phase first due wide rel high potenti damag ozon compar hcfc less damag class 2 odss hcfc 225',
#  'phase 2015',
#  'make switch heavili involv research non od altern hcfc 141b evalu substanc adequ safe replac hcfc 141b emit high level volatil organ compound restrict protect agenc unlik neighborhood mechan simpli switch one sever commerci altern current avail abil replac hcfc 141b commerci avail altern limit requir replac solvent approv certifi feder aviat administr',
#  'peopl worldwid seek way take conserv recycl effort heart touch everi aspect busi',
#  'corpor § respons repo',
#  'resourc conserv',
#  'resourc conserv daili commit reduc consumpt recycl wast materi promot overal awar daili global impact commit promot awar empow employe identifi way conserv resourc run busi combin reduc reus recycl materi usag product',
#  'like domest eagl oper wide dispers facil own lea result reli multipl suppli chain partner materi handl servic exist procur agreement standard requir thu result resourc conserv initi estim',
#  'promot minim recycl reduc volum solid wast gener airport control wast dispos method work local manag recycl materi program avail',
#  'requir support oper',
#  'undeni materi howev eagl requir mani materi resourc conduct day day oper',
#  'assess wast inventori eagl station mainten base provid indic materi signific quantiti includ paint relat product paint rag filter etc turbin compressor cleaner water oil lubric antifreez potabl water tank cleaner alkalin acid wash fluid process acid etc',
#  'conserv level commit promot awar empow employe identifi way conserv resourc run busi combin reduc reus recycl',
#  '© s ae',
#  'rea neg en s © ae',
#  'collect',
#  'recycl program alway save money save environ sometim special program run flight attend save co worker midst catastroph life event',
#  'wing foundat 501 c 3 chariti flight attend collect recycl empti aluminum can flight beverag servic effort began 1989 it’ prime exampl employe merg philanthrop passion work home',
#  'jennif wilson flight attend base washington c got involv foundation’ recycl effort 2004',
#  '“environment issu alway import i’v alway tri proactiv get involv ” jennif say “work wing foundat recycl program reward win win everyon — environ flight attend ”',
#  'foundation’ flight attend disast relief fadr fund receiv 100 percent proce program upsw 2003 19 000 rais recycl 2007 yearli total hit 109 000 jennif attribut gain grow conscious overal desir help co worker',
#  '“the fadr recycl fund still fraction assist provid wing foundat distribut 868 000 227 flight attend 2007 signific sourc fund grow year ” jennif say “it enabl u',
#  'provid assist victim home fire hurrican earthquak event creat financi hardship ”',
#  'flight attend collect trash final pas cabin land empti can insert collect tray remain cater cart tag alert cater partner presenc can cater staff deliv can recycl money rout back foundat',
#  '“we couldn’t without full support local cater compani work lsg sky chef gate gourmet ” jennif say',
#  '“work wing foundat recycl program reward win win everyon — environ flight attend ”',
#  'plan work keep expand program smaller locat system possibl can dead head back hub recycl progress made toward break barrier recycl effort inbound intern flight restrict base anim plant diseas control effort',
#  'recent receiv ok run recycl program miami american’ food beverag coordin also keep eye way expand recycl plastic newspap come practic collect item yet keep eye market technolog partnership infrastructur would make new recycl effort feasibl',
#  'flight attend recycl 10 million aluminum can',
#  'flight attend recycl',
#  'impact',
#  'jennif wilson took recycl campaign wing foundat 2003 friend robert amaya flight attend base miami',
#  'total estim water major facil',
#  '554 6',
#  '556 6',
#  'e c —e n c 3',
#  '2006',
#  '— 2007',
#  'figur',
#  'reduc consumpt mainten base make fleet modif save winglet addit requir peopl spaciou facil complex system consid one kansa citi mo facil histor facil requir 60 million gallon water everi year present signific opportun save',
#  'kansa citi base oper power central util plant water 50 000 gallon steel tank instal 1970 replac tank begun develop leak contribut reduc base’ total water consumpt 60 6 million gallon 2005 43 4 million gallon 2007 drop 28 4 percent',
#  'water save realiz headquart campu dalla well past four year save 79 million gallon water irrig system',
#  'smart irrig save 79 million gallon water irrig system calcul daili moistur content soil schedul water reduc chemic',
#  'calcul daili moistur content soil schedul water reduc chemic acequia process manag irrig local data experts’ knowledg agronomi soil scienc simplifi complex landscap mainten',
#  'reus recycl nonfuel materi uniqu opportun minim wast associ mainten sinc much mainten complet facil employe base avail data recycl recov 2 468 401 pound wast 2007 53 percent wast gener domest facil exclud common trash three mainten base',
#  'recycl program corpor initi push employe exampl provid employe desk side recycl contain paper wast also encourag placement larg recycl bin printer copier collect unwant paper program direct support employe level welcom opportun employe develop creat wast minim program encourag particip employe accept',
#  'control reduc impact take mani form corpor size ampl opportun facil real estat group promot sustain practic proud group accomplish amr’ mani station offic facil',
#  'amp’ recycl reus reclaim materi',
#  'materi',
#  '2007 total pound',
#  'oil relat petroleum high btu chemic sent blend energi recoveri oil',
#  '578 043 285 736',
#  'metal relat metal spray blast medium empti drum — poli metal element mercuri mercuri contamin debri element lead',
#  '214 200 73 896 4 964 570',
#  'lamp relat fluoresc lamp — straight hid lamp u shape fluoresc lamp circular fluoresc lamp',
#  '46 066 3 152 2 211 400',
#  'batteri nickel cadmium batteri lead acid batteri lithium batteri',
#  '31 617 4 765 553',
#  'miscellan nonhazard materi wastewat sludg rinsat water antifreez freon',
#  'hand wast reduct new automat paper towel dispens instal headquart 2008 provid doubl benefit reduc paper consumpt correspondingli paper wast wave hand dispens design length towel peopl less instal complet expect 320 dispens reduc wast weight headquart campu estim 50 percent 70 percent',
#  '215 346 4 200 408 274',
#  'tabl',
#  'headquart campu build admiral’ club locat part work includ follow',
#  'em ploye cham pion',
#  'replac carpet 800 000 squar foot headquart build carpet manufactur partial post consum content 100 percent recycl 560 000 pound old carpet divert landfil recycl honor greater dalla fort worth recycl allianc award construct demolit recycl effort',
#  'recycl corpor initi becom part cultur prime exampl peopl drive forc amp’ effort come oper dublin ireland',
#  'label place collect contain high traffic area david made arrang local recycl center pick transport collect materi site collect center thank david',
#  'corpor present 2007 three employe set form project group see could done local level start small awar program recycl improv team gather inform location’ impact provid articl tip onlin',
#  'purchas green privat offic furnitur headquart campu certifi greenguard institut third parti program verifi chemic particl meet indoor air qualiti guidelin forest stewardship council verifi wood legal log harvest well manag forest',
#  'david madden facil lead airline’ dublin offic proven champion wast contain hand access comput printer david took upon promot widen reach amr’ david madden dublin facil lead show recycl program throughout dublin recycl contain sign facil first step reduc facility’ impact',
#  '© ae oe mt ae rea neg en w mt © ae',
#  'e »',
#  'oo',
#  'specifi materi airport admiral’ club local sourc furnitur lo angel factori lo angel intern airport club club also reupholst rather replac worn piec',
#  'repair offic chair rather replac whenev possibl store part unus chair futur repair',
#  'extent practic leverag corpor action promot recycl beyond corpor boundari employe home complet quantum program — retir 30 000 corpor comput 2006 — host employe home recycl event earth day employe brought 400 comput monitor printer consum electron item love opportun respons dispos person electron wast took full advantag deliv 25 cubic yard person e wast home — enough fill semitrail second event took place june plan make regular earth day event employe',
#  '© ae © s ae',
#  'ren neg w s © ae',
#  'beyond headquart initi employe dalla fort worth intern airport conduct e wast collect nearli 7 000 pound tv monitor comput microwav brought recycl 2008 nationwid 5 million ton e wast thrown landfil inciner everi year result toxin contain lead mercuri end releas air water old tv set contain 10 pound lead',
#  'old new',
#  'anoth creativ role adopt amr’ human resourc train personnel train center ship old video audio tape columbia mo compani reformat resel altern commun train act program support employ peopl disabl act program provid employ 40 individu limit employ opportun partnership act program began octob 1992 430 000 tape donat year 7 ounc per video tape that’ 188 000 pound wast avoid landfil 2007 850 video audio cassett recycl',
#  '2008 rod peland custom servic agent st loui coordin collect deliveri tape recycl act includ movi brought home flight “ey american” video corpor commun item',
#  'sy 7 ae',
#  'oe ye 7 ae',
#  'pound paper',
#  'without olf trash',
#  'airline’ anyth tear program nearli 790 ton paper good recycl sinc 2004 key success it’ easi staff headquart campu reserv offic train confer center fight academi facil collect offic paper newspap cardboard desk side contain need take extra time remov stapl paper clip tape post note plastic tab metal bind addit strateg place bin accommod addit paper well plastic bottl aluminum can result ad 2007 alon 262 ton product recycl equat 4 454 tree 865 cubic yard landfil space',
#  'materi dispos amr’ recycl effort key minim solid wast transfer landfil dispos facil wast materi cannot recycl dispos site inciner placement landfil mean',
#  'mani airport station integr wast system solid wast gener station tenant e food servic compani retail store cargo compani etc combin manag airport author rather individu creat economi scale minim number multipl trash vendor also place author respons sustain dispos practic airport author',
#  'promot minim recycl reduc volum solid wast gener direct control dispos non recycl solid wast gener facil integr wast dispos servic multipl',
#  'q',
#  'see appendix e page 56 wast inventori detail',
#  'tenant addit feder regul prohibit recycl solid wast gener intern flight wast requir law inciner',
#  'vendor deliveri servic local landfil permit facil 2007 gener 2 12 million pound nonhazard wast exclud municip solid wast trash 2 54 million pound hazard wast appendix e provid detail wast inventori',
#  'respons control dispos solid wast contract local',
#  '2007 dispos method summari',
#  'b recycl energi recoveri',
#  'inciner',
#  'hazard landfil',
#  'w aqueou treatment',
#  'figur 2',
#  'mean make wast describ 85 percent hazard wast gener three mainten base largest portion wast stream associ mainten repair wast includ acid cleaner paint wast deriv metal plate coat oper remain portion gener wide dispers airport locat hazard wast relat cleaner coat minor mainten support equip keep air — call line mainten work contrast hazard wast major 65 percent non hazard wast gener individu station non hazard wast petroleum relat wast deriv jet oil oili water non hazard wast includ fluoresc light batteri',
#  '¥',
#  '© oe s ae rea neg en w s © ae',
#  'take home',
#  'lead coordin technic crew chief american’ oper boston saw opportun spot steve thoma renown host pb televis seri “thi old hous ” admir club',
#  '“ knew skier walk introduc ask he’d interest part american’ chariti ski event benefit cystic fibrosi foundat ” say wallac start',
#  '“it cool research project impact ” wallac say “it need ”',
#  '1973 fleet servic clerk “he sign we’v friend ever sinc ”',
#  'recent friendship put wallac work spare time unearth project thomas’ new seri “renov nation” discoveri network planet green',
#  'wallac also manag major project thoma one person profession tie thoma want renov summer home remot island coast main latest green materi leav smallest footprint environ effort featur “renov nation ”',
#  '“the greenest thing bring need equip island nearbi supplier creat nearli carbon neutral project work done everi trace presenc era field trail transport construct materi equip like we’d never ” wallac say “we built work barn guest quarter featur 100 percent recycl roof materi design last 80 year ”',
#  'wallac also long list experiment green project way work whether he’ test energi effici program reduc footprint station evalu bag belt impregn teflon reduc drag — correspondingli energi consumpt — wallac passion',
#  '“it’ cool research project impact ” wallac say “it’ need it’ go save planet eventu i’m make happen ”',
#  'wallace’ effort includ recycl virtual everyth station test baggag claim belt plate made composit materi would reduc belt’ weight 7 000 pound instal solar panel seldom vehicl make sure batteri stay charg enough start need',
#  'thoma hous project turn famili affair wallac whose 17 year old son joseph came along project',
#  '“he end build potter shed almost entir show kid left pretti decent carpent ”',
#  '',
#  'va rpa conjunct wit wie 5 5 agenc toreduc impact sound inhabit place oper',
#  'mr corporati ronment respons',
#  'nois reduct',
#  'intern civil aviat organ icao establish balanc approach nois manag serv identifi nois relat issu analyz mitig via sourc reduct land plan oper procedur restrict',
#  'unit state feder aviat administr adopt element icao balanc approach part 161 part 150 titl 14 u code feder regul eagl compli requir',
#  'sound reduct new boe 737 800 enter fleet next decad fli quieter md 80o replac winglet ad wing exist also helo make quieter',
#  'european union provis made gradual remov margin compliant servic nois sensit airport oper intern',
#  'look ahead',
#  'commerci aviat altern initi 2006 first time histori becam singl largest compon u oper cost u commerci aviat consum less 3 percent total u energi drive 6 percent u gross econom output 9 percent nation employ secur sustain sourc essenti continu prosper meanwhil concern risen intern impact aviat growth aviat commun engag emerg altern industri work togeth collect need data motiv direct research altern aviat caaft’ specif goal promot develop altern option offer equival level safeti compar favor petroleum base jet cost base specif goal enhanc secur energi suppli',
#  'mani suppli chain member serv aviat industri particip commerci aviat altern initi caafi establish enhanc energi secur sustain aviat explor potenti altern caafi provid forum u commerci exist fleet 655 jet 296 eagl may benefit combin effort caafi aviat suppli chain member includ strive acceler develop biofuel relat logist creat sustain respons altern industri',
#  'share',
#  'econom effect u commerci aviat consum less 3 percent total u energi drive 6 percent u gross econom output 9 percent nation employ',
#  '‘ » ny mt',
#  'new technolog part initi conserv focus identifi new technolog solut improv effici oper major initi help reduc impact come year includ',
#  'led screen approach gate laser scan devic identifi direct arrow led screen front gate allow pilot park appropri spot avoid delay due unavail guidemen pilot abl park turn engin sooner',
#  '767 300 winglet first carrier instal winglet 767 300 winglet 11 foot tall add 11 foot wingspan project kick earli 2009 potenti reap save 17 million gallon per year',
#  'ramplink new technolog hand ramp crew chief allow enter data quicker accur save reduc taxi delay handheld devic call ramplink allow ramp crew chief receiv real time feedback flight critic inform bar code scan enter relev data cargo contain',
#  'dock guidanc system autom park devic reduc arriv delay improv local air qualiti system incorpor low level laser scan devic',
#  'develop futur new technolog solut take effort futur reduc impact boost effici peopl',
#  'dear stakehold',
#  'behalf men woman eagl like express commit support amr’ initi',
#  'top prioriti eagl person safeti employe custom commit safeti lead u ensur part materi label correctli handl properli dispos respons way',
#  'effort reduc consumpt fossil extend across compani manifest',
#  'electr vehicl tarmac elimin buse termin regular mainten wash engin pilots’ optimum flight plan achiev direct rout minim burn effici ground base power system ground instead run engin keep light temperatur control',
#  'hope demonstr eagl seriou conserv energi safeguard employe custom protect environ constantli improv sustain compani planet',
#  'sincer p oe peter bowler presid ceo eagl',
#  'oo',
#  'detail impact track progress toward goal sustain',
#  'appendix',
#  'ela minlelsy',
#  'descript',
#  'strategi analysi',
#  'name organ',
#  'primari brand product servic organ indic natur role provid product servic degre util outsourc',
#  'oper structur organ includ main divis oper compani subsidiari joint ventur',
#  'locat organization’ headquart',
#  'number countri organ oper name countri either major oper specif relev sustain issu cover',
#  'natur ownership legal form',
#  'market serv includ geograph breakdown sector serv type custom beneficiari',
#  'gri index',
#  'descript',
#  'scale organ includ e number employe e net sale privat sector organ net revenu public sector organ e total capit broken term debt equiti privat sector organ © quantiti product servic provid addit organ encourag provid addit inform appropri e total asset e benefici ownership includ ident percentag ownership largest sharehold e breakdown countri region follow sale revenu countri region make 5 percent total revenu cost countri region make 5 percent total revenu employe',
#  'gri index',
#  'descript',
#  'facil open close expans ¢ chang share capit structur capit format mainten alter oper privat sector organ',
#  'award receiv period',
#  'period e g fiscal calendar year inform provid',
#  'date recent previou',
#  'cycl annual biennial etc',
#  'contact point question regard content',
#  'signific chang period regard size structur ownership includ e locat chang oper includ',
#  'process defin content includ e determin materi ¢ priorit topic within ¢ identifi stakehold organ expect',
#  'includ explan organ appli “guidanc defin content” associ principl',
#  'gri index',
#  'descript',
#  'boundari e g countri divis subsidiari lea facil joint ventur supplier see gri boundari protocol guidanc',
#  'gri index',
#  'descript',
#  'signific chang previou period scope boundari measur method appli',
#  'state specif limit scope boundari see complet principl explan scope boundari scope address full rang materi econom social impact organ state strategi project timelin provid complet coverag',
#  'basi joint ventur subsidiari lea facil outsourc oper entiti significantli affect compar period period organ',
#  'explan effect restat inform provid earlier reason statement e g merger acquisit chang base year period natur busi measur method',
#  'tabl identifi locat standard disclosur identifi page number web link follow found ¢ strategi analysi 2 e organiz profil 2 2 10 e paramet 3 3 13 ¢ govern commit engag 4 4 17 e disclosur manag approach per categori © coreperform indic e gri addit indic includ e gri sector supplement indic includ appendix page 46',
#  'gri index',
#  'descript',
#  'non execut member committe indic direct respons econom social perform',
#  'indic whether chair highest govern bodi also execut offic function within organization’ manag reason arrang',
#  'govern structur organ includ committe highest govern bodi respons specif task set strategi organiz oversight describ mandat composit includ number independ member',
#  'organ unitari board structur state number member highest govern bodi independ non execut member state organ defin “independent” “non execut ” element appli organ unitari board structur see glossari definit “independ ” applic',
#  'mechan sharehold employe provid recommend direct highest govern bodi includ refer process regard e sharehold resolut',
#  '',
#  'descript',
#  'mechan enabl minor sharehold express opinion highest govern bodi ¢ inform consult employe work relationship formal represent bodi organ level “work council ” represent employe highest govern bodi identifi topic relat econom social perform rais mechan period',
#  'list stakehold group engag organ exampl stakehold group ¢ commun civil societi ¢ custom e sharehold provid capit ¢ supplier e employe worker trade union',
#  'descript',
#  'basi identif select stakehold engag includ organization’ process defin stakehold group determin group engag engag',
#  'gri index',
#  'dyexsyorat ole 0a',
#  'total direct indirect greenhous ga weight core',
#  'relev indirect greenhous ga weight core',
#  'direct energi consumpt primari energi sourc core',
#  'energi save due conserv effici improv addit',
#  'initi reduc greenhous ga reduct achiev addit',
#  'nox sox signific air type weight core',
#  'initi provid energi effici renew energi base product servic reduct energi requir result initi addit',
#  'initi reduc indirect energi consumpt reduct achiev addit',
#  'direct econom valu gener distribut includ revenu oper cost employe compens donat commun invest retain earn payment capit provid govern',
#  'annual page 50',
#  'percentag employe train organization’ anti corrupt polici procedur',
#  'appendix b',
#  'ambr’ sharehold annual elect amr’ board director director requir act best interest compani sharehold mind board overse manag compani includ perform ceo senior manag posit chairman board ceo fill gerard j arpey',
#  'corpor respons author issu manag amr’ corpor depart extens specif train staff station mainten base amr‘ corpor depart led manag director vice presid safeti secur ‘thi corpor staff direct reli upon much larger network eagl staff train issu locat facil togeth broadli distribut team work ensur meet exce requir comprehens program manag corpor',
#  'specif program design accomplish follow goal',
#  'interact stakehold supplier custom issu impact compani commerci aviat identifi practic must implement improv manag system',
#  'assist facil manag effort protect environ achiev complianc identifi oper rais potenti concern elimin occurr accid non complianc reduc elimin releas pollut environ increas level employe awar verifi complianc identifi non complianc regul compani polici',
#  'central object amr’ program continu improv perform follow area',
#  'air audit chemic import export chemic inventori drink water train curriculum hydrant system greenhous ga industri wastewat nois remedi spill respons storag tank wast',
#  'tabl',
#  'train corpor provid special train staff station specif requir cours usual associ epa enforc initi like recent revis oil spill prevent regul seriou audit find',
#  'take social respons serious establish varieti initi educ employe includ web base train program busi ethic program includ train polici regard anti corrupt fraud respons workplac harass unlaw discrimin safeti manag specif non manag employe requir take train read commun involv practic 2008 citizen www aa com',
#  'busi ethic train includ anti corrupt',
#  'employe group manag non manag total employe',
#  'percentag 88 2 10',
#  'appendix c',
#  'organiz profil corpor incorpor octob 1982 base fort worth texa ambr’ oper fall almost entir industri subsidiari follow inc eagl hold corpor eagl',
#  'acomplet organiz profil includ annual file year u secur exchang commiss sec publish http www aa com content amrcorp investorrel main jhtml',
#  'largest schedul passeng world term avail seat mile revenu passeng mile servic approxim 170 destin throughout north america caribbean latin america europ asia cargo oper also make one largest schedul air freight carrier world',
#  'eagl own two region eagl inc execut inc busi eagl mr tom opderbeck project',
#  'profil 2007 respons err calendar year 2007 jan 2007 dec 31 2007 began annual 2006 err publish third quarter 2007',
#  'question comment regard err direct',
#  'manag',
#  '4333 amon carter blvd fort worth tx 76155 2664 tom opderbeck aa com',
#  'appendix',
#  'util follow greenhous ga ghg inventori standard conduct ghg inventori',
#  'ansi iso nsf e14064 2006 greenhous gase part specif guidanc organiz level quantif greenhous ga remov « greenhous ga protocol corpor account standard revis edit world resourc institut',
#  'consist standard inventori base follow principl relev complet consist transpar accuraci made dilig effort meet principl',
#  'usag inform refriger usag data natur ga gasolin pertin oper inform calcul annual six ghg categori recogn e14064 ghg defin e14064 gaseou constitu atmospher natur anthropogen absorb emit radiat specif wavelength within spectrum infrar radiat emit earth’ surfac atmospher cloud six chemic recogn e14064 correspond global warm potenti cover tabl',
#  'cio oe tal ctanait meen itel',
#  'carbon dioxid co methan ch nitrou oxid n 0 hydrofluorocarbon hfc perfluorocarbon pfc sulfur hexafluorid sf tabl',
#  '0 21 0 310 vari vari 23 900',
#  'ghg convert carbon dioxid equival co e base global warm potenti provid annex c e14064 includ appendix ‘the ghg convert co e multipli correspond global warm potenti',
#  'ghg classifi direct indirect accord industri standard',
#  'scope direct includ ghg associ stationari transport sourc transport sourc includ compani own vehicl ground support equip direct associ',
#  'activ three mainten engin base direct scope sourc base includ steam gener electr gener jet engin test combust compani vehicl ground support equip fugit hfc refriger equip',
#  'scope indirect cover ghg associ purchas electr steam airport termin offic area airport termin mainten engin base',
#  'scope ill indirect inventori option wri e14064 scope iii indirect sourc includ gener worker commut work supplier deliv good locat contractor pick wast recycl product facil',
#  'ghg calcul gener accord principl industri standard referenc multipli throughput factor throughput quantiti jet consum natur ga burn gasolin diesel fleet vehicl ground support equip electr purchas factor repres quantiti ghg gener per unit throughput',
#  '‘the accuraci ghg inventori depend accuraci factor accuraci complet throughput data factor data base readili avail inform literatur convers carbon carbon dioxid well understood factor util believ highli accur within percent',
#  'accuraci throughput data depend upon methodolog tool track throughput data sinc 99 percent scope direct ghg attribut jet consumpt accuraci throughput',
#  'data depend primarili accuraci jet usag data track quantiti jet consum flight data record flight tabul within central databas amr’ annual base data set believ accur within least 3 percent data cross check compar jet purchas quantiti confirm data accuraci purchas electr natur ga quantiti base util bill monthli usag quantiti compil within central databas ground support equip fleet vehicl track station mainten base data tabul',
#  'summar headquart case data point smaller station readili avail case throughput assum base throughput similar station thu accuraci throughput make minor contribut ghg total may highli accur howev accuraci throughput account 99 percent ghg highli accur',
#  '‘the overal accuraci ghg inventori believ accur reflect ghg within least 4 percent actual ghg base assumpt regard accuraci factor throughput data',
#  'ghg summari',
#  'factor',
#  'ch',
#  'n',
#  'jet combust',
#  'natur ga combust',
#  'ref 3 page 45 heat combust 5 67',
#  'metric ton 10° hhv bt',
#  '70 8716',
#  'short ton 10° btu',
#  'ref page 55',
#  '70 91',
#  'short ton 10° btu',
#  'ref 4 page 32',
#  'u',
#  'mmbtu bbl',
#  'metric ton gallon deriv factor',
#  'metric ton gj',
#  '9567 66600',
#  'ref page 55',
#  '19 36',
#  'pound gallon',
#  'ref 3 page 64',
#  '9 567666',
#  'ne acc',
#  'kg co2 mmbtu',
#  'ref 4 page 32',
#  '0 008781696',
#  'metric ton gallon',
#  'convers',
#  'gallon',
#  'ij',
#  'rt',
#  '9',
#  '0 009567666',
#  'metric ton gallon deriv factor',
#  'metric ton c0 10 ref 5 appendix f btu',
#  'ref 6 1054 joul btu 135 000',
#  '0 5',
#  'kg terajoul',
#  '0 00528',
#  'kg mmbtu',
#  'ref 7',
#  '0 001882',
#  'kg gallon',
#  'ref 7',
#  'btu gallon jet deriv factor',
#  '0 0005',
#  'metric',
#  '0 00528',
#  'metric ton 10° btu',
#  '0 000001882',
#  'metric ton gallon',
#  'convers',
#  'ton terajoul metric ton tera btu',
#  'deriv factor',
#  '4 74383e 07',
#  '4 74383e 19',
#  'metric ton btu deriv factor factor',
#  '6 40417e 14',
#  'metric ton gallon deriv metric ton 000 deriv factor gallon',
#  '6 40417e 11',
#  'ref 6 1054 joul btu 135 000',
#  '2 0',
#  'kg terajoul',
#  '0 00011',
#  'kg mmbtu',
#  '0 000627',
#  'kg gallon',
#  'ref 7',
#  'btu gallon jet deriv factor',
#  '0 002',
#  'metric',
#  '0 00011',
#  'metric ton 10° btu',
#  '0 000000627',
#  'metric ton gallon',
#  'convers',
#  'ton terajoul metric ton tera btu metric ton btu',
#  '',
#  '9e 06 9e 18',
#  '2 56167e 13',
#  'metric ton gallon deriv factor metric ton 000 deriv factor gallon',
#  '9° 56167e 10',
#  'efer',
#  'see page 55 global warm potenti detail',
#  'factor fel usa dis 2',
#  'ch',
#  'ghg summari',
#  'purchas bet —‘ —reterneer™ factor int —— «—— eronee™ metric ton co e ref 5',
#  'factor tt «cetra factor unit',
#  '',
#  '23',
#  'koth ret ° appenc pose eet',
#  'appendix f',
#  'ko galion metric ton gallon',
#  'heat content 86 300 btu gallon',
#  'ref 3 page 45',
#  '0 00542',
#  '72 31 0 01026802',
#  'metric ton gallon ref 5 appendix h metric ton gallon deriv factor kg mmbtu 0 00000548 metric ton mw hr refer 7 0 000910565 kg gallon',
#  '0 01055 0 01055 metric ton 10° btu',
#  'ref 7',
#  '9 10565e 07',
#  'metric ton gallon',
#  'ton gallon',
#  'deriv factor ane',
#  '4981e 06 metric',
#  '0 00063',
#  'kg mmbtu',
#  '0 00000948 metric ton mw hr',
#  '5 46339e 05',
#  'kg gallon',
#  '0 00063 metric ton 10° btu 8 946e 08 metric ton gallon',
#  'see page 55 global warm potenti detail refer',
#  '5 46339e 08',
#  'metric ton gallon',
#  'ghg',
#  'cho late mme nite recommend 100 year ghg global warm potenti',
#  'se te',
#  'refer calcul tool direct stationari combust version 3 0 juli 2005 2 petroleum industri guidelin greenhous ga batel decemb 2003 3 technic guidelin voluntari greenhous gase 1605 b program offic polici intern affair usdo march 2006 4 world resourc institut discus paper natur ga transmiss distribut greenhous ga protocol jan 26 2007 5 instruct form eia 1605 voluntari greenhous gase apri 2 2007',
#  '00 ch',
#  '310 650',
#  '300',
#  '6 cheatin panel apter 3 section 3 6 2 tabl 7 air cool planet campu carbon calcul ca cp version 5 0 2006',
#  'age 2006 guidelin volum 2 3 6',
#  'appendix e',
#  'hazard non hazard wast gener type locat hazard pound airport oper mainten base subtot 341 210 2 738 452 261 144 2 994 686 493 319 775 267 412 284 690 624 3 079 662 2 855 830 2 268 586 2 102 908',
#  '373 864 2 169 433 2 943 297',
#  'non hazard pound airport oper mainten base subtot 617 518 935 332',
#  'total',
#  'locat',
#  '876 030 542 783 647 105 810 746 779 952 794 452 552 850 2 418 813 2 457 851 574 404',
#  '014 541 108 615 2 123 156',
#  '4 632 512 5 274 643 4 726 437 3 677 312 4 666 453',
#  'recycl energi recoveri inciner hazard landfil aqueou treatment total wast',
#  '2007 dispos summari',
#  'airport oper p ound hazard non hazard subtot 3 046 70 819',
#  '266 817 582 000',
#  '85 937 286 954',
#  '373 864 014 541',
#  '73 865',
#  '848 817',
#  '372 891',
#  '388 405',
#  'mainten base pound hazard non hazard subtot 459 816 034',
#  '470 987 258 239',
#  '52 670 2 379',
#  '180 300 24 333',
#  '465 017 7 630',
#  '2 169 433 108 615',
#  '816 493',
#  '729 226',
#  '55 049',
#  '204 633',
#  '472 647',
#  '3 278 048',
#  'total',
#  '890 358',
#  '578 043',
#  '427 940',
#  '276 082',
#  '494 030',
#  '4 666 453',
#  'appendic er',
#  'appendix f 2007 fleet inventori',
#  'flight equip — oper own lea oper compani dec 31 2007 includ',
#  'averag seat capac own lea lea',
#  'capit oper',
#  'averag total age year',
#  'equip type',
#  'averi larg major compani own encumb lien grant connect financ transact enter compani',
#  '57',
#  'corpor ¥ respons']
