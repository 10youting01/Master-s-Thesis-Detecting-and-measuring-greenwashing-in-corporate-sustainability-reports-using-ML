# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = "/usr/bin/tesseract"
from pdf2image import convert_from_path
from PIL import Image, ImageDraw
import numpy as np
import json
import os
from statistics import quantiles

# %%
pdf_path = "../CSR Reporting/NASDAQ/NASDAQ_ADI_2019.pdf"  # 替換為您的 PDF 路徑
output_image_path = "../CSR_report_processed_v3/NASDAQ/NASDAQ_ADI_2019"
output_file_path = "../CSR_report_processed_v3/NASDAQ/NASDAQ_ADI_2019/NASDAQ_ADI_2019.json"

# %%
def process_pdf(pdf_path, output_image_path, density_threshold=15):

    if not os.path.exists(output_image_path):
        os.makedirs(output_image_path)
    # 轉換 PDF 頁面為圖片
    pages = convert_from_path(pdf_path, dpi=300)
    all_dense_regions = []
    all_region_data = []

    for page_i, page_image in enumerate(pages):
        print(f"\n--- Processing Page {page_i + 1} ---")

        # OCR 文字區塊提取
        data = pytesseract.image_to_data(page_image, output_type=pytesseract.Output.DICT)

        if len(data['text']) < 300:
            continue

        valid_indices = [i for i in range(len(data['text'])) if data['text'][i].strip()]

        if not valid_indices:
            print(f"Page {page_i + 1}: No valid text found.")
            continue

        # 計算前25%的平均值
        def trimmed_mean(values, trim_ratio=0.3):
            if not values:
                return 0
            sorted_values = np.sort(values)
            trim_count = int(len(sorted_values) * trim_ratio)
            trimmed_values = sorted_values[:trim_count]
            return np.mean(trimmed_values)
        
        def percentage(values, trim_ratio=0.8):
            if not values:
                return 0
            sorted_values = np.sort(values)
            trim_count = int(len(sorted_values) * trim_ratio)
            trimmed_values = sorted_values[trim_count]
            return trimmed_values

        non_zero_widths = [w for w in data['width'] if w > 0]
        non_zero_heights = [h for h in data['height'] if h > 0]
        average_width = percentage(non_zero_widths, trim_ratio=0.5)
        average_height = percentage(non_zero_heights)

        # 設定合併閾值
        horizontal_threshold = int(average_width)
        vertical_threshold = int(average_height)

        print(f"Avg Width: {average_width}, Avg Height: {average_height}")
        print(f"Horizontal Threshold: {horizontal_threshold}, Vertical Threshold: {vertical_threshold}")

        # **建立所有文字區塊**
        region_candidates = []
        for i in valid_indices:
            x, y, w, h = data['left'][i], data['top'][i], data['width'][i], data['height'][i]
            text = data['text'][i].strip()
            text_length = len(text)
            region_candidates.append([x, y, x + w, y + h, text_length, text, 1])  # 1 代表這個區塊內的文字數量

        # 記錄所有的文字區塊資訊
        region_data = []
        for region in region_candidates:
            region_data.append({
                "page": page_i + 1,
                "x1": region[0], "y1": region[1],
                "x2": region[2], "y2": region[3],
                "width": region[2] - region[0],
                "height": region[3] - region[1],
                "text_length": region[4],
                "text": region[5],
                "text_num": region[6]
            })

        all_region_data.extend(region_data)

        # **建立區塊關係圖**
        adjacency_list = {i: [] for i in range(len(region_candidates))}

        # 檢查所有文字區塊是否相連
        for i, region1 in enumerate(region_candidates):
            print(f"Region {i}: {region}")
            x1, y1, x2, y2, _, _, _ = region1

            for j, region2 in enumerate(region_candidates):
                if i != j:
                    x1b, y1b, x2b, y2b, _, _, _ = region2

                    # 判斷兩個區塊是否可以合併
                    horizontally_close = abs(x1 - x2b) <= horizontal_threshold or abs(x1b - x2) <= horizontal_threshold
                    vertically_close = abs(y1 - y2b) <= vertical_threshold or abs(y1b - y2) <= vertical_threshold
                    overlap_vertically = not (y1 > y2b or y2 < y1b)
                    overlap_horizontally = not (x1 > x2b or x2 < x1b)

                    if (horizontally_close or overlap_horizontally) and (vertically_close or overlap_vertically):
                        adjacency_list[i].append(j)
                        print(f"Page {page_i + 1}: Connecting {region1[5]} -> {region2[5]}")  # 🔥 Debug 這行

        # **合併區塊**
        visited = set()
        merged_regions = []

        def merge_connected_regions(start_idx):
            print(f"Starting BFS from: {region_candidates[start_idx][5]} at {region_candidates[start_idx][0]}, {region_candidates[start_idx][1]}")

            """ 使用 BFS 來合併所有相連區塊 """
            queue = [start_idx]
            merged_region = list(region_candidates[start_idx])  # 複製初始區塊資訊
            visited.add(start_idx)
            print(f"Merging {region_candidates[start_idx][5]} at {region_candidates[start_idx][0]}, {region_candidates[start_idx][1]}")

            while queue:
                idx = queue.pop(0)
                for neighbor_idx in adjacency_list[idx]:
                    if neighbor_idx not in visited:
                        visited.add(neighbor_idx)
                        queue.append(neighbor_idx)
                        
                        # 合併區塊
                        x1b, y1b, x2b, y2b, text_length, text, text_num = region_candidates[neighbor_idx]
                        merged_region[0] = min(merged_region[0], x1b)
                        merged_region[1] = min(merged_region[1], y1b)
                        merged_region[2] = max(merged_region[2], x2b)
                        merged_region[3] = max(merged_region[3], y2b)
                        merged_region[4] += text_length
                        merged_region[5] += " " + text
                        merged_region[6] += text_num

            return merged_region

        # 執行合併
        for i in range(len(region_candidates)):
            if i not in visited:
                merged_region = merge_connected_regions(i)
                merged_regions.append(merged_region)

        # **篩選高密度區域**
        dense_regions = []
        for region in merged_regions:
            x1, y1, x2, y2, total_text_length, all_text, total_text_num = region
            if total_text_num > density_threshold:
                width = x2 - x1
                height = y2 - y1
                area = width * height
                text_density = total_text_length / area if area > 0 else 0

                if text_density >= 0:
                # if text_density >= 0.0001:
                    dense_regions.append({
                        "page": page_i + 1,
                        "x1": x1, "y1": y1, "x2": x2, "y2": y2,
                        "width": width, "height": height, "area": area,
                        "total_text_length": total_text_length,
                        "text_density": text_density,
                        "all_text": all_text.strip(),
                        "text_num": total_text_num
                    })
        
        # 

        all_dense_regions.extend(dense_regions)

        # **繪製紅色邊框標註區域**
        draw = ImageDraw.Draw(page_image)
        for region in dense_regions:
            x1, y1, x2, y2 = region["x1"], region["y1"], region["x2"], region["y2"]
            draw.rectangle([x1, y1, x2, y2], outline="red", width=2)

        page_image.save(f'{output_image_path}/page_{page_i + 1}.jpg')

    # **輸出 JSON**
    with open(f'{output_image_path}/dense_regions.json', 'w') as json_file:
        json.dump(all_dense_regions, json_file, indent=4)
    
    with open(f'{output_image_path}/region_candidates.json', 'w') as json_file:
        json.dump(all_region_data, json_file, indent=4, ensure_ascii=False)

# %%
process_pdf(pdf_path, output_image_path, density_threshold=0)
# Out:
# --- Processing Page 1 ---
#
# --- Processing Page 2 ---
#
# --- Processing Page 3 ---
# Avg Width: 132, Avg Height: 41
# Horizontal Threshold: 132, Vertical Threshold: 41
# Region 0: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting ~ -> MESSAGE
# Region 1: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting MESSAGE -> ~
# Page 3: Connecting MESSAGE -> FROM
# Region 2: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting FROM -> MESSAGE
# Page 3: Connecting FROM -> OUR
# Region 3: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting OUR -> FROM
# Page 3: Connecting OUR -> CEO
# Region 4: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting CEO -> OUR
# Region 5: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Throughout -> ADI's
# Page 3: Connecting Throughout -> 55-year
# Page 3: Connecting Throughout -> and
# Page 3: Connecting Throughout -> adapted
# Page 3: Connecting Throughout -> to
# Page 3: Connecting Throughout -> changing
# Region 6: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting ADI's -> Throughout
# Page 3: Connecting ADI's -> 55-year
# Region 7: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting 55-year -> Throughout
# Page 3: Connecting 55-year -> ADI's
# Page 3: Connecting 55-year -> history,
# Page 3: Connecting 55-year -> adapted
# Page 3: Connecting 55-year -> to
# Page 3: Connecting 55-year -> changing
# Page 3: Connecting 55-year -> global
# Region 8: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting history, -> 55-year
# Page 3: Connecting history, -> we
# Page 3: Connecting history, -> have
# Page 3: Connecting history, -> changing
# Page 3: Connecting history, -> global
# Page 3: Connecting history, -> dynamics.
# Region 9: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting we -> history,
# Page 3: Connecting we -> have
# Page 3: Connecting we -> successfully
# Page 3: Connecting we -> Our
# Region 10: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting have -> history,
# Page 3: Connecting have -> we
# Page 3: Connecting have -> successfully
# Page 3: Connecting have -> Our
# Region 11: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting successfully -> we
# Page 3: Connecting successfully -> have
# Page 3: Connecting successfully -> navigated
# Page 3: Connecting successfully -> dynamics.
# Page 3: Connecting successfully -> Our
# Page 3: Connecting successfully -> ability
# Page 3: Connecting successfully -> to
# Page 3: Connecting successfully -> do
# Page 3: Connecting successfully -> so—and
# Region 12: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting navigated -> successfully
# Page 3: Connecting navigated -> ability
# Page 3: Connecting navigated -> to
# Page 3: Connecting navigated -> do
# Page 3: Connecting navigated -> so—and
# Region 13: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> Throughout
# Page 3: Connecting and -> adapted
# Region 14: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting adapted -> Throughout
# Page 3: Connecting adapted -> 55-year
# Page 3: Connecting adapted -> and
# Page 3: Connecting adapted -> to
# Page 3: Connecting adapted -> changing
# Page 3: Connecting adapted -> commitment
# Page 3: Connecting adapted -> to
# Region 15: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> Throughout
# Page 3: Connecting to -> 55-year
# Page 3: Connecting to -> adapted
# Page 3: Connecting to -> changing
# Region 16: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting changing -> Throughout
# Page 3: Connecting changing -> 55-year
# Page 3: Connecting changing -> history,
# Page 3: Connecting changing -> adapted
# Page 3: Connecting changing -> to
# Page 3: Connecting changing -> global
# Page 3: Connecting changing -> commitment
# Page 3: Connecting changing -> to
# Page 3: Connecting changing -> solving
# Page 3: Connecting changing -> the
# Region 17: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting global -> 55-year
# Page 3: Connecting global -> history,
# Page 3: Connecting global -> changing
# Page 3: Connecting global -> dynamics.
# Page 3: Connecting global -> to
# Page 3: Connecting global -> solving
# Page 3: Connecting global -> the
# Page 3: Connecting global -> world’s
# Region 18: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting dynamics. -> history,
# Page 3: Connecting dynamics. -> successfully
# Page 3: Connecting dynamics. -> global
# Page 3: Connecting dynamics. -> Our
# Page 3: Connecting dynamics. -> ability
# Page 3: Connecting dynamics. -> solving
# Page 3: Connecting dynamics. -> the
# Page 3: Connecting dynamics. -> world’s
# Page 3: Connecting dynamics. -> toughest
# Page 3: Connecting dynamics. -> problems
# Region 19: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Our -> we
# Page 3: Connecting Our -> have
# Page 3: Connecting Our -> successfully
# Page 3: Connecting Our -> dynamics.
# Page 3: Connecting Our -> ability
# Region 20: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting ability -> successfully
# Page 3: Connecting ability -> navigated
# Page 3: Connecting ability -> dynamics.
# Page 3: Connecting ability -> Our
# Page 3: Connecting ability -> to
# Page 3: Connecting ability -> do
# Page 3: Connecting ability -> so—and
# Page 3: Connecting ability -> toughest
# Page 3: Connecting ability -> problems
# Page 3: Connecting ability -> while
# Region 21: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> successfully
# Page 3: Connecting to -> navigated
# Page 3: Connecting to -> ability
# Page 3: Connecting to -> do
# Page 3: Connecting to -> so—and
# Region 22: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting do -> successfully
# Page 3: Connecting do -> navigated
# Page 3: Connecting do -> ability
# Page 3: Connecting do -> to
# Page 3: Connecting do -> so—and
# Region 23: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting so—and -> successfully
# Page 3: Connecting so—and -> navigated
# Page 3: Connecting so—and -> ability
# Page 3: Connecting so—and -> to
# Page 3: Connecting so—and -> do
# Region 24: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting our -> commitment
# Region 25: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting commitment -> adapted
# Page 3: Connecting commitment -> changing
# Page 3: Connecting commitment -> our
# Page 3: Connecting commitment -> to
# Page 3: Connecting commitment -> solving
# Region 26: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> adapted
# Page 3: Connecting to -> changing
# Page 3: Connecting to -> global
# Page 3: Connecting to -> commitment
# Page 3: Connecting to -> solving
# Region 27: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting solving -> changing
# Page 3: Connecting solving -> global
# Page 3: Connecting solving -> dynamics.
# Page 3: Connecting solving -> commitment
# Page 3: Connecting solving -> to
# Page 3: Connecting solving -> the
# Page 3: Connecting solving -> world’s
# Page 3: Connecting solving -> better
# Page 3: Connecting solving -> future—has
# Page 3: Connecting solving -> become
# Region 28: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> changing
# Page 3: Connecting the -> global
# Page 3: Connecting the -> dynamics.
# Page 3: Connecting the -> solving
# Page 3: Connecting the -> world’s
# Region 29: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting world’s -> global
# Page 3: Connecting world’s -> dynamics.
# Page 3: Connecting world’s -> solving
# Page 3: Connecting world’s -> the
# Page 3: Connecting world’s -> toughest
# Region 30: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting toughest -> dynamics.
# Page 3: Connecting toughest -> ability
# Page 3: Connecting toughest -> world’s
# Page 3: Connecting toughest -> problems
# Page 3: Connecting toughest -> become
# Page 3: Connecting toughest -> evident
# Region 31: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting problems -> dynamics.
# Page 3: Connecting problems -> ability
# Page 3: Connecting problems -> toughest
# Page 3: Connecting problems -> while
# Page 3: Connecting problems -> we
# Page 3: Connecting problems -> evident
# Page 3: Connecting problems -> during
# Region 32: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting while -> ability
# Page 3: Connecting while -> problems
# Page 3: Connecting while -> we
# Region 33: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting we -> problems
# Page 3: Connecting we -> while
# Region 34: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting engineer -> a
# Page 3: Connecting engineer -> better
# Page 3: Connecting engineer -> unprecedented
# Region 35: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting a -> engineer
# Page 3: Connecting a -> better
# Region 36: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting better -> solving
# Page 3: Connecting better -> engineer
# Page 3: Connecting better -> a
# Page 3: Connecting better -> future—has
# Region 37: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting future—has -> solving
# Page 3: Connecting future—has -> better
# Page 3: Connecting future—has -> become
# Region 38: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting become -> solving
# Page 3: Connecting become -> toughest
# Page 3: Connecting become -> future—has
# Page 3: Connecting become -> even
# Page 3: Connecting become -> more
# Region 39: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting even -> become
# Page 3: Connecting even -> more
# Page 3: Connecting even -> evident
# Region 40: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting more -> become
# Page 3: Connecting more -> even
# Page 3: Connecting more -> evident
# Page 3: Connecting more -> COVID-19
# Region 41: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting evident -> toughest
# Page 3: Connecting evident -> problems
# Page 3: Connecting evident -> even
# Page 3: Connecting evident -> more
# Page 3: Connecting evident -> during
# Page 3: Connecting evident -> COVID-19
# Region 42: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting during -> problems
# Page 3: Connecting during -> evident
# Page 3: Connecting during -> the
# Page 3: Connecting during -> COVID-19
# Page 3: Connecting during -> pandemic.
# Region 43: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> during
# Page 3: Connecting the -> COVID-19
# Region 44: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting unprecedented -> engineer
# Page 3: Connecting unprecedented -> challenges
# Region 45: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting challenges -> unprecedented
# Page 3: Connecting challenges -> faced
# Page 3: Connecting challenges -> as
# Region 46: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting faced -> challenges
# Page 3: Connecting faced -> as
# Page 3: Connecting faced -> a
# Page 3: Connecting faced -> result
# Region 47: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting as -> challenges
# Page 3: Connecting as -> faced
# Page 3: Connecting as -> a
# Page 3: Connecting as -> result
# Region 48: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting a -> faced
# Page 3: Connecting a -> as
# Page 3: Connecting a -> result
# Region 49: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting result -> faced
# Page 3: Connecting result -> as
# Page 3: Connecting result -> a
# Page 3: Connecting result -> of
# Page 3: Connecting result -> the
# Region 50: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting of -> result
# Page 3: Connecting of -> the
# Page 3: Connecting of -> COVID-19
# Region 51: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> result
# Page 3: Connecting the -> of
# Page 3: Connecting the -> COVID-19
# Region 52: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting COVID-19 -> more
# Page 3: Connecting COVID-19 -> evident
# Page 3: Connecting COVID-19 -> during
# Page 3: Connecting COVID-19 -> the
# Page 3: Connecting COVID-19 -> of
# Page 3: Connecting COVID-19 -> the
# Page 3: Connecting COVID-19 -> pandemic.
# Region 53: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting pandemic. -> during
# Page 3: Connecting pandemic. -> COVID-19
# Page 3: Connecting pandemic. -> problems
# Page 3: Connecting pandemic. -> As
# Region 54: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting For -> example,
# Region 55: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting example, -> For
# Page 3: Connecting example, -> ADI
# Page 3: Connecting example, -> stepped
# Page 3: Connecting example, -> community
# Page 3: Connecting example, -> by
# Page 3: Connecting example, -> shifting
# Region 56: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting ADI -> example,
# Page 3: Connecting ADI -> stepped
# Region 57: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting stepped -> example,
# Page 3: Connecting stepped -> ADI
# Page 3: Connecting stepped -> in
# Page 3: Connecting stepped -> to
# Page 3: Connecting stepped -> help
# Page 3: Connecting stepped -> community
# Page 3: Connecting stepped -> by
# Page 3: Connecting stepped -> shifting
# Page 3: Connecting stepped -> towards
# Page 3: Connecting stepped -> technologies
# Region 58: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting in -> stepped
# Page 3: Connecting in -> to
# Page 3: Connecting in -> help
# Region 59: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> stepped
# Page 3: Connecting to -> in
# Page 3: Connecting to -> help
# Page 3: Connecting to -> meet
# Region 60: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting help -> stepped
# Page 3: Connecting help -> in
# Page 3: Connecting help -> to
# Page 3: Connecting help -> meet
# Page 3: Connecting help -> the
# Page 3: Connecting help -> towards
# Page 3: Connecting help -> technologies
# Region 61: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting meet -> to
# Page 3: Connecting meet -> help
# Page 3: Connecting meet -> the
# Page 3: Connecting meet -> needs
# Region 62: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> help
# Page 3: Connecting the -> meet
# Page 3: Connecting the -> needs
# Region 63: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting needs -> meet
# Page 3: Connecting needs -> the
# Page 3: Connecting needs -> of
# Page 3: Connecting needs -> the
# Region 64: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting of -> needs
# Page 3: Connecting of -> the
# Page 3: Connecting of -> medical
# Region 65: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> needs
# Page 3: Connecting the -> of
# Page 3: Connecting the -> medical
# Region 66: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting medical -> of
# Page 3: Connecting medical -> the
# Region 67: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting community -> example,
# Page 3: Connecting community -> stepped
# Page 3: Connecting community -> by
# Page 3: Connecting community -> shifting
# Page 3: Connecting community -> to
# Page 3: Connecting community -> the
# Page 3: Connecting community -> crisis.
# Region 68: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting by -> example,
# Page 3: Connecting by -> stepped
# Page 3: Connecting by -> community
# Page 3: Connecting by -> shifting
# Page 3: Connecting by -> to
# Page 3: Connecting by -> the
# Page 3: Connecting by -> crisis.
# Region 69: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting shifting -> example,
# Page 3: Connecting shifting -> stepped
# Page 3: Connecting shifting -> community
# Page 3: Connecting shifting -> by
# Page 3: Connecting shifting -> towards
# Page 3: Connecting shifting -> to
# Page 3: Connecting shifting -> the
# Page 3: Connecting shifting -> crisis.
# Page 3: Connecting shifting -> This
# Page 3: Connecting shifting -> included
# Region 70: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting towards -> stepped
# Page 3: Connecting towards -> help
# Page 3: Connecting towards -> shifting
# Page 3: Connecting towards -> technologies
# Region 71: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting technologies -> stepped
# Page 3: Connecting technologies -> help
# Page 3: Connecting technologies -> towards
# Page 3: Connecting technologies -> that
# Page 3: Connecting technologies -> support
# Page 3: Connecting technologies -> This
# Page 3: Connecting technologies -> included
# Page 3: Connecting technologies -> increasing
# Page 3: Connecting technologies -> the
# Region 72: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting that -> technologies
# Page 3: Connecting that -> support
# Region 73: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting support -> technologies
# Page 3: Connecting support -> that
# Page 3: Connecting support -> the
# Page 3: Connecting support -> global
# Page 3: Connecting support -> increasing
# Page 3: Connecting support -> the
# Page 3: Connecting support -> production
# Page 3: Connecting support -> of
# Region 74: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> support
# Page 3: Connecting the -> global
# Region 75: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting global -> support
# Page 3: Connecting global -> the
# Page 3: Connecting global -> production
# Page 3: Connecting global -> of
# Region 76: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting response -> to
# Page 3: Connecting response -> the
# Page 3: Connecting response -> components
# Page 3: Connecting response -> for
# Region 77: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> community
# Page 3: Connecting to -> by
# Page 3: Connecting to -> shifting
# Page 3: Connecting to -> response
# Page 3: Connecting to -> the
# Page 3: Connecting to -> crisis.
# Region 78: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> community
# Page 3: Connecting the -> by
# Page 3: Connecting the -> shifting
# Page 3: Connecting the -> response
# Page 3: Connecting the -> to
# Page 3: Connecting the -> crisis.
# Region 79: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting crisis. -> community
# Page 3: Connecting crisis. -> by
# Page 3: Connecting crisis. -> shifting
# Page 3: Connecting crisis. -> to
# Page 3: Connecting crisis. -> the
# Page 3: Connecting crisis. -> This
# Page 3: Connecting crisis. -> included
# Region 80: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting This -> shifting
# Page 3: Connecting This -> technologies
# Page 3: Connecting This -> crisis.
# Page 3: Connecting This -> included
# Region 81: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting included -> shifting
# Page 3: Connecting included -> technologies
# Page 3: Connecting included -> crisis.
# Page 3: Connecting included -> This
# Page 3: Connecting included -> increasing
# Region 82: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting increasing -> technologies
# Page 3: Connecting increasing -> support
# Page 3: Connecting increasing -> included
# Page 3: Connecting increasing -> the
# Page 3: Connecting increasing -> production
# Page 3: Connecting increasing -> point-of-care
# Page 3: Connecting increasing -> solutions,
# Page 3: Connecting increasing -> such
# Region 83: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> technologies
# Page 3: Connecting the -> support
# Page 3: Connecting the -> increasing
# Page 3: Connecting the -> production
# Region 84: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting production -> support
# Page 3: Connecting production -> global
# Page 3: Connecting production -> increasing
# Page 3: Connecting production -> the
# Page 3: Connecting production -> of
# Page 3: Connecting production -> solutions,
# Page 3: Connecting production -> such
# Page 3: Connecting production -> ventilators,
# Region 85: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting of -> support
# Page 3: Connecting of -> global
# Page 3: Connecting of -> production
# Region 86: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting components -> response
# Page 3: Connecting components -> for
# Page 3: Connecting components -> critical
# Page 3: Connecting components -> infusion
# Page 3: Connecting components -> and
# Region 87: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting for -> response
# Page 3: Connecting for -> components
# Page 3: Connecting for -> critical
# Region 88: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting critical -> components
# Page 3: Connecting critical -> for
# Page 3: Connecting critical -> point-of-care
# Region 89: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting point-of-care -> increasing
# Page 3: Connecting point-of-care -> critical
# Page 3: Connecting point-of-care -> solutions,
# Page 3: Connecting point-of-care -> and
# Page 3: Connecting point-of-care -> diagnostic
# Page 3: Connecting point-of-care -> imaging
# Page 3: Connecting point-of-care -> systems.
# Region 90: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting solutions, -> increasing
# Page 3: Connecting solutions, -> production
# Page 3: Connecting solutions, -> point-of-care
# Page 3: Connecting solutions, -> such
# Page 3: Connecting solutions, -> as
# Page 3: Connecting solutions, -> imaging
# Region 91: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting such -> increasing
# Page 3: Connecting such -> production
# Page 3: Connecting such -> solutions,
# Page 3: Connecting such -> as
# Page 3: Connecting such -> ventilators,
# Region 92: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting as -> solutions,
# Page 3: Connecting as -> such
# Page 3: Connecting as -> ventilators,
# Region 93: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting ventilators, -> production
# Page 3: Connecting ventilators, -> such
# Page 3: Connecting ventilators, -> as
# Region 94: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting infusion -> components
# Page 3: Connecting infusion -> pumps
# Region 95: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting pumps -> infusion
# Page 3: Connecting pumps -> and
# Page 3: Connecting pumps -> diagnostic
# Region 96: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> components
# Page 3: Connecting and -> point-of-care
# Page 3: Connecting and -> pumps
# Page 3: Connecting and -> diagnostic
# Region 97: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting diagnostic -> point-of-care
# Page 3: Connecting diagnostic -> pumps
# Page 3: Connecting diagnostic -> and
# Page 3: Connecting diagnostic -> imaging
# Region 98: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting imaging -> point-of-care
# Page 3: Connecting imaging -> solutions,
# Page 3: Connecting imaging -> diagnostic
# Page 3: Connecting imaging -> systems.
# Region 99: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting systems. -> point-of-care
# Page 3: Connecting systems. -> imaging
# Region 100: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting And -> our
# Page 3: Connecting And -> impact
# Region 101: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting our -> And
# Page 3: Connecting our -> impact
# Region 102: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting impact -> And
# Page 3: Connecting impact -> our
# Page 3: Connecting impact -> extends
# Page 3: Connecting impact -> The
# Page 3: Connecting impact -> Analog
# Page 3: Connecting impact -> Devices
# Page 3: Connecting impact -> Foundation
# Region 103: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting extends -> impact
# Page 3: Connecting extends -> beyond
# Region 104: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting beyond -> extends
# Page 3: Connecting beyond -> our
# Page 3: Connecting beyond -> own
# Page 3: Connecting beyond -> Devices
# Page 3: Connecting beyond -> Foundation
# Page 3: Connecting beyond -> made
# Region 105: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting our -> beyond
# Page 3: Connecting our -> own
# Page 3: Connecting our -> capabilities
# Region 106: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting own -> beyond
# Page 3: Connecting own -> our
# Page 3: Connecting own -> capabilities
# Region 107: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting capabilities -> our
# Page 3: Connecting capabilities -> own
# Page 3: Connecting capabilities -> and
# Page 3: Connecting capabilities -> facilities.
# Page 3: Connecting capabilities -> made
# Page 3: Connecting capabilities -> donations
# Page 3: Connecting capabilities -> of
# Page 3: Connecting capabilities -> $4
# Page 3: Connecting capabilities -> million
# Region 108: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> capabilities
# Page 3: Connecting and -> facilities.
# Page 3: Connecting and -> $4
# Region 109: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting facilities. -> capabilities
# Page 3: Connecting facilities. -> and
# Page 3: Connecting facilities. -> $4
# Region 110: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting The -> impact
# Page 3: Connecting The -> Analog
# Region 111: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Analog -> impact
# Page 3: Connecting Analog -> The
# Page 3: Connecting Analog -> Devices
# Page 3: Connecting Analog -> World
# Page 3: Connecting Analog -> Health
# Page 3: Connecting Analog -> Organization’s
# Region 112: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Devices -> impact
# Page 3: Connecting Devices -> beyond
# Page 3: Connecting Devices -> Analog
# Page 3: Connecting Devices -> Foundation
# Page 3: Connecting Devices -> Organization’s
# Region 113: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Foundation -> impact
# Page 3: Connecting Foundation -> beyond
# Page 3: Connecting Foundation -> Devices
# Page 3: Connecting Foundation -> made
# Page 3: Connecting Foundation -> Organization’s
# Page 3: Connecting Foundation -> COVID-19
# Page 3: Connecting Foundation -> Solidarity
# Region 114: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting made -> beyond
# Page 3: Connecting made -> capabilities
# Page 3: Connecting made -> Foundation
# Page 3: Connecting made -> donations
# Page 3: Connecting made -> Organization’s
# Page 3: Connecting made -> COVID-19
# Page 3: Connecting made -> Solidarity
# Region 115: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting donations -> capabilities
# Page 3: Connecting donations -> made
# Page 3: Connecting donations -> of
# Page 3: Connecting donations -> $4
# Page 3: Connecting donations -> million
# Page 3: Connecting donations -> COVID-19
# Page 3: Connecting donations -> Solidarity
# Region 116: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting of -> capabilities
# Page 3: Connecting of -> donations
# Page 3: Connecting of -> $4
# Page 3: Connecting of -> million
# Page 3: Connecting of -> Solidarity
# Region 117: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting $4 -> capabilities
# Page 3: Connecting $4 -> and
# Page 3: Connecting $4 -> facilities.
# Page 3: Connecting $4 -> donations
# Page 3: Connecting $4 -> of
# Page 3: Connecting $4 -> million
# Page 3: Connecting $4 -> Solidarity
# Page 3: Connecting $4 -> Response
# Page 3: Connecting $4 -> Fund
# Region 118: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting million -> capabilities
# Page 3: Connecting million -> donations
# Page 3: Connecting million -> of
# Page 3: Connecting million -> $4
# Page 3: Connecting million -> to
# Page 3: Connecting million -> the
# Region 119: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> million
# Page 3: Connecting to -> the
# Region 120: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> million
# Page 3: Connecting the -> to
# Region 121: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting World -> Analog
# Page 3: Connecting World -> Health
# Region 122: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Health -> Analog
# Page 3: Connecting Health -> World
# Page 3: Connecting Health -> Organization’s
# Region 123: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Organization’s -> Analog
# Page 3: Connecting Organization’s -> Devices
# Page 3: Connecting Organization’s -> Foundation
# Page 3: Connecting Organization’s -> made
# Page 3: Connecting Organization’s -> Health
# Page 3: Connecting Organization’s -> COVID-19
# Page 3: Connecting Organization’s -> key
# Page 3: Connecting Organization’s -> supporter
# Page 3: Connecting Organization’s -> of
# Page 3: Connecting Organization’s -> the
# Page 3: Connecting Organization’s -> Global
# Page 3: Connecting Organization’s -> Citizen
# Region 124: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting COVID-19 -> Foundation
# Page 3: Connecting COVID-19 -> made
# Page 3: Connecting COVID-19 -> donations
# Page 3: Connecting COVID-19 -> Organization’s
# Page 3: Connecting COVID-19 -> Solidarity
# Page 3: Connecting COVID-19 -> Global
# Page 3: Connecting COVID-19 -> Citizen
# Page 3: Connecting COVID-19 -> “One
# Region 125: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Solidarity -> Foundation
# Page 3: Connecting Solidarity -> made
# Page 3: Connecting Solidarity -> donations
# Page 3: Connecting Solidarity -> of
# Page 3: Connecting Solidarity -> $4
# Page 3: Connecting Solidarity -> COVID-19
# Page 3: Connecting Solidarity -> Response
# Page 3: Connecting Solidarity -> Global
# Page 3: Connecting Solidarity -> Citizen
# Page 3: Connecting Solidarity -> “One
# Page 3: Connecting Solidarity -> World:
# Page 3: Connecting Solidarity -> Together
# Region 126: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Response -> $4
# Page 3: Connecting Response -> Solidarity
# Page 3: Connecting Response -> Fund
# Page 3: Connecting Response -> and
# Page 3: Connecting Response -> “One
# Page 3: Connecting Response -> World:
# Page 3: Connecting Response -> Together
# Page 3: Connecting Response -> At
# Region 127: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Fund -> $4
# Page 3: Connecting Fund -> Response
# Page 3: Connecting Fund -> and
# Region 128: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> Response
# Page 3: Connecting and -> Fund
# Region 129: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting was -> a
# Page 3: Connecting was -> key
# Page 3: Connecting was -> supporter
# Region 130: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting a -> was
# Page 3: Connecting a -> key
# Page 3: Connecting a -> supporter
# Region 131: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting key -> Organization’s
# Page 3: Connecting key -> was
# Page 3: Connecting key -> a
# Page 3: Connecting key -> supporter
# Page 3: Connecting key -> Home”
# Page 3: Connecting key -> campaign.
# Region 132: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting supporter -> Organization’s
# Page 3: Connecting supporter -> was
# Page 3: Connecting supporter -> a
# Page 3: Connecting supporter -> key
# Page 3: Connecting supporter -> of
# Page 3: Connecting supporter -> the
# Page 3: Connecting supporter -> Home”
# Page 3: Connecting supporter -> campaign.
# Page 3: Connecting supporter -> Additionally,
# Region 133: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting of -> Organization’s
# Page 3: Connecting of -> supporter
# Page 3: Connecting of -> the
# Page 3: Connecting of -> Global
# Region 134: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> Organization’s
# Page 3: Connecting the -> supporter
# Page 3: Connecting the -> of
# Page 3: Connecting the -> Global
# Region 135: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Global -> Organization’s
# Page 3: Connecting Global -> COVID-19
# Page 3: Connecting Global -> Solidarity
# Page 3: Connecting Global -> of
# Page 3: Connecting Global -> the
# Page 3: Connecting Global -> Citizen
# Region 136: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Citizen -> Organization’s
# Page 3: Connecting Citizen -> COVID-19
# Page 3: Connecting Citizen -> Solidarity
# Page 3: Connecting Citizen -> Global
# Page 3: Connecting Citizen -> “One
# Page 3: Connecting Citizen -> World:
# Region 137: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting “One -> COVID-19
# Page 3: Connecting “One -> Solidarity
# Page 3: Connecting “One -> Response
# Page 3: Connecting “One -> Citizen
# Page 3: Connecting “One -> World:
# Region 138: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting World: -> Solidarity
# Page 3: Connecting World: -> Response
# Page 3: Connecting World: -> Citizen
# Page 3: Connecting World: -> “One
# Page 3: Connecting World: -> Together
# Page 3: Connecting World: -> $500,000
# Region 139: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Together -> Solidarity
# Page 3: Connecting Together -> Response
# Page 3: Connecting Together -> World:
# Page 3: Connecting Together -> At
# Page 3: Connecting Together -> donated
# Page 3: Connecting Together -> $500,000
# Page 3: Connecting Together -> to
# Region 140: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting At -> Response
# Page 3: Connecting At -> Together
# Page 3: Connecting At -> $500,000
# Region 141: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Home” -> key
# Page 3: Connecting Home” -> supporter
# Page 3: Connecting Home” -> campaign.
# Region 142: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting campaign. -> key
# Page 3: Connecting campaign. -> supporter
# Page 3: Connecting campaign. -> Home”
# Page 3: Connecting campaign. -> Additionally,
# Page 3: Connecting campaign. -> Massachusetts
# Page 3: Connecting campaign. -> General
# Page 3: Connecting campaign. -> Hospital's
# Region 143: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Additionally, -> supporter
# Page 3: Connecting Additionally, -> campaign.
# Page 3: Connecting Additionally, -> the
# Page 3: Connecting Additionally, -> foundation
# Page 3: Connecting Additionally, -> Massachusetts
# Page 3: Connecting Additionally, -> General
# Page 3: Connecting Additionally, -> Hospital's
# Page 3: Connecting Additionally, -> Vaccine
# Region 144: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> Additionally,
# Page 3: Connecting the -> foundation
# Region 145: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting foundation -> Additionally,
# Page 3: Connecting foundation -> the
# Page 3: Connecting foundation -> donated
# Region 146: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting donated -> Together
# Page 3: Connecting donated -> foundation
# Page 3: Connecting donated -> $500,000
# Region 147: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting $500,000 -> World:
# Page 3: Connecting $500,000 -> Together
# Page 3: Connecting $500,000 -> At
# Page 3: Connecting $500,000 -> donated
# Page 3: Connecting $500,000 -> to
# Page 3: Connecting $500,000 -> Immunotherapy
# Page 3: Connecting $500,000 -> Center,
# Region 148: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> Together
# Page 3: Connecting to -> $500,000
# Page 3: Connecting to -> Center,
# Region 149: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Massachusetts -> campaign.
# Page 3: Connecting Massachusetts -> Additionally,
# Page 3: Connecting Massachusetts -> General
# Region 150: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting General -> campaign.
# Page 3: Connecting General -> Additionally,
# Page 3: Connecting General -> Massachusetts
# Page 3: Connecting General -> Hospital's
# Region 151: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Hospital's -> campaign.
# Page 3: Connecting Hospital's -> Additionally,
# Page 3: Connecting Hospital's -> General
# Page 3: Connecting Hospital's -> Vaccine
# Page 3: Connecting Hospital's -> further
# Page 3: Connecting Hospital's -> advance
# Page 3: Connecting Hospital's -> the
# Page 3: Connecting Hospital's -> importance
# Region 152: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Vaccine -> Additionally,
# Page 3: Connecting Vaccine -> Hospital's
# Page 3: Connecting Vaccine -> and
# Page 3: Connecting Vaccine -> Immunotherapy
# Region 153: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> Vaccine
# Page 3: Connecting and -> Immunotherapy
# Region 154: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Immunotherapy -> $500,000
# Page 3: Connecting Immunotherapy -> Vaccine
# Page 3: Connecting Immunotherapy -> and
# Page 3: Connecting Immunotherapy -> Center,
# Page 3: Connecting Immunotherapy -> importance
# Page 3: Connecting Immunotherapy -> of
# Page 3: Connecting Immunotherapy -> testing
# Page 3: Connecting Immunotherapy -> and
# Page 3: Connecting Immunotherapy -> vaccine
# Region 155: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Center, -> $500,000
# Page 3: Connecting Center, -> to
# Page 3: Connecting Center, -> Immunotherapy
# Page 3: Connecting Center, -> vaccine
# Region 156: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting which -> will
# Page 3: Connecting which -> further
# Region 157: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting will -> which
# Page 3: Connecting will -> further
# Region 158: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting further -> Hospital's
# Page 3: Connecting further -> which
# Page 3: Connecting further -> will
# Page 3: Connecting further -> advance
# Region 159: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting advance -> Hospital's
# Page 3: Connecting advance -> further
# Page 3: Connecting advance -> the
# Page 3: Connecting advance -> importance
# Region 160: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> Hospital's
# Page 3: Connecting the -> advance
# Page 3: Connecting the -> importance
# Region 161: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting importance -> Hospital's
# Page 3: Connecting importance -> Immunotherapy
# Page 3: Connecting importance -> advance
# Page 3: Connecting importance -> the
# Page 3: Connecting importance -> of
# Page 3: Connecting importance -> testing
# Region 162: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting of -> Immunotherapy
# Page 3: Connecting of -> importance
# Page 3: Connecting of -> testing
# Region 163: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting testing -> Immunotherapy
# Page 3: Connecting testing -> importance
# Page 3: Connecting testing -> of
# Page 3: Connecting testing -> and
# Page 3: Connecting testing -> vaccine
# Region 164: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> Immunotherapy
# Page 3: Connecting and -> testing
# Page 3: Connecting and -> vaccine
# Region 165: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting vaccine -> Immunotherapy
# Page 3: Connecting vaccine -> Center,
# Page 3: Connecting vaccine -> testing
# Page 3: Connecting vaccine -> and
# Region 166: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting research -> at
# Page 3: Connecting research -> the
# Region 167: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting at -> research
# Page 3: Connecting at -> the
# Page 3: Connecting at -> center.
# Region 168: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> research
# Page 3: Connecting the -> at
# Page 3: Connecting the -> center.
# Region 169: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting center. -> at
# Page 3: Connecting center. -> the
# Region 170: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting 2019 -> ANALOG
# Region 171: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting ANALOG -> 2019
# Page 3: Connecting ANALOG -> DEVICES
# Region 172: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting DEVICES -> ANALOG
# Page 3: Connecting DEVICES -> CORPORATE
# Region 173: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting CORPORATE -> DEVICES
# Page 3: Connecting CORPORATE -> RESPONSIBILITY
# Region 174: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting RESPONSIBILITY -> CORPORATE
# Page 3: Connecting RESPONSIBILITY -> REPORT
# Region 175: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting REPORT -> RESPONSIBILITY
# Region 176: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting Combined, -> these
# Page 3: Connecting Combined, -> commitment
# Region 177: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting these -> Combined,
# Page 3: Connecting these -> efforts
# Region 178: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting efforts -> these
# Page 3: Connecting efforts -> underscore
# Region 179: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting underscore -> efforts
# Page 3: Connecting underscore -> our
# Page 3: Connecting underscore -> shared
# Region 180: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting our -> underscore
# Page 3: Connecting our -> shared
# Region 181: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting shared -> underscore
# Page 3: Connecting shared -> our
# Page 3: Connecting shared -> purpose
# Region 182: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting purpose -> shared
# Page 3: Connecting purpose -> and
# Page 3: Connecting purpose -> citizens
# Page 3: Connecting purpose -> and
# Page 3: Connecting purpose -> testament
# Region 183: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> purpose
# Region 184: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting commitment -> Combined,
# Page 3: Connecting commitment -> to
# Page 3: Connecting commitment -> our
# Region 185: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> commitment
# Page 3: Connecting to -> our
# Page 3: Connecting to -> role
# Region 186: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting our -> commitment
# Page 3: Connecting our -> to
# Page 3: Connecting our -> role
# Page 3: Connecting our -> as
# Region 187: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting role -> to
# Page 3: Connecting role -> our
# Page 3: Connecting role -> as
# Page 3: Connecting role -> corporate
# Region 188: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting as -> our
# Page 3: Connecting as -> role
# Page 3: Connecting as -> corporate
# Region 189: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting corporate -> role
# Page 3: Connecting corporate -> as
# Page 3: Connecting corporate -> citizens
# Page 3: Connecting corporate -> achieve
# Page 3: Connecting corporate -> when
# Page 3: Connecting corporate -> align
# Page 3: Connecting corporate -> around
# Region 190: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting citizens -> purpose
# Page 3: Connecting citizens -> corporate
# Page 3: Connecting citizens -> and
# Page 3: Connecting citizens -> are
# Region 191: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting and -> purpose
# Page 3: Connecting and -> citizens
# Page 3: Connecting and -> are
# Page 3: Connecting and -> a
# Page 3: Connecting and -> testament
# Region 192: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting are -> citizens
# Page 3: Connecting are -> and
# Page 3: Connecting are -> a
# Page 3: Connecting are -> testament
# Region 193: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting a -> and
# Page 3: Connecting a -> are
# Page 3: Connecting a -> testament
# Region 194: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting testament -> purpose
# Page 3: Connecting testament -> and
# Page 3: Connecting testament -> are
# Page 3: Connecting testament -> a
# Region 195: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> what
# Page 3: Connecting to -> we
# Region 196: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting what -> to
# Page 3: Connecting what -> we
# Page 3: Connecting what -> can
# Region 197: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting we -> to
# Page 3: Connecting we -> what
# Page 3: Connecting we -> can
# Page 3: Connecting we -> achieve
# Region 198: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting can -> what
# Page 3: Connecting can -> we
# Page 3: Connecting can -> achieve
# Region 199: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting achieve -> corporate
# Page 3: Connecting achieve -> we
# Page 3: Connecting achieve -> can
# Page 3: Connecting achieve -> when
# Page 3: Connecting achieve -> we
# Region 200: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting when -> corporate
# Page 3: Connecting when -> achieve
# Page 3: Connecting when -> we
# Page 3: Connecting when -> align
# Region 201: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting we -> achieve
# Page 3: Connecting we -> when
# Page 3: Connecting we -> align
# Page 3: Connecting we -> around
# Region 202: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting align -> corporate
# Page 3: Connecting align -> when
# Page 3: Connecting align -> we
# Page 3: Connecting align -> around
# Region 203: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting around -> corporate
# Page 3: Connecting around -> we
# Page 3: Connecting around -> align
# Page 3: Connecting around -> solving
# Region 204: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting solving -> around
# Page 3: Connecting solving -> complex
# Region 205: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting complex -> solving
# Region 206: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting problems -> pandemic.
# Page 3: Connecting problems -> together.
# Region 207: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting together. -> problems
# Region 208: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting As -> pandemic.
# Page 3: Connecting As -> we
# Page 3: Connecting As -> look
# Region 209: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting we -> As
# Page 3: Connecting we -> look
# Page 3: Connecting we -> beyond
# Region 210: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting look -> As
# Page 3: Connecting look -> we
# Page 3: Connecting look -> beyond
# Region 211: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting beyond -> we
# Page 3: Connecting beyond -> look
# Page 3: Connecting beyond -> the
# Page 3: Connecting beyond -> immediate
# Page 3: Connecting beyond -> current
# Page 3: Connecting beyond -> environment,
# Region 212: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting the -> beyond
# Page 3: Connecting the -> immediate
# Region 213: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting immediate -> beyond
# Page 3: Connecting immediate -> the
# Page 3: Connecting immediate -> challenges
# Region 214: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting challenges -> immediate
# Page 3: Connecting challenges -> environment,
# Page 3: Connecting challenges -> believe
# Region 215: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting of -> our
# Page 3: Connecting of -> current
# Region 216: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting our -> of
# Page 3: Connecting our -> current
# Region 217: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting current -> beyond
# Page 3: Connecting current -> of
# Page 3: Connecting current -> our
# Page 3: Connecting current -> environment,
# Region 218: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting environment, -> beyond
# Page 3: Connecting environment, -> challenges
# Page 3: Connecting environment, -> current
# Page 3: Connecting environment, -> we
# Page 3: Connecting environment, -> believe
# Page 3: Connecting environment, -> much
# Page 3: Connecting environment, -> do
# Page 3: Connecting environment, -> leverage
# Region 219: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting we -> environment,
# Page 3: Connecting we -> believe
# Region 220: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting believe -> challenges
# Page 3: Connecting believe -> environment,
# Page 3: Connecting believe -> we
# Region 221: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting there -> is
# Page 3: Connecting there -> much
# Region 222: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting is -> there
# Page 3: Connecting is -> much
# Region 223: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting much -> environment,
# Page 3: Connecting much -> there
# Page 3: Connecting much -> is
# Page 3: Connecting much -> more
# Page 3: Connecting much -> we
# Region 224: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting more -> much
# Page 3: Connecting more -> we
# Page 3: Connecting more -> can
# Page 3: Connecting more -> a
# Region 225: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting we -> much
# Page 3: Connecting we -> more
# Page 3: Connecting we -> can
# Page 3: Connecting we -> do
# Page 3: Connecting we -> a
# Region 226: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting can -> more
# Page 3: Connecting can -> we
# Page 3: Connecting can -> do
# Page 3: Connecting can -> to
# Page 3: Connecting can -> leverage
# Page 3: Connecting can -> a
# Region 227: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting do -> environment,
# Page 3: Connecting do -> we
# Page 3: Connecting do -> can
# Page 3: Connecting do -> to
# Page 3: Connecting do -> leverage
# Page 3: Connecting do -> a
# Region 228: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting to -> can
# Page 3: Connecting to -> do
# Page 3: Connecting to -> leverage
# Region 229: [1806, 2191, 1879, 2235, 5, 'el=aa', 1]
# Page 3: Connecting leverage -> environment,
# Page 3: Connecting leverage -> can
# Page 3: Connecting leverage -> do
# ...
# Page 75: Connecting our -> talent
# Page 75: Connecting our -> of
# Page 75: Connecting our -> people
# Page 75: Connecting our -> committed
# Page 75: Connecting our -> to
# Page 75: Connecting our -> creating
# Region 416: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting people -> Pages
# Page 75: Connecting people -> 51-44
# Page 75: Connecting people -> of
# Page 75: Connecting people -> our
# Page 75: Connecting people -> is
# Page 75: Connecting people -> how
# Page 75: Connecting people -> committed
# Page 75: Connecting people -> to
# Page 75: Connecting people -> creating
# Page 75: Connecting people -> a
# Page 75: Connecting people -> culture
# Region 417: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting is -> 51-44
# Page 75: Connecting is -> people
# Page 75: Connecting is -> how
# Page 75: Connecting is -> we
# Page 75: Connecting is -> creating
# Page 75: Connecting is -> a
# Page 75: Connecting is -> culture
# Region 418: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting how -> 51-44
# Page 75: Connecting how -> people
# Page 75: Connecting how -> is
# Page 75: Connecting how -> we
# Page 75: Connecting how -> will
# Page 75: Connecting how -> creating
# Page 75: Connecting how -> a
# Page 75: Connecting how -> culture
# Page 75: Connecting how -> that
# Region 419: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting we -> is
# Page 75: Connecting we -> how
# Page 75: Connecting we -> will
# Page 75: Connecting we -> succeed
# Page 75: Connecting we -> a
# Page 75: Connecting we -> culture
# Page 75: Connecting we -> that
# Page 75: Connecting we -> invests
# Region 420: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting will -> how
# Page 75: Connecting will -> we
# Page 75: Connecting will -> succeed
# Page 75: Connecting will -> culture
# Page 75: Connecting will -> that
# Page 75: Connecting will -> invests
# Region 421: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting succeed -> we
# Page 75: Connecting succeed -> will
# Page 75: Connecting succeed -> as
# Page 75: Connecting succeed -> a
# Page 75: Connecting succeed -> company,
# Page 75: Connecting succeed -> culture
# Page 75: Connecting succeed -> that
# Page 75: Connecting succeed -> invests
# Page 75: Connecting succeed -> in
# Page 75: Connecting succeed -> our
# Page 75: Connecting succeed -> people,
# Region 422: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting as -> succeed
# Page 75: Connecting as -> a
# Page 75: Connecting as -> company,
# Page 75: Connecting as -> invests
# Page 75: Connecting as -> in
# Page 75: Connecting as -> our
# Page 75: Connecting as -> people,
# Region 423: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting a -> succeed
# Page 75: Connecting a -> as
# Page 75: Connecting a -> company,
# Page 75: Connecting a -> invests
# Page 75: Connecting a -> in
# Page 75: Connecting a -> our
# Page 75: Connecting a -> people,
# Region 424: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting company, -> succeed
# Page 75: Connecting company, -> as
# Page 75: Connecting company, -> a
# Page 75: Connecting company, -> which
# Page 75: Connecting company, -> invests
# Page 75: Connecting company, -> in
# Page 75: Connecting company, -> our
# Page 75: Connecting company, -> people,
# Region 425: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting which -> company,
# Page 75: Connecting which -> people,
# Region 426: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting is -> ADI
# Page 75: Connecting is -> believes
# Page 75: Connecting is -> why
# Page 75: Connecting is -> we
# Page 75: Connecting is -> is
# Page 75: Connecting is -> inclusive
# Region 427: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting why -> ADI
# Page 75: Connecting why -> believes
# Page 75: Connecting why -> is
# Page 75: Connecting why -> we
# Page 75: Connecting why -> are
# Page 75: Connecting why -> is
# Page 75: Connecting why -> inclusive
# Page 75: Connecting why -> and
# Region 428: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting we -> ADI
# Page 75: Connecting we -> believes
# Page 75: Connecting we -> the
# Page 75: Connecting we -> is
# Page 75: Connecting we -> why
# Page 75: Connecting we -> are
# Page 75: Connecting we -> committed
# Page 75: Connecting we -> is
# Page 75: Connecting we -> inclusive
# Page 75: Connecting we -> and
# Page 75: Connecting we -> treats
# Region 429: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting are -> believes
# Page 75: Connecting are -> the
# Page 75: Connecting are -> talent
# Page 75: Connecting are -> why
# Page 75: Connecting are -> we
# Page 75: Connecting are -> committed
# Page 75: Connecting are -> inclusive
# Page 75: Connecting are -> and
# Page 75: Connecting are -> treats
# Region 430: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting committed -> believes
# Page 75: Connecting committed -> the
# Page 75: Connecting committed -> talent
# Page 75: Connecting committed -> of
# Page 75: Connecting committed -> our
# Page 75: Connecting committed -> people
# Page 75: Connecting committed -> we
# Page 75: Connecting committed -> are
# Page 75: Connecting committed -> to
# Page 75: Connecting committed -> creating
# Page 75: Connecting committed -> inclusive
# Page 75: Connecting committed -> and
# Page 75: Connecting committed -> treats
# Page 75: Connecting committed -> employees
# Region 431: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting to -> talent
# Page 75: Connecting to -> of
# Page 75: Connecting to -> our
# Page 75: Connecting to -> people
# Page 75: Connecting to -> committed
# Page 75: Connecting to -> creating
# Page 75: Connecting to -> treats
# Page 75: Connecting to -> employees
# Page 75: Connecting to -> equitably
# Region 432: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting creating -> talent
# Page 75: Connecting creating -> of
# Page 75: Connecting creating -> our
# Page 75: Connecting creating -> people
# Page 75: Connecting creating -> is
# Page 75: Connecting creating -> how
# Page 75: Connecting creating -> committed
# Page 75: Connecting creating -> to
# Page 75: Connecting creating -> a
# Page 75: Connecting creating -> culture
# Page 75: Connecting creating -> treats
# Page 75: Connecting creating -> employees
# Page 75: Connecting creating -> equitably
# Region 433: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting a -> people
# Page 75: Connecting a -> is
# Page 75: Connecting a -> how
# Page 75: Connecting a -> we
# Page 75: Connecting a -> creating
# Page 75: Connecting a -> culture
# Page 75: Connecting a -> employees
# Page 75: Connecting a -> equitably
# Page 75: Connecting a -> and
# Region 434: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting culture -> people
# Page 75: Connecting culture -> is
# Page 75: Connecting culture -> how
# Page 75: Connecting culture -> we
# Page 75: Connecting culture -> will
# Page 75: Connecting culture -> succeed
# Page 75: Connecting culture -> creating
# Page 75: Connecting culture -> a
# Page 75: Connecting culture -> that
# Page 75: Connecting culture -> invests
# Page 75: Connecting culture -> employees
# Page 75: Connecting culture -> equitably
# Page 75: Connecting culture -> and
# Page 75: Connecting culture -> fairly.
# Region 435: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting that -> how
# Page 75: Connecting that -> we
# Page 75: Connecting that -> will
# Page 75: Connecting that -> succeed
# Page 75: Connecting that -> culture
# Page 75: Connecting that -> invests
# Page 75: Connecting that -> equitably
# Page 75: Connecting that -> and
# Page 75: Connecting that -> fairly.
# Region 436: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting invests -> we
# Page 75: Connecting invests -> will
# Page 75: Connecting invests -> succeed
# Page 75: Connecting invests -> as
# Page 75: Connecting invests -> a
# Page 75: Connecting invests -> company,
# Page 75: Connecting invests -> culture
# Page 75: Connecting invests -> that
# Page 75: Connecting invests -> in
# Page 75: Connecting invests -> our
# Page 75: Connecting invests -> and
# Page 75: Connecting invests -> fairly.
# Region 437: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting in -> succeed
# Page 75: Connecting in -> as
# Page 75: Connecting in -> a
# Page 75: Connecting in -> company,
# Page 75: Connecting in -> invests
# Page 75: Connecting in -> our
# Page 75: Connecting in -> people,
# Page 75: Connecting in -> fairly.
# Region 438: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting our -> succeed
# Page 75: Connecting our -> as
# Page 75: Connecting our -> a
# Page 75: Connecting our -> company,
# Page 75: Connecting our -> invests
# Page 75: Connecting our -> in
# Page 75: Connecting our -> people,
# Region 439: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting people, -> succeed
# Page 75: Connecting people, -> as
# Page 75: Connecting people, -> a
# Page 75: Connecting people, -> company,
# Page 75: Connecting people, -> which
# Page 75: Connecting people, -> in
# Page 75: Connecting people, -> our
# Region 440: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting is -> is
# Page 75: Connecting is -> why
# Page 75: Connecting is -> we
# Page 75: Connecting is -> inclusive
# Region 441: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting inclusive -> is
# Page 75: Connecting inclusive -> why
# Page 75: Connecting inclusive -> we
# Page 75: Connecting inclusive -> are
# Page 75: Connecting inclusive -> committed
# Page 75: Connecting inclusive -> is
# Page 75: Connecting inclusive -> and
# Page 75: Connecting inclusive -> treats
# Region 442: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting and -> why
# Page 75: Connecting and -> we
# Page 75: Connecting and -> are
# Page 75: Connecting and -> committed
# Page 75: Connecting and -> inclusive
# Page 75: Connecting and -> treats
# Region 443: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting treats -> we
# Page 75: Connecting treats -> are
# Page 75: Connecting treats -> committed
# Page 75: Connecting treats -> to
# Page 75: Connecting treats -> creating
# Page 75: Connecting treats -> inclusive
# Page 75: Connecting treats -> and
# Page 75: Connecting treats -> employees
# Region 444: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting employees -> committed
# Page 75: Connecting employees -> to
# Page 75: Connecting employees -> creating
# Page 75: Connecting employees -> a
# Page 75: Connecting employees -> culture
# Page 75: Connecting employees -> treats
# Page 75: Connecting employees -> equitably
# Region 445: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting equitably -> to
# Page 75: Connecting equitably -> creating
# Page 75: Connecting equitably -> a
# Page 75: Connecting equitably -> culture
# Page 75: Connecting equitably -> that
# Page 75: Connecting equitably -> employees
# Page 75: Connecting equitably -> and
# Page 75: Connecting equitably -> fairly.
# Region 446: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting and -> a
# Page 75: Connecting and -> culture
# Page 75: Connecting and -> that
# Page 75: Connecting and -> invests
# Page 75: Connecting and -> equitably
# Page 75: Connecting and -> fairly.
# Region 447: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting fairly. -> culture
# Page 75: Connecting fairly. -> that
# Page 75: Connecting fairly. -> invests
# Page 75: Connecting fairly. -> in
# Page 75: Connecting fairly. -> equitably
# Page 75: Connecting fairly. -> and
# Region 448: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting Support -> Boosting
# Page 75: Connecting Support -> Biodiversity
# Page 75: Connecting Support -> for
# Page 75: Connecting Support -> biodiversity
# Page 75: Connecting Support -> local
# Page 75: Connecting Support -> communities.
# Region 449: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting for -> Boosting
# Page 75: Connecting for -> Biodiversity
# Page 75: Connecting for -> Support
# Page 75: Connecting for -> biodiversity
# Page 75: Connecting for -> local
# Page 75: Connecting for -> communities.
# Region 450: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting biodiversity -> Boosting
# Page 75: Connecting biodiversity -> Biodiversity
# Page 75: Connecting biodiversity -> Page
# Page 75: Connecting biodiversity -> 51
# Page 75: Connecting biodiversity -> Support
# Page 75: Connecting biodiversity -> for
# Page 75: Connecting biodiversity -> conservation
# Page 75: Connecting biodiversity -> communities.
# Region 451: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting conservation -> Biodiversity
# Page 75: Connecting conservation -> Page
# Page 75: Connecting conservation -> 51
# Page 75: Connecting conservation -> biodiversity
# Page 75: Connecting conservation -> programs
# Page 75: Connecting conservation -> communities.
# Region 452: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting programs -> conservation
# Page 75: Connecting programs -> at
# Page 75: Connecting programs -> our
# Page 75: Connecting programs -> facilities
# Region 453: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting at -> programs
# Page 75: Connecting at -> our
# Page 75: Connecting at -> facilities
# Region 454: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting our -> programs
# Page 75: Connecting our -> at
# Page 75: Connecting our -> facilities
# Region 455: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting facilities -> programs
# Page 75: Connecting facilities -> at
# Page 75: Connecting facilities -> our
# Page 75: Connecting facilities -> and
# Page 75: Connecting facilities -> in
# Region 456: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting and -> facilities
# Page 75: Connecting and -> in
# Page 75: Connecting and -> our
# Region 457: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting in -> facilities
# Page 75: Connecting in -> and
# Page 75: Connecting in -> our
# Region 458: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting our -> and
# Page 75: Connecting our -> in
# Region 459: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting local -> Support
# Page 75: Connecting local -> for
# Page 75: Connecting local -> communities.
# Region 460: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting communities. -> Support
# Page 75: Connecting communities. -> for
# Page 75: Connecting communities. -> biodiversity
# Page 75: Connecting communities. -> conservation
# Page 75: Connecting communities. -> local
# Region 461: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting rt -> peeeitatend
# Region 462: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting 2019 -> ANALOG
# Region 463: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting ANALOG -> 2019
# Page 75: Connecting ANALOG -> DEVICES
# Region 464: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting DEVICES -> ANALOG
# Page 75: Connecting DEVICES -> CORPORATE
# Region 465: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting CORPORATE -> DEVICES
# Page 75: Connecting CORPORATE -> RESPONSIBILITY
# Region 466: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting RESPONSIBILITY -> CORPORATE
# Page 75: Connecting RESPONSIBILITY -> REPORT
# Region 467: [3119, 2410, 3148, 2433, 2, '75', 1]
# Page 75: Connecting REPORT -> RESPONSIBILITY
# Region 468: [3119, 2410, 3148, 2433, 2, '75', 1]
# Starting BFS from: > at 150, 387
# Merging > at 150, 387
# Starting BFS from: Analog at 259, 678
# Merging Analog at 259, 678
# Starting BFS from: yore at 197, 844
# Merging yore at 197, 844
# Starting BFS from: Improving at 1958, 848
# Merging Improving at 1958, 848
# Starting BFS from: 1[i4- at 1726, 1132
# Merging 1[i4- at 1726, 1132
# Starting BFS from: Diversity at 1958, 1132
# Merging Diversity at 1958, 1132
# Starting BFS from: macorel at 194, 1235
# Merging macorel at 194, 1235
# Starting BFS from: Impact at 392, 1240
# Merging Impact at 392, 1240
# Starting BFS from: lass at 1776, 1509
# Merging lass at 1776, 1509
# Starting BFS from: ppt at 197, 1527
# Merging ppt at 197, 1527
# Starting BFS from: Protecting at 392, 1531
# Merging Protecting at 392, 1531
# Starting BFS from: parncg at 191, 1819
# Merging parncg at 191, 1819
# Starting BFS from: 1K at 1726, 1854
# Merging 1K at 1726, 1854
# Starting BFS from: peeeitatend at 196, 2134
# Merging peeeitatend at 196, 2134
# Starting BFS from: Vth at 1726, 2138
# Merging Vth at 1726, 2138
# Starting BFS from: Boosting at 1958, 2138
# Merging Boosting at 1958, 2138
# Starting BFS from: 2019 at 152, 2409
# Merging 2019 at 152, 2409
# Starting BFS from: 75 at 3119, 2410
# Merging 75 at 3119, 2410
#
# --- Processing Page 76 ---
#
# --- Processing Page 77 ---

# %%
# # read second_round.json file
# second_round  = json.load(open('C:/Users/r12725056/anaconda3/Master/Greenwashing/CSR_report_processed/NASDAQ/second_round/second_round.json', 'r'))
# for i in range(0, 5):
#     pdf_name = second_round[i]
#     pdf_path = f'../CSR Reporting/NASDAQ/{pdf_name}.pdf'
#     output_image_path = f'../CSR_report_processed_v3/NASDAQ/{pdf_name}/{pdf_name}_v3'
#     if not os.path.exists(output_image_path):
#         os.makedirs(output_image_path)
#     process_pdf(pdf_path, output_image_path, density_threshold=15)
#     print(f"Processed {pdf_name} successfully")
