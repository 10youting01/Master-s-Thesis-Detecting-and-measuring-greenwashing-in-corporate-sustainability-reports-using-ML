# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = "/usr/bin/tesseract"
from pdf2image import convert_from_path
from PIL import Image, ImageDraw
import numpy as np
import json
import os
from statistics import quantiles

# %%
pdf_path = "../CSR Reporting/NASDAQ/NASDAQ_TEAM_2021.pdf"  # 替換為您的 PDF 路徑
output_image_path = "../CSR_report_processed_v3/NASDAQ/NASDAQ_TEAM_2021_old"
output_file_path = "../CSR_report_processed_v3/NASDAQ/NASDAQ_TEAM_2021_old/NASDAQ_TEAM_2021_old.json"

# %%
def process_pdf(pdf_path, output_image_path, density_threshold=15):
    if not os.path.exists(output_image_path):
        os.makedirs(output_image_path)
    # 轉換 PDF 頁面為圖片
    pages = convert_from_path(pdf_path, dpi=300)
    all_dense_regions = []
    all_region_data = []

    for page_i, page_image in enumerate(pages):
        print(f"\n--- Processing Page {page_i + 1} ---")

        # OCR 文字區塊提取
        data = pytesseract.image_to_data(page_image, output_type=pytesseract.Output.DICT)

        if len(data['text']) < 300:
            continue

        valid_indices = [i for i in range(len(data['text'])) if data['text'][i].strip()]

        if not valid_indices:
            print(f"Page {page_i + 1}: No valid text found.")
            continue

        # 計算平均寬度與高度作為閾值
        def trimmed_mean(values, trim_ratio=0.25):
            sorted_values = np.sort(values)
            trim_count = int(len(sorted_values) * trim_ratio)
            trimmed_values = sorted_values[:trim_count]
            return np.mean(trimmed_values) if len(trimmed_values) > 0 else 0

        non_zero_widths = [data['width'][i] for i in valid_indices if data['width'][i] > 0]

        average_width = trimmed_mean(non_zero_widths)
        average_height = sum(data['height'][i] for i in valid_indices) / len(valid_indices)

        # 設定合併閾值
        horizontal_threshold = int(average_width)
        vertical_threshold = int(average_height)

        print(f"Avg Width: {average_width}, Avg Height: {average_height}")
        print(f"Horizontal Threshold: {horizontal_threshold}, Vertical Threshold: {vertical_threshold}")

        # **建立所有文字區塊**
        region_candidates = []
        for i in valid_indices:
            x, y, w, h = data['left'][i], data['top'][i], data['width'][i], data['height'][i]
            text = data['text'][i].strip()
            text_length = len(text)
            region_candidates.append([x, y, x + w, y + h, text_length, text, 1])  # 1 代表這個區塊內的文字數量

        # 記錄所有的文字區塊資訊
        region_data = []
        for region in region_candidates:
            region_data.append({
                "page": page_i + 1,
                "x1": region[0], "y1": region[1],
                "x2": region[2], "y2": region[3],
                "width": region[2] - region[0],
                "height": region[3] - region[1],
                "text_length": region[4],
                "text": region[5],
                "text_num": region[6]
            })

        all_region_data.extend(region_data)

        # **建立區塊關係圖**
        adjacency_list = {i: [] for i in range(len(region_candidates))}

        # 檢查所有文字區塊是否相連
        for i, region1 in enumerate(region_candidates):
            x1, y1, x2, y2, _, _, _ = region1

            for j, region2 in enumerate(region_candidates):
                if i != j:
                    x1b, y1b, x2b, y2b, _, _, _ = region2

                    # 判斷兩個區塊是否可以合併
                    horizontally_close = abs(x1 - x2b) <= horizontal_threshold or abs(x1b - x2) <= horizontal_threshold
                    vertically_close = abs(y1 - y2b) <= vertical_threshold or abs(y1b - y2) <= vertical_threshold
                    overlap_vertically = not (y1 > y2b or y2 < y1b)
                    overlap_horizontally = not (x1 > x2b or x2 < x1b)

                    if (horizontally_close or overlap_horizontally) and (vertically_close or overlap_vertically):
                        adjacency_list[i].append(j)
                        print(f"Page {page_i + 1}: Connecting {region1[5]} -> {region2[5]}")  # 🔥 Debug 這行

        # **合併區塊**
        visited = set()
        merged_regions = []

        def merge_connected_regions(start_idx):
            """ 使用 BFS 來合併所有相連區塊 """
            queue = [start_idx]
            merged_region = list(region_candidates[start_idx])  # 複製初始區塊資訊
            visited.add(start_idx)
            print(f"Merging {region_candidates[start_idx][5]} at {region_candidates[start_idx][0]}, {region_candidates[start_idx][1]}")

            while queue:
                idx = queue.pop(0)
                for neighbor_idx in adjacency_list[idx]:
                    if neighbor_idx not in visited:
                        visited.add(neighbor_idx)
                        queue.append(neighbor_idx)
                        
                        # 合併區塊
                        x1b, y1b, x2b, y2b, text_length, text, text_num = region_candidates[neighbor_idx]
                        merged_region[0] = min(merged_region[0], x1b)
                        merged_region[1] = min(merged_region[1], y1b)
                        merged_region[2] = max(merged_region[2], x2b)
                        merged_region[3] = max(merged_region[3], y2b)
                        merged_region[4] += text_length
                        merged_region[5] += " " + text
                        merged_region[6] += text_num

            return merged_region

        # 執行合併
        for i in range(len(region_candidates)):
            if i not in visited:
                merged_region = merge_connected_regions(i)
                merged_regions.append(merged_region)

        # **篩選高密度區域**
        dense_regions = []
        for region in merged_regions:
            x1, y1, x2, y2, total_text_length, all_text, total_text_num = region
            if total_text_num > density_threshold:
                width = x2 - x1
                height = y2 - y1
                area = width * height
                text_density = total_text_length / area if area > 0 else 0

                if text_density >= 0.0001:
                    dense_regions.append({
                        "page": page_i + 1,
                        "x1": x1, "y1": y1, "x2": x2, "y2": y2,
                        "width": width, "height": height, "area": area,
                        "total_text_length": total_text_length,
                        "text_density": text_density,
                        "all_text": all_text.strip(),
                        "text_num": total_text_num
                    })

        all_dense_regions.extend(dense_regions)

        # **繪製紅色邊框標註區域**
        draw = ImageDraw.Draw(page_image)
        for region in dense_regions:
            x1, y1, x2, y2 = region["x1"], region["y1"], region["x2"], region["y2"]
            draw.rectangle([x1, y1, x2, y2], outline="red", width=2)

        page_image.save(f'{output_image_path}/page_{page_i + 1}.jpg')

    # **輸出 JSON**
    with open(f'{output_image_path}/dense_regions.json', 'w') as json_file:
        json.dump(all_dense_regions, json_file, indent=4)

# %%
process_pdf(pdf_path, output_image_path, density_threshold=15)
# Out:
# --- Processing Page 1 ---
#
# --- Processing Page 2 ---
#
# --- Processing Page 3 ---
# Avg Width: 31.027272727272727, Avg Height: 25.490909090909092
# Horizontal Threshold: 31, Vertical Threshold: 25
# Page 3: Connecting It’s -> not
# Page 3: Connecting not -> It’s
# Page 3: Connecting not -> just
# Page 3: Connecting just -> not
# Page 3: Connecting just -> about
# Page 3: Connecting just -> critical
# Page 3: Connecting just -> the
# Page 3: Connecting about -> just
# Page 3: Connecting about -> “doing
# Page 3: Connecting “doing -> about
# Page 3: Connecting “doing -> the
# Page 3: Connecting “doing -> long-term
# Page 3: Connecting the -> “doing
# Page 3: Connecting the -> right
# Page 3: Connecting right -> the
# Page 3: Connecting right -> thing.”
# Page 3: Connecting right -> of
# Page 3: Connecting thing.” -> right
# Page 3: Connecting thing.” -> Investing
# Page 3: Connecting thing.” -> of
# Page 3: Connecting thing.” -> business.
# Page 3: Connecting Investing -> thing.”
# Page 3: Connecting Investing -> in
# Page 3: Connecting Investing -> business.
# Page 3: Connecting in -> Investing
# Page 3: Connecting in -> sustainability
# Page 3: Connecting sustainability -> in
# Page 3: Connecting is -> critical
# Page 3: Connecting critical -> just
# Page 3: Connecting critical -> is
# Page 3: Connecting critical -> to
# Page 3: Connecting to -> critical
# Page 3: Connecting to -> the
# Page 3: Connecting the -> just
# Page 3: Connecting the -> to
# Page 3: Connecting the -> long-term
# Page 3: Connecting long-term -> “doing
# Page 3: Connecting long-term -> the
# Page 3: Connecting long-term -> success
# Page 3: Connecting success -> long-term
# Page 3: Connecting success -> of
# Page 3: Connecting of -> right
# Page 3: Connecting of -> thing.”
# Page 3: Connecting of -> success
# Page 3: Connecting of -> our
# Page 3: Connecting our -> of
# Page 3: Connecting our -> business.
# Page 3: Connecting business. -> thing.”
# Page 3: Connecting business. -> Investing
# Page 3: Connecting business. -> our
# Page 3: Connecting Doing -> well
# Page 3: Connecting well -> Doing
# Page 3: Connecting well -> as
# Page 3: Connecting as -> well
# Page 3: Connecting as -> a
# Page 3: Connecting a -> as
# Page 3: Connecting a -> company
# Page 3: Connecting company -> a
# Page 3: Connecting company -> and
# Page 3: Connecting and -> company
# Page 3: Connecting and -> doing
# Page 3: Connecting doing -> and
# Page 3: Connecting doing -> good
# Page 3: Connecting good -> doing
# Page 3: Connecting good -> as
# Page 3: Connecting as -> good
# Page 3: Connecting as -> citizens
# Page 3: Connecting citizens -> as
# Page 3: Connecting citizens -> of
# Page 3: Connecting of -> citizens
# Page 3: Connecting of -> the
# Page 3: Connecting the -> of
# Page 3: Connecting the -> world
# Page 3: Connecting world -> the
# Page 3: Connecting world -> are
# Page 3: Connecting are -> world
# Page 3: Connecting are -> not
# Page 3: Connecting not -> are
# Page 3: Connecting not -> mutually
# Page 3: Connecting mutually -> not
# Page 3: Connecting exclusive. -> In
# Page 3: Connecting In -> exclusive.
# Page 3: Connecting In -> fact,
# Page 3: Connecting fact, -> In
# Page 3: Connecting fact, -> this
# Page 3: Connecting this -> fact,
# Page 3: Connecting this -> is
# Page 3: Connecting is -> this
# Page 3: Connecting is -> what
# Page 3: Connecting what -> is
# Page 3: Connecting what -> creates
# Page 3: Connecting creates -> what
# Page 3: Connecting creates -> and
# Page 3: Connecting and -> creates
# Page 3: Connecting and -> sustains
# Page 3: Connecting sustains -> and
# Page 3: Connecting sustains -> a
# Page 3: Connecting a -> sustains
# Page 3: Connecting a -> thriving
# Page 3: Connecting thriving -> a
# Page 3: Connecting thriving -> ecosystem
# Page 3: Connecting ecosystem -> thriving
# Page 3: Connecting ecosystem -> over
# Page 3: Connecting over -> ecosystem
# Page 3: Connecting over -> the
# Page 3: Connecting the -> over
# Page 3: Connecting the -> long
# Page 3: Connecting long -> the
# Page 3: Connecting long -> term.
# Page 3: Connecting term. -> long
# Page 3: Connecting We -> have
# Page 3: Connecting have -> We
# Page 3: Connecting have -> always
# Page 3: Connecting always -> have
# Page 3: Connecting always -> aimed
# Page 3: Connecting aimed -> always
# Page 3: Connecting aimed -> to
# Page 3: Connecting to -> aimed
# Page 3: Connecting to -> integrate
# Page 3: Connecting integrate -> to
# Page 3: Connecting integrate -> social
# Page 3: Connecting social -> integrate
# Page 3: Connecting social -> and
# Page 3: Connecting and -> social
# Page 3: Connecting and -> environmental
# Page 3: Connecting environmental -> and
# Page 3: Connecting environmental -> progress
# Page 3: Connecting progress -> environmental
# Page 3: Connecting progress -> into
# Page 3: Connecting into -> progress
# Page 3: Connecting into -> everything
# Page 3: Connecting everything -> into
# Page 3: Connecting Atlassian -> does
# Page 3: Connecting does -> Atlassian
# Page 3: Connecting does -> -
# Page 3: Connecting - -> does
# Page 3: Connecting - -> from
# Page 3: Connecting from -> -
# Page 3: Connecting from -> investing
# Page 3: Connecting investing -> from
# Page 3: Connecting investing -> in
# Page 3: Connecting in -> investing
# Page 3: Connecting in -> our
# Page 3: Connecting our -> in
# Page 3: Connecting our -> people,
# Page 3: Connecting people, -> our
# Page 3: Connecting people, -> to
# Page 3: Connecting to -> people,
# Page 3: Connecting to -> protecting
# Page 3: Connecting protecting -> to
# Page 3: Connecting protecting -> the
# Page 3: Connecting the -> protecting
# Page 3: Connecting the -> rights
# Page 3: Connecting rights -> the
# Page 3: Connecting rights -> of
# Page 3: Connecting of -> rights
# Page 3: Connecting of -> our
# Page 3: Connecting our -> of
# Page 3: Connecting our -> customers,
# Page 3: Connecting customers, -> our
# Page 3: Connecting to -> engaging
# Page 3: Connecting engaging -> to
# Page 3: Connecting engaging -> with
# Page 3: Connecting with -> engaging
# Page 3: Connecting with -> our
# Page 3: Connecting our -> with
# Page 3: Connecting our -> communities
# Page 3: Connecting communities -> our
# Page 3: Connecting communities -> through
# Page 3: Connecting through -> communities
# Page 3: Connecting through -> the
# Page 3: Connecting the -> through
# Page 3: Connecting the -> Atlassian
# Page 3: Connecting Atlassian -> the
# Page 3: Connecting Atlassian -> Foundation,
# Page 3: Connecting Foundation, -> Atlassian
# Page 3: Connecting Foundation, -> and
# Page 3: Connecting and -> Foundation,
# Page 3: Connecting and -> addressing
# Page 3: Connecting addressing -> and
# Page 3: Connecting climate -> threats.
# Page 3: Connecting threats. -> climate
# Page 3: Connecting Now -> we
# Page 3: Connecting we -> Now
# Page 3: Connecting we -> have
# Page 3: Connecting have -> we
# Page 3: Connecting have -> yet
# Page 3: Connecting yet -> have
# Page 3: Connecting yet -> another
# Page 3: Connecting another -> yet
# Page 3: Connecting another -> reason
# Page 3: Connecting reason -> another
# Page 3: Connecting reason -> to
# Page 3: Connecting to -> reason
# Page 3: Connecting to -> lean
# Page 3: Connecting lean -> to
# Page 3: Connecting lean -> into
# Page 3: Connecting into -> lean
# Page 3: Connecting into -> sustainability:
# Page 3: Connecting sustainability: -> into
# Page 3: Connecting sustainability: -> people.
# Page 3: Connecting people. -> sustainability:
# Page 3: Connecting people. -> Atlassian’s
# Page 3: Connecting Atlassian’s -> people.
# Page 3: Connecting Atlassian’s -> recent
# Page 3: Connecting recent -> Atlassian’s
# Page 3: Connecting Return -> on
# Page 3: Connecting on -> Return
# Page 3: Connecting on -> Action
# Page 3: Connecting Action -> on
# Page 3: Connecting Action -> Report
# Page 3: Connecting Report -> Action
# Page 3: Connecting Report -> revealed
# Page 3: Connecting revealed -> Report
# Page 3: Connecting revealed -> that
# Page 3: Connecting that -> revealed
# Page 3: Connecting that -> values
# Page 3: Connecting values -> that
# Page 3: Connecting values -> alignment
# Page 3: Connecting alignment -> values
# Page 3: Connecting alignment -> between
# Page 3: Connecting between -> alignment
# Page 3: Connecting between -> employers
# Page 3: Connecting employers -> between
# Page 3: Connecting employers -> and
# Page 3: Connecting and -> employers
# Page 3: Connecting and -> their
# Page 3: Connecting their -> and
# Page 3: Connecting employees -> matters
# Page 3: Connecting matters -> employees
# Page 3: Connecting matters -> more
# Page 3: Connecting more -> matters
# Page 3: Connecting more -> than
# Page 3: Connecting than -> more
# Page 3: Connecting than -> ever.
# Page 3: Connecting ever. -> than
# Page 3: Connecting ever. -> In
# Page 3: Connecting In -> ever.
# Page 3: Connecting In -> fact,
# Page 3: Connecting fact, -> In
# Page 3: Connecting fact, -> well
# Page 3: Connecting well -> fact,
# Page 3: Connecting well -> over
# Page 3: Connecting over -> well
# Page 3: Connecting over -> a
# Page 3: Connecting a -> over
# Page 3: Connecting a -> third
# Page 3: Connecting third -> a
# Page 3: Connecting third -> of
# Page 3: Connecting of -> third
# Page 3: Connecting of -> Millennial
# Page 3: Connecting Millennial -> of
# Page 3: Connecting Millennial -> workers
# Page 3: Connecting workers -> Millennial
# Page 3: Connecting (the -> largest
# Page 3: Connecting largest -> (the
# Page 3: Connecting largest -> generational
# Page 3: Connecting generational -> largest
# Page 3: Connecting generational -> cohort
# Page 3: Connecting cohort -> generational
# Page 3: Connecting cohort -> in
# Page 3: Connecting in -> cohort
# Page 3: Connecting in -> today’s
# Page 3: Connecting today’s -> in
# Page 3: Connecting today’s -> workforce)
# Page 3: Connecting workforce) -> today’s
# Page 3: Connecting workforce) -> went
# Page 3: Connecting went -> workforce)
# Page 3: Connecting went -> on
# Page 3: Connecting on -> went
# Page 3: Connecting on -> to
# Page 3: Connecting to -> on
# Page 3: Connecting to -> say
# Page 3: Connecting say -> to
# Page 3: Connecting say -> they
# Page 3: Connecting they -> say
# Page 3: Connecting they -> would
# Page 3: Connecting would -> they
# Page 3: Connecting would -> quit
# Page 3: Connecting quit -> would
# Page 3: Connecting quit -> their
# Page 3: Connecting their -> quit
# Page 3: Connecting jobs -> if
# Page 3: Connecting if -> jobs
# Page 3: Connecting if -> it
# Page 3: Connecting it -> if
# Page 3: Connecting it -> became
# Page 3: Connecting became -> it
# Page 3: Connecting became -> clear
# Page 3: Connecting clear -> became
# Page 3: Connecting clear -> that
# Page 3: Connecting that -> clear
# Page 3: Connecting that -> their
# Page 3: Connecting their -> that
# Page 3: Connecting their -> employers’
# Page 3: Connecting employers’ -> their
# Page 3: Connecting employers’ -> values
# Page 3: Connecting values -> employers’
# Page 3: Connecting values -> did
# Page 3: Connecting did -> values
# Page 3: Connecting did -> not
# Page 3: Connecting not -> did
# Page 3: Connecting not -> align
# Page 3: Connecting align -> not
# Page 3: Connecting align -> with
# Page 3: Connecting with -> align
# Page 3: Connecting with -> their
# Page 3: Connecting their -> with
# Page 3: Connecting their -> own.
# Page 3: Connecting own. -> their
# Page 3: Connecting But -> it’s
# Page 3: Connecting it’s -> But
# Page 3: Connecting it’s -> not
# Page 3: Connecting not -> it’s
# Page 3: Connecting not -> just
# Page 3: Connecting just -> not
# Page 3: Connecting just -> about
# Page 3: Connecting about -> just
# Page 3: Connecting about -> attracting
# Page 3: Connecting attracting -> about
# Page 3: Connecting attracting -> and
# Page 3: Connecting and -> attracting
# Page 3: Connecting and -> retaining
# Page 3: Connecting retaining -> and
# Page 3: Connecting retaining -> talent.
# Page 3: Connecting talent. -> retaining
# Page 3: Connecting talent. -> It’s
# Page 3: Connecting It’s -> talent.
# Page 3: Connecting It’s -> about
# Page 3: Connecting about -> It’s
# Page 3: Connecting about -> earning
# Page 3: Connecting earning -> about
# Page 3: Connecting earning -> the
# Page 3: Connecting the -> earning
# Page 3: Connecting the -> trust
# Page 3: Connecting trust -> the
# Page 3: Connecting trust -> of
# Page 3: Connecting of -> trust
# Page 3: Connecting of -> current
# Page 3: Connecting current -> of
# Page 3: Connecting and -> prospective
# Page 3: Connecting prospective -> and
# Page 3: Connecting prospective -> customers,
# Page 3: Connecting customers, -> prospective
# Page 3: Connecting customers, -> too
# Page 3: Connecting too -> customers,
# Page 3: Connecting too -> -
# Page 3: Connecting - -> too
# Page 3: Connecting - -> and
# Page 3: Connecting and -> -
# Page 3: Connecting and -> they’ve
# Page 3: Connecting they’ve -> and
# Page 3: Connecting they’ve -> told
# Page 3: Connecting told -> they’ve
# Page 3: Connecting told -> us
# Page 3: Connecting us -> told
# Page 3: Connecting us -> that
# Page 3: Connecting that -> us
# Page 3: Connecting that -> our
# Page 3: Connecting our -> that
# Page 3: Connecting our -> attitudes
# Page 3: Connecting attitudes -> our
# Page 3: Connecting attitudes -> and
# Page 3: Connecting and -> attitudes
# Page 3: Connecting and -> actions
# Page 3: Connecting actions -> and
# Page 3: Connecting actions -> around
# Page 3: Connecting around -> actions
# Page 3: Connecting sustainable -> practices
# Page 3: Connecting practices -> sustainable
# Page 3: Connecting practices -> matter
# Page 3: Connecting matter -> practices
# Page 3: Connecting matter -> to
# Page 3: Connecting to -> matter
# Page 3: Connecting to -> them.
# Page 3: Connecting them. -> to
# Page 3: Connecting When -> it
# Page 3: Connecting it -> When
# Page 3: Connecting it -> comes
# Page 3: Connecting comes -> it
# Page 3: Connecting comes -> to
# Page 3: Connecting to -> comes
# Page 3: Connecting to -> taking
# Page 3: Connecting taking -> to
# Page 3: Connecting taking -> action,
# Page 3: Connecting action, -> taking
# Page 3: Connecting action, -> Atlassian
# Page 3: Connecting Atlassian -> action,
# Page 3: Connecting Atlassian -> plays
# Page 3: Connecting plays -> Atlassian
# Page 3: Connecting plays -> the
# Page 3: Connecting the -> plays
# Page 3: Connecting the -> full
# Page 3: Connecting full -> the
# Page 3: Connecting full -> court.
# Page 3: Connecting court. -> full
# Page 3: Connecting court. -> In
# Page 3: Connecting In -> court.
# Page 3: Connecting In -> fiscal
# Page 3: Connecting fiscal -> In
# Page 3: Connecting fiscal -> year
# Page 3: Connecting year -> fiscal
# Page 3: Connecting year -> 2020,
# Page 3: Connecting 2020, -> year
# Page 3: Connecting 2020, -> we
# Page 3: Connecting we -> 2020,
# Page 3: Connecting reached -> our
# Page 3: Connecting our -> reached
# Page 3: Connecting our -> goal
# Page 3: Connecting goal -> our
# Page 3: Connecting goal -> of
# Page 3: Connecting of -> goal
# Page 3: Connecting of -> operating
# Page 3: Connecting operating -> of
# Page 3: Connecting operating -> exclusively
# Page 3: Connecting exclusively -> operating
# Page 3: Connecting exclusively -> on
# Page 3: Connecting on -> exclusively
# Page 3: Connecting on -> renewable
# Page 3: Connecting renewable -> on
# Page 3: Connecting renewable -> electricity,
# Page 3: Connecting electricity, -> renewable
# Page 3: Connecting electricity, -> completed
# Page 3: Connecting completed -> electricity,
# Page 3: Connecting completed -> a
# Page 3: Connecting a -> completed
# Page 3: Connecting a -> human
# Page 3: Connecting human -> a
# Page 3: Connecting rights -> assessment,
# Page 3: Connecting assessment, -> rights
# Page 3: Connecting assessment, -> and
# Page 3: Connecting and -> assessment,
# Page 3: Connecting and -> rallied
# Page 3: Connecting rallied -> and
# Page 3: Connecting rallied -> nearly
# Page 3: Connecting nearly -> rallied
# Page 3: Connecting nearly -> 70%
# Page 3: Connecting 70% -> nearly
# Page 3: Connecting 70% -> of
# Page 3: Connecting of -> 70%
# Page 3: Connecting of -> Atlassians
# Page 3: Connecting Atlassians -> of
# Page 3: Connecting Atlassians -> to
# Page 3: Connecting to -> Atlassians
# Page 3: Connecting to -> volunteer
# Page 3: Connecting volunteer -> to
# Page 3: Connecting volunteer -> with
# Page 3: Connecting with -> volunteer
# Page 3: Connecting with -> non-profit
# Page 3: Connecting non-profit -> with
# Page 3: Connecting organizations. -> This
# Page 3: Connecting This -> organizations.
# Page 3: Connecting This -> year,
# Page 3: Connecting year, -> This
# Page 3: Connecting year, -> we
# Page 3: Connecting we -> year,
# Page 3: Connecting we -> built
# Page 3: Connecting built -> we
# Page 3: Connecting built -> on
# Page 3: Connecting on -> built
# Page 3: Connecting on -> that
# Page 3: Connecting that -> on
# Page 3: Connecting that -> with
# Page 3: Connecting with -> that
# Page 3: Connecting with -> an
# Page 3: Connecting an -> with
# Page 3: Connecting an -> increasingly
# Page 3: Connecting increasingly -> an
# Page 3: Connecting increasingly -> data-driven
# Page 3: Connecting data-driven -> increasingly
# Page 3: Connecting data-driven -> approach
# Page 3: Connecting approach -> data-driven
# Page 3: Connecting approach -> to
# Page 3: Connecting to -> approach
# Page 3: Connecting climate -> mitigation,
# Page 3: Connecting mitigation, -> climate
# Page 3: Connecting mitigation, -> steps
# Page 3: Connecting steps -> mitigation,
# Page 3: Connecting steps -> to
# Page 3: Connecting to -> steps
# Page 3: Connecting to -> integrate
# Page 3: Connecting integrate -> to
# Page 3: Connecting integrate -> human
# Page 3: Connecting human -> integrate
# Page 3: Connecting human -> rights
# Page 3: Connecting rights -> human
# Page 3: Connecting rights -> within
# Page 3: Connecting within -> rights
# Page 3: Connecting within -> Atlassian,
# Page 3: Connecting Atlassian, -> within
# Page 3: Connecting Atlassian, -> and
# Page 3: Connecting and -> Atlassian,
# Page 3: Connecting and -> a
# Page 3: Connecting a -> and
# Page 3: Connecting a -> full
# Page 3: Connecting full -> a
# Page 3: Connecting full -> 10-point
# Page 3: Connecting 10-point -> full
# Page 3: Connecting increase -> in
# Page 3: Connecting in -> increase
# Page 3: Connecting in -> volunteer
# Page 3: Connecting volunteer -> in
# Page 3: Connecting volunteer -> participation.
# Page 3: Connecting participation. -> volunteer
# Page 3: Connecting That’s -> not
# Page 3: Connecting not -> That’s
# Page 3: Connecting not -> to
# Page 3: Connecting to -> not
# Page 3: Connecting to -> say
# Page 3: Connecting say -> to
# Page 3: Connecting say -> we’re
# Page 3: Connecting we’re -> say
# Page 3: Connecting we’re -> nailing
# Page 3: Connecting nailing -> we’re
# Page 3: Connecting nailing -> it
# Page 3: Connecting it -> nailing
# Page 3: Connecting it -> on
# Page 3: Connecting on -> it
# Page 3: Connecting on -> all
# Page 3: Connecting all -> on
# Page 3: Connecting all -> fronts.
# Page 3: Connecting fronts. -> all
# Page 3: Connecting fronts. -> As
# Page 3: Connecting As -> fronts.
# Page 3: Connecting As -> we
# Page 3: Connecting we -> As
# Page 3: Connecting we -> mentioned
# Page 3: Connecting mentioned -> we
# Page 3: Connecting mentioned -> in
# Page 3: Connecting in -> mentioned
# Page 3: Connecting in -> the
# Page 3: Connecting the -> in
# Page 3: Connecting the -> last
# Page 3: Connecting last -> the
# Page 3: Connecting last -> report,
# Page 3: Connecting report, -> last
# Page 3: Connecting report, -> we
# Page 3: Connecting we -> report,
# Page 3: Connecting we -> still
# Page 3: Connecting still -> we
# Page 3: Connecting have -> lots
# Page 3: Connecting lots -> have
# Page 3: Connecting lots -> of
# Page 3: Connecting of -> lots
# Page 3: Connecting of -> work
# Page 3: Connecting work -> of
# Page 3: Connecting work -> ahead
# Page 3: Connecting ahead -> work
# Page 3: Connecting ahead -> of
# Page 3: Connecting of -> ahead
# Page 3: Connecting of -> us
# Page 3: Connecting us -> of
# Page 3: Connecting us -> in
# Page 3: Connecting in -> us
# Page 3: Connecting in -> the
# Page 3: Connecting the -> in
# Page 3: Connecting the -> area
# Page 3: Connecting area -> the
# Page 3: Connecting area -> of
# Page 3: Connecting of -> area
# Page 3: Connecting of -> diversity,
# Page 3: Connecting diversity, -> of
# Page 3: Connecting diversity, -> equity,
# Page 3: Connecting equity, -> diversity,
# Page 3: Connecting equity, -> and
# Page 3: Connecting and -> equity,
# Page 3: Connecting and -> inclusion
# Page 3: Connecting inclusion -> and
# Page 3: Connecting inclusion -> (DEI).
# Page 3: Connecting (DEI). -> inclusion
# Page 3: Connecting (DEI). -> While
# Page 3: Connecting While -> (DEI).
# Page 3: Connecting we've -> always
# Page 3: Connecting always -> we've
# Page 3: Connecting always -> believed
# Page 3: Connecting believed -> always
# Page 3: Connecting believed -> in
# Page 3: Connecting in -> believed
# Page 3: Connecting in -> the
# Page 3: Connecting the -> in
# Page 3: Connecting the -> importance
# Page 3: Connecting importance -> the
# Page 3: Connecting importance -> of
# Page 3: Connecting of -> importance
# Page 3: Connecting of -> the
# Page 3: Connecting the -> of
# Page 3: Connecting the -> work,
# Page 3: Connecting work, -> the
# Page 3: Connecting work, -> this
# Page 3: Connecting this -> work,
# Page 3: Connecting this -> year
# Page 3: Connecting year -> this
# Page 3: Connecting year -> we
# Page 3: Connecting we -> year
# Page 3: Connecting we -> learned
# Page 3: Connecting learned -> we
# Page 3: Connecting learned -> that
# Page 3: Connecting that -> learned
# Page 3: Connecting that -> we
# Page 3: Connecting we -> that
# Page 3: Connecting we -> had
# Page 3: Connecting had -> we
# Page 3: Connecting a -> long
# Page 3: Connecting long -> a
# Page 3: Connecting long -> way
# Page 3: Connecting way -> long
# Page 3: Connecting way -> to
# Page 3: Connecting to -> way
# Page 3: Connecting to -> go
# Page 3: Connecting go -> to
# Page 3: Connecting go -> to
# Page 3: Connecting to -> go
# Page 3: Connecting to -> make
# Page 3: Connecting make -> to
# Page 3: Connecting make -> our
# Page 3: Connecting our -> make
# Page 3: Connecting our -> actions
# Page 3: Connecting actions -> our
# Page 3: Connecting actions -> live
# Page 3: Connecting live -> actions
# Page 3: Connecting live -> up
# Page 3: Connecting up -> live
# Page 3: Connecting up -> to
# Page 3: Connecting to -> up
# Page 3: Connecting to -> our
# Page 3: Connecting our -> to
# Page 3: Connecting our -> words.
# Page 3: Connecting words. -> our
# Page 3: Connecting words. -> So,
# Page 3: Connecting So, -> words.
# Page 3: Connecting So, -> we
# Page 3: Connecting we -> So,
# Page 3: Connecting we -> approached
# Page 3: Connecting approached -> we
# Page 3: Connecting approached -> FY21as
# Page 3: Connecting FY21as -> approached
# Page 3: Connecting FY21as -> a
# Page 3: Connecting a -> FY21as
# Page 3: Connecting “rebuilding -> year.”
# Page 3: Connecting year.” -> “rebuilding
# Page 3: Connecting year.” -> We
# Page 3: Connecting We -> year.”
# Page 3: Connecting We -> slowed
# Page 3: Connecting slowed -> We
# Page 3: Connecting slowed -> down
# Page 3: Connecting down -> slowed
# Page 3: Connecting down -> some
# Page 3: Connecting some -> down
# Page 3: Connecting some -> of
# Page 3: Connecting of -> some
# Page 3: Connecting of -> our
# Page 3: Connecting our -> of
# Page 3: Connecting our -> outward-facing
# Page 3: Connecting outward-facing -> our
# Page 3: Connecting outward-facing -> work
# Page 3: Connecting work -> outward-facing
# Page 3: Connecting work -> so
# Page 3: Connecting so -> work
# Page 3: Connecting so -> we
# Page 3: Connecting we -> so
# Page 3: Connecting we -> could
# Page 3: Connecting could -> we
# Page 3: Connecting could -> invest
# Page 3: Connecting invest -> could
# Page 3: Connecting in -> research,
# Page 3: Connecting research, -> in
# Page 3: Connecting research, -> planning,
# Page 3: Connecting planning, -> research,
# Page 3: Connecting planning, -> and
# Page 3: Connecting and -> planning,
# Page 3: Connecting and -> staffing
# Page 3: Connecting staffing -> and
# Page 3: Connecting staffing -> that
# Page 3: Connecting that -> staffing
# Page 3: Connecting that -> will
# Page 3: Connecting will -> that
# Page 3: Connecting will -> set
# Page 3: Connecting set -> will
# Page 3: Connecting set -> us
# Page 3: Connecting us -> set
# Page 3: Connecting us -> up
# Page 3: Connecting up -> us
# Page 3: Connecting up -> to
# Page 3: Connecting to -> up
# Page 3: Connecting to -> move
# Page 3: Connecting move -> to
# Page 3: Connecting move -> faster
# Page 3: Connecting faster -> move
# Page 3: Connecting faster -> toward
# Page 3: Connecting toward -> faster
# Page 3: Connecting toward -> our
# Page 3: Connecting our -> toward
# Page 3: Connecting our -> DEI
# Page 3: Connecting DEI -> our
# Page 3: Connecting DEI -> goals
# Page 3: Connecting goals -> DEI
# Page 3: Connecting and -> the
# Page 3: Connecting the -> and
# Page 3: Connecting the -> kind
# Page 3: Connecting kind -> the
# Page 3: Connecting kind -> of
# Page 3: Connecting of -> kind
# Page 3: Connecting of -> company
# Page 3: Connecting company -> of
# Page 3: Connecting company -> we
# Page 3: Connecting we -> company
# Page 3: Connecting we -> want
# Page 3: Connecting want -> we
# Page 3: Connecting want -> to
# Page 3: Connecting to -> want
# Page 3: Connecting to -> be
# Page 3: Connecting be -> to
# Page 3: Connecting be -> in
# Page 3: Connecting in -> be
# Page 3: Connecting in -> FY22
# Page 3: Connecting FY22 -> in
# Page 3: Connecting FY22 -> and
# Page 3: Connecting and -> FY22
# Page 3: Connecting and -> beyond.
# Page 3: Connecting beyond. -> and
# Page 3: Connecting Scott -> and
# Page 3: Connecting and -> Scott
# Page 3: Connecting and -> |
# Page 3: Connecting and -> are
# Page 3: Connecting | -> and
# Page 3: Connecting | -> are
# Page 3: Connecting are -> and
# Page 3: Connecting are -> |
# Page 3: Connecting are -> incredibly
# Page 3: Connecting incredibly -> are
# Page 3: Connecting incredibly -> proud
# Page 3: Connecting proud -> incredibly
# Page 3: Connecting proud -> of
# Page 3: Connecting of -> proud
# Page 3: Connecting of -> everything
# Page 3: Connecting everything -> of
# Page 3: Connecting everything -> Atlassian
# Page 3: Connecting Atlassian -> everything
# Page 3: Connecting Atlassian -> has
# Page 3: Connecting has -> Atlassian
# Page 3: Connecting has -> accomplished
# Page 3: Connecting accomplished -> has
# Page 3: Connecting accomplished -> so
# Page 3: Connecting so -> accomplished
# Page 3: Connecting so -> far,
# Page 3: Connecting far, -> so
# Page 3: Connecting far, -> and
# Page 3: Connecting and -> far,
# Page 3: Connecting and -> we’re
# Page 3: Connecting we’re -> and
# Page 3: Connecting keen -> to
# Page 3: Connecting to -> keen
# Page 3: Connecting to -> rollup
# Page 3: Connecting rollup -> to
# Page 3: Connecting rollup -> our
# Page 3: Connecting our -> rollup
# Page 3: Connecting our -> sleeves
# Page 3: Connecting sleeves -> our
# Page 3: Connecting sleeves -> and
# Page 3: Connecting and -> sleeves
# Page 3: Connecting and -> keep
# Page 3: Connecting keep -> and
# Page 3: Connecting keep -> at
# Page 3: Connecting at -> keep
# Page 3: Connecting at -> it
# Page 3: Connecting it -> at
# Page 3: Connecting it -> in
# Page 3: Connecting in -> it
# Page 3: Connecting in -> the
# Page 3: Connecting the -> in
# Page 3: Connecting the -> coming
# Page 3: Connecting coming -> the
# Page 3: Connecting coming -> years.
# Page 3: Connecting years. -> coming
# Page 3: Connecting years. -> Together
# Page 3: Connecting Together -> years.
# Page 3: Connecting Together -> with
# Page 3: Connecting with -> Together
# Page 3: Connecting with -> our
# Page 3: Connecting our -> with
# Page 3: Connecting our -> amazing
# Page 3: Connecting amazing -> our
# Page 3: Connecting team -> of
# Page 3: Connecting of -> team
# Page 3: Connecting of -> Atlassians,
# Page 3: Connecting Atlassians, -> of
# Page 3: Connecting Atlassians, -> plus
# Page 3: Connecting plus -> Atlassians,
# Page 3: Connecting plus -> external
# Page 3: Connecting external -> plus
# Page 3: Connecting external -> partners,
# Page 3: Connecting partners, -> external
# Page 3: Connecting partners, -> we
# Page 3: Connecting we -> partners,
# Page 3: Connecting we -> can
# Page 3: Connecting can -> we
# Page 3: Connecting can -> (sustainably)
# Page 3: Connecting (sustainably) -> can
# Page 3: Connecting (sustainably) -> unleash
# Page 3: Connecting unleash -> (sustainably)
# Page 3: Connecting unleash -> the
# Page 3: Connecting the -> unleash
# Page 3: Connecting the -> potential
# Page 3: Connecting potential -> the
# Page 3: Connecting potential -> in
# Page 3: Connecting in -> potential
# Page 3: Connecting every -> team.
# Page 3: Connecting team. -> every
# Page 3: Connecting Mike -> Cannon-Brookes
# Page 3: Connecting Cannon-Brookes -> Mike
# Page 3: Connecting Co-Founder -> and
# Page 3: Connecting and -> Co-Founder
# Page 3: Connecting and -> Co-CEO
# Page 3: Connecting Co-CEO -> and
# Page 3: Connecting Sydney, -> Australia,
# Page 3: Connecting Australia, -> Sydney,
# Page 3: Connecting Australia, -> October
# Page 3: Connecting October -> Australia,
# Page 3: Connecting October -> 2021
# Page 3: Connecting 2021 -> October
# Merging It’s at 954, 265
# Merging Doing at 958, 446
# Merging exclusive. at 956, 508
# Merging We at 955, 634
# Merging Atlassian at 955, 694
# Merging to at 955, 761
# Merging climate at 956, 819
# Merging Now at 958, 946
# Merging Return at 958, 1009
# Merging employees at 956, 1069
# Merging (the at 958, 1132
# Merging jobs at 954, 1194
# Merging But at 958, 1321
# Merging and at 956, 1382
# Merging sustainable at 956, 1444
# Merging When at 955, 1570
# Merging reached at 957, 1632
# Merging rights at 957, 1694
# Merging organizations. at 956, 1759
# Merging climate at 956, 1819
# Merging increase at 957, 1884
# Merging That’s at 955, 2007
# Merging have at 957, 2069
# Merging we've at 955, 2134
# Merging a at 956, 2202
# Merging “rebuilding at 956, 2257
# Merging in at 957, 2321
# Merging and at 956, 2382
# Merging Scott at 956, 2509
# Merging keen at 957, 2569
# Merging team at 955, 2636
# Merging every at 956, 2702
# Merging SX at 958, 2811
# Merging CWS at 1163, 2815
# Merging Mike at 964, 2980
# Merging Co-Founder at 962, 3041
# Merging Sydney, at 961, 3134
#
# --- Processing Page 4 ---
#
# --- Processing Page 5 ---
#
# --- Processing Page 6 ---
# Avg Width: 40.5625, Avg Height: 27.8515625
# Horizontal Threshold: 40, Vertical Threshold: 27
# Page 6: Connecting Summary -> of
# Page 6: Connecting of -> Summary
# Page 6: Connecting of -> fiscal
# Page 6: Connecting fiscal -> of
# Page 6: Connecting fiscal -> year
# Page 6: Connecting year -> fiscal
# Page 6: Connecting year -> 2021
# Page 6: Connecting 2021 -> year
# Page 6: Connecting Where -> we
# Page 6: Connecting we -> Where
# Page 6: Connecting we -> fell
# Page 6: Connecting fell -> we
# Page 6: Connecting fell -> short
# Page 6: Connecting short -> fell
# Page 6: Connecting We -> set
# Page 6: Connecting set -> We
# Page 6: Connecting set -> value
# Page 6: Connecting value -> set
# Page 6: Connecting value -> chain
# Page 6: Connecting chain -> value
# Page 6: Connecting chain -> (scope
# Page 6: Connecting (scope -> chain
# Page 6: Connecting (scope -> 3)
# Page 6: Connecting 3) -> (scope
# Page 6: Connecting 3) -> reduction
# Page 6: Connecting reduction -> 3)
# Page 6: Connecting reduction -> targets
# Page 6: Connecting targets -> reduction
# Page 6: Connecting that -> included
# Page 6: Connecting included -> that
# Page 6: Connecting included -> business
# Page 6: Connecting business -> included
# Page 6: Connecting business -> travel
# Page 6: Connecting travel -> business
# Page 6: Connecting travel -> because
# Page 6: Connecting because -> travel
# Page 6: Connecting because -> it’s
# Page 6: Connecting it’s -> because
# Page 6: Connecting it’s -> our
# Page 6: Connecting our -> it’s
# Page 6: Connecting second-largest -> emissions
# Page 6: Connecting emissions -> second-largest
# Page 6: Connecting emissions -> area.
# Page 6: Connecting area. -> emissions
# Page 6: Connecting area. -> With
# Page 6: Connecting With -> area.
# Page 6: Connecting With -> the
# Page 6: Connecting the -> With
# Page 6: Connecting the -> pan-
# Page 6: Connecting pan- -> the
# Page 6: Connecting demic-induced -> pause
# Page 6: Connecting pause -> demic-induced
# Page 6: Connecting pause -> on
# Page 6: Connecting on -> pause
# Page 6: Connecting on -> travel,
# Page 6: Connecting travel, -> on
# Page 6: Connecting travel, -> there
# Page 6: Connecting there -> travel,
# Page 6: Connecting there -> was
# Page 6: Connecting was -> there
# Page 6: Connecting was -> too
# Page 6: Connecting too -> was
# Page 6: Connecting much -> ambiguity
# Page 6: Connecting ambiguity -> much
# Page 6: Connecting ambiguity -> to
# Page 6: Connecting to -> ambiguity
# Page 6: Connecting to -> land
# Page 6: Connecting land -> to
# Page 6: Connecting land -> a
# Page 6: Connecting a -> land
# Page 6: Connecting a -> reduction
# Page 6: Connecting reduction -> a
# Page 6: Connecting reduction -> strategy.
# Page 6: Connecting strategy. -> reduction
# Page 6: Connecting This -> means
# Page 6: Connecting means -> This
# Page 6: Connecting means -> we'll
# Page 6: Connecting we'll -> means
# Page 6: Connecting we'll -> start
# Page 6: Connecting start -> we'll
# Page 6: Connecting start -> fiscal
# Page 6: Connecting fiscal -> start
# Page 6: Connecting fiscal -> year
# Page 6: Connecting year -> fiscal
# Page 6: Connecting year -> 2022
# Page 6: Connecting 2022 -> year
# Page 6: Connecting 2022 -> with
# Page 6: Connecting with -> 2022
# Page 6: Connecting that -> as
# Page 6: Connecting as -> that
# Page 6: Connecting as -> a
# Page 6: Connecting a -> as
# Page 6: Connecting a -> priority.
# Page 6: Connecting priority. -> a
# Page 6: Connecting When -> we
# Page 6: Connecting we -> When
# Page 6: Connecting we -> look
# Page 6: Connecting look -> we
# Page 6: Connecting look -> at
# Page 6: Connecting at -> look
# Page 6: Connecting at -> how
# Page 6: Connecting how -> at
# Page 6: Connecting how -> we’ve
# Page 6: Connecting we’ve -> how
# Page 6: Connecting we’ve -> resourced
# Page 6: Connecting resourced -> we’ve
# Page 6: Connecting resourced -> DEI
# Page 6: Connecting DEI -> resourced
# Page 6: Connecting at -> Atlassian,
# Page 6: Connecting Atlassian, -> at
# Page 6: Connecting Atlassian, -> it’s
# Page 6: Connecting it’s -> Atlassian,
# Page 6: Connecting it’s -> clear
# Page 6: Connecting clear -> it’s
# Page 6: Connecting clear -> we’ve
# Page 6: Connecting we’ve -> clear
# Page 6: Connecting we’ve -> historically
# Page 6: Connecting historically -> we’ve
# Page 6: Connecting underinvested, -> in
# Page 6: Connecting in -> underinvested,
# Page 6: Connecting in -> spite
# Page 6: Connecting spite -> in
# Page 6: Connecting spite -> of
# Page 6: Connecting of -> spite
# Page 6: Connecting of -> publicly
# Page 6: Connecting publicly -> of
# Page 6: Connecting publicly -> proclaiming
# Page 6: Connecting proclaiming -> publicly
# Page 6: Connecting our -> commitment
# Page 6: Connecting commitment -> our
# Page 6: Connecting commitment -> to
# Page 6: Connecting to -> commitment
# Page 6: Connecting to -> the
# Page 6: Connecting the -> to
# Page 6: Connecting the -> work.
# Page 6: Connecting work. -> the
# Page 6: Connecting work. -> This
# Page 6: Connecting This -> work.
# Page 6: Connecting This -> means
# Page 6: Connecting means -> This
# Page 6: Connecting means -> we
# Page 6: Connecting we -> means
# Page 6: Connecting were -> starting
# Page 6: Connecting starting -> were
# Page 6: Connecting starting -> from
# Page 6: Connecting from -> starting
# Page 6: Connecting from -> the
# Page 6: Connecting the -> from
# Page 6: Connecting the -> ground
# Page 6: Connecting ground -> the
# Page 6: Connecting ground -> up,
# Page 6: Connecting up, -> ground
# Page 6: Connecting up, -> including
# Page 6: Connecting including -> up,
# Page 6: Connecting building -> the
# Page 6: Connecting the -> building
# Page 6: Connecting the -> basics
# Page 6: Connecting basics -> the
# Page 6: Connecting basics -> of
# Page 6: Connecting of -> basics
# Page 6: Connecting of -> our
# Page 6: Connecting our -> of
# Page 6: Connecting our -> data
# Page 6: Connecting data -> our
# Page 6: Connecting data -> capabilities
# Page 6: Connecting capabilities -> data
# Page 6: Connecting and -> how
# Page 6: Connecting how -> and
# Page 6: Connecting how -> to
# Page 6: Connecting to -> how
# Page 6: Connecting to -> enable
# Page 6: Connecting enable -> to
# Page 6: Connecting enable -> HR
# Page 6: Connecting HR -> enable
# Page 6: Connecting HR -> and
# Page 6: Connecting and -> HR
# Page 6: Connecting and -> business
# Page 6: Connecting business -> and
# Page 6: Connecting business -> leaders.
# Page 6: Connecting leaders. -> business
# Page 6: Connecting In -> our
# Page 6: Connecting our -> In
# Page 6: Connecting our -> last
# Page 6: Connecting last -> our
# Page 6: Connecting last -> report,
# Page 6: Connecting report, -> last
# Page 6: Connecting report, -> we
# Page 6: Connecting we -> report,
# Page 6: Connecting we -> noted
# Page 6: Connecting noted -> we
# Page 6: Connecting noted -> that
# Page 6: Connecting that -> noted
# Page 6: Connecting that -> key
# Page 6: Connecting key -> that
# Page 6: Connecting performance -> indicators
# Page 6: Connecting indicators -> performance
# Page 6: Connecting indicators -> for
# Page 6: Connecting for -> indicators
# Page 6: Connecting for -> this
# Page 6: Connecting this -> for
# Page 6: Connecting this -> pillar
# Page 6: Connecting pillar -> this
# Page 6: Connecting pillar -> were
# Page 6: Connecting were -> pillar
# Page 6: Connecting still -> pending.
# Page 6: Connecting pending. -> still
# Page 6: Connecting pending. -> We
# Page 6: Connecting We -> pending.
# Page 6: Connecting We -> still
# Page 6: Connecting still -> We
# Page 6: Connecting still -> have
# Page 6: Connecting have -> still
# Page 6: Connecting have -> not
# Page 6: Connecting not -> have
# Page 6: Connecting not -> found
# Page 6: Connecting found -> not
# Page 6: Connecting found -> a
# Page 6: Connecting a -> found
# Page 6: Connecting a -> data-
# Page 6: Connecting data- -> a
# Page 6: Connecting driven -> way
# Page 6: Connecting way -> driven
# Page 6: Connecting way -> to
# Page 6: Connecting to -> way
# Page 6: Connecting to -> demonstrate
# Page 6: Connecting demonstrate -> to
# Page 6: Connecting demonstrate -> real
# Page 6: Connecting real -> demonstrate
# Page 6: Connecting real -> impact,
# Page 6: Connecting impact, -> real
# Page 6: Connecting though -> we
# Page 6: Connecting we -> though
# Page 6: Connecting we -> have
# Page 6: Connecting have -> we
# Page 6: Connecting have -> landed
# Page 6: Connecting landed -> have
# Page 6: Connecting landed -> a
# Page 6: Connecting a -> landed
# Page 6: Connecting a -> key
# Page 6: Connecting key -> a
# Page 6: Connecting key -> performance
# Page 6: Connecting performance -> key
# Page 6: Connecting narrative -> that
# Page 6: Connecting that -> narrative
# Page 6: Connecting that -> demonstrates
# Page 6: Connecting demonstrates -> that
# Page 6: Connecting demonstrates -> our
# Page 6: Connecting our -> demonstrates
# Page 6: Connecting our -> progress.
# Page 6: Connecting progress. -> our
# Page 6: Connecting We'll -> continue
# Page 6: Connecting continue -> We'll
# Page 6: Connecting continue -> to
# Page 6: Connecting to -> continue
# Page 6: Connecting to -> seek
# Page 6: Connecting seek -> to
# Page 6: Connecting seek -> out
# Page 6: Connecting out -> seek
# Page 6: Connecting out -> ways
# Page 6: Connecting ways -> out
# Page 6: Connecting ways -> to
# Page 6: Connecting to -> ways
# Page 6: Connecting to -> disclose
# Page 6: Connecting disclose -> to
# Page 6: Connecting meaningful, -> measurable
# Page 6: Connecting measurable -> meaningful,
# Page 6: Connecting measurable -> progress
# Page 6: Connecting progress -> measurable
# Page 6: Connecting progress -> on
# Page 6: Connecting on -> progress
# Page 6: Connecting on -> human
# Page 6: Connecting human -> on
# Page 6: Connecting rights -> and
# Page 6: Connecting and -> rights
# Page 6: Connecting and -> ethics
# Page 6: Connecting ethics -> and
# Page 6: Connecting ethics -> in
# Page 6: Connecting in -> ethics
# Page 6: Connecting in -> the
# Page 6: Connecting the -> in
# Page 6: Connecting the -> future.
# Page 6: Connecting future. -> the
# Page 6: Connecting This -> year
# Page 6: Connecting year -> This
# Page 6: Connecting year -> the
# Page 6: Connecting the -> year
# Page 6: Connecting the -> Atlassian
# Page 6: Connecting Atlassian -> the
# Page 6: Connecting Atlassian -> Foundation
# Page 6: Connecting Foundation -> Atlassian
# Page 6: Connecting Foundation -> was
# Page 6: Connecting was -> Foundation
# Page 6: Connecting was -> faced
# Page 6: Connecting faced -> was
# Page 6: Connecting with -> many
# Page 6: Connecting many -> with
# Page 6: Connecting many -> opportunities
# Page 6: Connecting opportunities -> many
# Page 6: Connecting opportunities -> to
# Page 6: Connecting to -> opportunities
# Page 6: Connecting to -> fund
# Page 6: Connecting fund -> to
# Page 6: Connecting fund -> programs
# Page 6: Connecting programs -> fund
# Page 6: Connecting in -> aid
# Page 6: Connecting aid -> in
# Page 6: Connecting aid -> of
# Page 6: Connecting of -> aid
# Page 6: Connecting of -> natural
# Page 6: Connecting natural -> of
# Page 6: Connecting natural -> disasters,
# Page 6: Connecting disasters, -> natural
# Page 6: Connecting disasters, -> the
# Page 6: Connecting the -> disasters,
# Page 6: Connecting the -> global
# Page 6: Connecting global -> the
# Page 6: Connecting global -> health
# Page 6: Connecting health -> global
# Page 6: Connecting pandemic -> (COVID-19),
# Page 6: Connecting (COVID-19), -> pandemic
# Page 6: Connecting (COVID-19), -> and
# Page 6: Connecting and -> (COVID-19),
# Page 6: Connecting and -> societal
# Page 6: Connecting societal -> and
# Page 6: Connecting societal -> injustices
# Page 6: Connecting injustices -> societal
# Page 6: Connecting (Stop -> AAPI
# Page 6: Connecting AAPI -> (Stop
# Page 6: Connecting AAPI -> Hate).
# Page 6: Connecting Hate). -> AAPI
# Page 6: Connecting Hate). -> In
# Page 6: Connecting In -> Hate).
# Page 6: Connecting In -> response
# Page 6: Connecting response -> In
# Page 6: Connecting response -> to
# Page 6: Connecting to -> response
# Page 6: Connecting to -> all
# Page 6: Connecting all -> to
# Page 6: Connecting all -> of
# Page 6: Connecting of -> all
# Page 6: Connecting of -> these,
# Page 6: Connecting these, -> of
# Page 6: Connecting the -> Atlassian
# Page 6: Connecting Atlassian -> the
# Page 6: Connecting Atlassian -> Foundation
# Page 6: Connecting Foundation -> Atlassian
# Page 6: Connecting Foundation -> lacked
# Page 6: Connecting lacked -> Foundation
# Page 6: Connecting lacked -> a
# Page 6: Connecting a -> lacked
# Page 6: Connecting a -> standardized
# Page 6: Connecting standardized -> a
# Page 6: Connecting framework -> in
# Page 6: Connecting in -> framework
# Page 6: Connecting in -> how
# Page 6: Connecting how -> in
# Page 6: Connecting how -> emergency
# Page 6: Connecting emergency -> how
# Page 6: Connecting emergency -> response
# Page 6: Connecting response -> emergency
# Page 6: Connecting response -> funds
# Page 6: Connecting funds -> response
# Page 6: Connecting are -> allocated
# Page 6: Connecting allocated -> are
# Page 6: Connecting allocated -> and
# Page 6: Connecting and -> allocated
# Page 6: Connecting and -> distributed.
# Page 6: Connecting distributed. -> and
# Page 6: Connecting distributed. -> However,
# Page 6: Connecting However, -> distributed.
# Page 6: Connecting However, -> the
# Page 6: Connecting the -> However,
# Page 6: Connecting Atlassian -> Foundation
# Page 6: Connecting Foundation -> Atlassian
# Page 6: Connecting Foundation -> has
# Page 6: Connecting has -> Foundation
# Page 6: Connecting has -> demonstrated
# Page 6: Connecting demonstrated -> has
# Page 6: Connecting demonstrated -> agility,
# Page 6: Connecting agility, -> demonstrated
# Page 6: Connecting resilience, -> and
# Page 6: Connecting and -> resilience,
# Page 6: Connecting and -> creativity
# Page 6: Connecting creativity -> and
# Page 6: Connecting creativity -> in
# Page 6: Connecting in -> creativity
# Page 6: Connecting in -> putting
# Page 6: Connecting putting -> in
# Page 6: Connecting putting -> the
# Page 6: Connecting the -> putting
# Page 6: Connecting the -> causes
# Page 6: Connecting causes -> the
# Page 6: Connecting that -> Atlassians
# Page 6: Connecting Atlassians -> that
# Page 6: Connecting Atlassians -> care
# Page 6: Connecting care -> Atlassians
# Page 6: Connecting care -> most
# Page 6: Connecting most -> care
# Page 6: Connecting most -> about
# Page 6: Connecting about -> most
# Page 6: Connecting about -> at
# Page 6: Connecting at -> about
# Page 6: Connecting at -> the
# Page 6: Connecting the -> at
# Page 6: Connecting the -> heart
# Page 6: Connecting heart -> the
# Page 6: Connecting of -> our
# Page 6: Connecting our -> of
# Page 6: Connecting our -> funding
# Page 6: Connecting funding -> our
# Page 6: Connecting funding -> and
# Page 6: Connecting and -> funding
# Page 6: Connecting and -> work,
# Page 6: Connecting work, -> and
# Page 6: Connecting work, -> and
# Page 6: Connecting and -> work,
# Page 6: Connecting and -> is
# Page 6: Connecting is -> and
# Page 6: Connecting is -> well-advanced
# Page 6: Connecting well-advanced -> is
# Page 6: Connecting in -> developing
# Page 6: Connecting developing -> in
# Page 6: Connecting developing -> such
# Page 6: Connecting such -> developing
# Page 6: Connecting such -> a
# Page 6: Connecting a -> such
# Page 6: Connecting a -> framework.
# Page 6: Connecting framework. -> a
# Merging Summary at 284, 290
# Merging Where at 281, 629
# Merging PLANET at 292, 814
# Merging We at 289, 901
# Merging that at 290, 970
# Merging second-largest at 292, 1041
# Merging demic-induced at 292, 1112
# Merging much at 293, 1182
# Merging This at 290, 1253
# Merging that at 290, 1324
# Merging PEOPLE at 292, 1472
# Merging When at 289, 1557
# Merging at at 292, 1633
# Merging underinvested, at 292, 1699
# Merging our at 292, 1779
# Merging were at 290, 1850
# Merging building at 293, 1912
# Merging and at 292, 1982
# Merging CUSTOMERS at 290, 2130
# Merging In at 293, 2218
# Merging performance at 293, 2287
# Merging still at 292, 2357
# Merging driven at 292, 2428
# Merging though at 290, 2499
# Merging narrative at 293, 2572
# Merging We'll at 289, 2641
# Merging meaningful, at 293, 2712
# Merging rights at 293, 2782
# Merging COMMUNITY at 1318, 813
# Merging This at 1318, 898
# Merging with at 1318, 969
# Merging in at 1320, 1042
# Merging pandemic at 1321, 1111
# Merging (Stop at 1320, 1181
# Merging the at 1318, 1253
# Merging framework at 1318, 1323
# Merging are at 1320, 1403
# Merging Atlassian at 1317, 1465
# Merging resilience, at 1321, 1536
# Merging that at 1318, 1607
# Merging of at 1320, 1678
# Merging in at 1320, 1750
#
# --- Processing Page 7 ---
#
# --- Processing Page 8 ---
# Avg Width: 40.97849462365591, Avg Height: 28.485333333333333
# Horizontal Threshold: 40, Vertical Threshold: 28
# Page 8: Connecting This -> report
# Page 8: Connecting report -> This
# Page 8: Connecting For -> Atlassian’s
# Page 8: Connecting Atlassian’s -> For
# Page 8: Connecting Atlassian’s -> third
# Page 8: Connecting third -> Atlassian’s
# Page 8: Connecting third -> sustainability
# Page 8: Connecting sustainability -> third
# Page 8: Connecting sustainability -> report,
# Page 8: Connecting report, -> sustainability
# Page 8: Connecting report, -> we’ve
# Page 8: Connecting we’ve -> report,
# Page 8: Connecting we’ve -> expanded
# Page 8: Connecting expanded -> we’ve
# Page 8: Connecting expanded -> and
# Page 8: Connecting and -> expanded
# Page 8: Connecting and -> improved
# Page 8: Connecting improved -> and
# Page 8: Connecting our -> disclosures,
# Page 8: Connecting disclosures, -> our
# Page 8: Connecting disclosures, -> but
# Page 8: Connecting but -> disclosures,
# Page 8: Connecting but -> our
# Page 8: Connecting our -> but
# Page 8: Connecting our -> guiding
# Page 8: Connecting guiding -> our
# Page 8: Connecting guiding -> principles
# Page 8: Connecting principles -> guiding
# Page 8: Connecting principles -> remain:
# Page 8: Connecting remain: -> principles
# Page 8: Connecting remain: -> progress
# Page 8: Connecting progress -> remain:
# Page 8: Connecting progress -> over
# Page 8: Connecting over -> progress
# Page 8: Connecting over -> perfection
# Page 8: Connecting perfection -> over
# Page 8: Connecting and -> an
# Page 8: Connecting an -> and
# Page 8: Connecting an -> iterative
# Page 8: Connecting iterative -> an
# Page 8: Connecting iterative -> approach
# Page 8: Connecting approach -> iterative
# Page 8: Connecting approach -> informed
# Page 8: Connecting informed -> approach
# Page 8: Connecting informed -> by
# Page 8: Connecting by -> informed
# Page 8: Connecting by -> feedback
# Page 8: Connecting feedback -> by
# Page 8: Connecting feedback -> from
# Page 8: Connecting from -> feedback
# Page 8: Connecting from -> stakeholders.
# Page 8: Connecting stakeholders. -> from
# Page 8: Connecting Our -> fiscal
# Page 8: Connecting fiscal -> Our
# Page 8: Connecting fiscal -> year
# Page 8: Connecting year -> fiscal
# Page 8: Connecting year -> 2021
# Page 8: Connecting 2021 -> year
# Page 8: Connecting 2021 -> report,
# Page 8: Connecting report, -> 2021
# Page 8: Connecting report, -> covering
# Page 8: Connecting covering -> report,
# Page 8: Connecting covering -> July
# Page 8: Connecting July -> covering
# Page 8: Connecting July -> 1,
# Page 8: Connecting 1, -> July
# Page 8: Connecting 1, -> 2020,
# Page 8: Connecting 2020, -> 1,
# Page 8: Connecting 2020, -> to
# Page 8: Connecting to -> 2020,
# Page 8: Connecting to -> June
# Page 8: Connecting June -> to
# Page 8: Connecting June -> 30,
# Page 8: Connecting 30, -> June
# Page 8: Connecting 30, -> 2021,
# Page 8: Connecting 2021, -> 30,
# ...
# Merging Our at 289, 1364
# Merging the at 288, 1429
# Merging open at 289, 1505
# Merging based at 290, 1562
# Merging Fiscal at 291, 1685
# Merging processes at 290, 1761
# Merging Note at 291, 1877
# Merging historically at 290, 1942
# Merging nuanced, at 290, 2008
# Merging of at 289, 2075
# Merging Indigenous at 291, 2142
# Merging sourcing at 290, 2210
# Merging We at 287, 2277
# Merging * at 288, 2406
# Merging ¢ at 325, 2487
# Merging Fiscal at 385, 2475
# Merging ¢ at 288, 2568
# Merging ¢ at 325, 2650
# Merging US-based at 385, 2638
# Merging * at 382, 2731
# Merging Fiscal at 436, 2715
# Merging ¢ at 325, 2812
# Merging US-based at 385, 2800
# Merging * at 382, 2893
# Merging Fiscal at 436, 2877
# Merging XII at 2318, 3124
#
# --- Processing Page 55 ---
#
# --- Processing Page 56 ---
#
# --- Processing Page 57 ---
# Avg Width: 36.81132075471698, Avg Height: 28.845794392523363
# Horizontal Threshold: 36, Vertical Threshold: 28
# Page 57: Connecting Bug -> bounty
# Page 57: Connecting bounty -> Bug
# Page 57: Connecting bounty -> program
# Page 57: Connecting program -> bounty
# Page 57: Connecting We -> continued
# Page 57: Connecting continued -> We
# Page 57: Connecting continued -> our
# Page 57: Connecting our -> continued
# Page 57: Connecting our -> Bug
# Page 57: Connecting Bug -> our
# Page 57: Connecting Bug -> Bounty
# Page 57: Connecting Bounty -> Bug
# Page 57: Connecting Bounty -> program
# Page 57: Connecting program -> Bounty
# Page 57: Connecting program -> for
# Page 57: Connecting for -> program
# Page 57: Connecting for -> our
# Page 57: Connecting our -> for
# Page 57: Connecting our -> cloud
# Page 57: Connecting cloud -> our
# Page 57: Connecting cloud -> products,
# Page 57: Connecting products, -> cloud
# Page 57: Connecting products, -> server
# Page 57: Connecting server -> products,
# Page 57: Connecting server -> products,
# Page 57: Connecting products, -> server
# Page 57: Connecting products, -> and
# Page 57: Connecting and -> products,
# Page 57: Connecting and -> Atlassian
# Page 57: Connecting Atlassian -> and
# Page 57: Connecting mobile -> applications.
# Page 57: Connecting applications. -> mobile
# Page 57: Connecting ¢ -> Through
# Page 57: Connecting Through -> ¢
# Page 57: Connecting Through -> this
# Page 57: Connecting Through -> USD$302,000
# Page 57: Connecting this -> Through
# Page 57: Connecting this -> program,
# Page 57: Connecting program, -> this
# Page 57: Connecting program, -> we
# Page 57: Connecting program, -> USD$302,000
# Page 57: Connecting program, -> for
# Page 57: Connecting program, -> 521
# Page 57: Connecting program, -> product
# Page 57: Connecting we -> program,
# Page 57: Connecting we -> awarded
# Page 57: Connecting awarded -> we
# Page 57: Connecting awarded -> USDS$421,400
# Page 57: Connecting USDS$421,400 -> awarded
# Page 57: Connecting USDS$421,400 -> for
# Page 57: Connecting USDS$421,400 -> vulnerabilities
# Page 57: Connecting USDS$421,400 -> fiscal
# Page 57: Connecting for -> USDS$421,400
# Page 57: Connecting for -> 549
# Page 57: Connecting 549 -> for
# Page 57: Connecting 549 -> product
# Page 57: Connecting product -> 549
# Page 57: Connecting product -> vulnerabilities
# Page 57: Connecting product -> 2020).
# Page 57: Connecting vulnerabilities -> product
# Page 57: Connecting vulnerabilities -> reported
# Page 57: Connecting reported -> vulnerabilities
# Page 57: Connecting reported -> (vs.
# Page 57: Connecting (vs. -> reported
# Page 57: Connecting USD$302,000 -> Through
# Page 57: Connecting USD$302,000 -> program,
# Page 57: Connecting USD$302,000 -> for
# Page 57: Connecting for -> program,
# Page 57: Connecting for -> USD$302,000
# Page 57: Connecting for -> 521
# Page 57: Connecting 521 -> program,
# Page 57: Connecting 521 -> for
# Page 57: Connecting 521 -> product
# Page 57: Connecting product -> program,
# Page 57: Connecting product -> 521
# Page 57: Connecting product -> vulnerabilities
# Page 57: Connecting vulnerabilities -> USDS$421,400
# Page 57: Connecting vulnerabilities -> product
# Page 57: Connecting vulnerabilities -> in
# Page 57: Connecting in -> vulnerabilities
# Page 57: Connecting in -> fiscal
# Page 57: Connecting fiscal -> USDS$421,400
# Page 57: Connecting fiscal -> in
# Page 57: Connecting fiscal -> year
# Page 57: Connecting year -> fiscal
# Page 57: Connecting year -> 2020).
# Page 57: Connecting 2020). -> product
# Page 57: Connecting 2020). -> year
# Page 57: Connecting * -> Critical
# Page 57: Connecting Critical -> *
# Page 57: Connecting Critical -> severity
# Page 57: Connecting severity -> Critical
# Page 57: Connecting severity -> bugs
# Page 57: Connecting bugs -> severity
# Page 57: Connecting bugs -> represented
# Page 57: Connecting represented -> bugs
# Page 57: Connecting represented -> 2%
# Page 57: Connecting 2% -> represented
# Page 57: Connecting 2% -> of
# Page 57: Connecting of -> 2%
# Page 57: Connecting of -> all
# Page 57: Connecting all -> of
# Page 57: Connecting all -> validated
# Page 57: Connecting validated -> all
# Page 57: Connecting validated -> bugs
# Page 57: Connecting bugs -> validated
# Page 57: Connecting bugs -> (vs.
# Page 57: Connecting (vs. -> bugs
# Page 57: Connecting (vs. -> 5.47%
# Page 57: Connecting 5.47% -> (vs.
# Page 57: Connecting 5.47% -> in
# Page 57: Connecting in -> 5.47%
# Page 57: Connecting in -> fiscal
# Page 57: Connecting fiscal -> in
# Page 57: Connecting fiscal -> year
# Page 57: Connecting year -> fiscal
# Page 57: Connecting year -> 2020).
# Page 57: Connecting 2020). -> year
# Page 57: Connecting * -> The
# Page 57: Connecting The -> *
# Page 57: Connecting The -> top
# Page 57: Connecting top -> The
# Page 57: Connecting top -> three
# Page 57: Connecting top -> Broken
# Page 57: Connecting top -> Authentication
# Page 57: Connecting three -> top
# Page 57: Connecting three -> categories
# Page 57: Connecting categories -> three
# Page 57: Connecting categories -> of
# Page 57: Connecting categories -> Authentication
# Page 57: Connecting categories -> and
# Page 57: Connecting of -> categories
# Page 57: Connecting of -> bugs
# Page 57: Connecting bugs -> of
# Page 57: Connecting bugs -> were
# Page 57: Connecting bugs -> and
# Page 57: Connecting bugs -> Session
# Page 57: Connecting were -> bugs
# Page 57: Connecting were -> Broken
# Page 57: Connecting Broken -> were
# Page 57: Connecting Broken -> Access
# Page 57: Connecting Access -> Broken
# Page 57: Connecting Access -> Control
# Page 57: Connecting Control -> Access
# Page 57: Connecting Control -> (BAC),
# Page 57: Connecting (BAC), -> Control
# Page 57: Connecting (BAC), -> Cross-Site
# Page 57: Connecting Cross-Site -> (BAC),
# Page 57: Connecting Cross-Site -> Scripting
# Page 57: Connecting Scripting -> Cross-Site
# Page 57: Connecting Scripting -> (XSS),
# Page 57: Connecting (XSS), -> Scripting
# Page 57: Connecting (XSS), -> and
# Page 57: Connecting and -> (XSS),
# Page 57: Connecting Broken -> top
# Page 57: Connecting Broken -> Authentication
# Page 57: Connecting Authentication -> top
# Page 57: Connecting Authentication -> categories
# Page 57: Connecting Authentication -> Broken
# Page 57: Connecting Authentication -> and
# Page 57: Connecting and -> categories
# Page 57: Connecting and -> bugs
# Page 57: Connecting and -> Authentication
# Page 57: Connecting and -> Session
# Page 57: Connecting Session -> bugs
# Page 57: Connecting Session -> and
# Page 57: Connecting Session -> Management.
# Page 57: Connecting Management. -> Session
# Page 57: Connecting We -> also
# Page 57: Connecting also -> We
# Page 57: Connecting also -> continued
# Page 57: Connecting continued -> also
# Page 57: Connecting continued -> our
# Page 57: Connecting our -> continued
# Page 57: Connecting our -> Ecosystem
# Page 57: Connecting Ecosystem -> our
# Page 57: Connecting Ecosystem -> bug
# Page 57: Connecting bug -> Ecosystem
# Page 57: Connecting bug -> bounty
# Page 57: Connecting bounty -> bug
# Page 57: Connecting bounty -> program,
# Page 57: Connecting program, -> bounty
# Page 57: Connecting program, -> helping
# Page 57: Connecting helping -> program,
# Page 57: Connecting helping -> over
# Page 57: Connecting over -> helping
# Page 57: Connecting over -> 960
# Page 57: Connecting 960 -> over
# Page 57: Connecting 960 -> Marketplace
# Page 57: Connecting Marketplace -> 960
# Page 57: Connecting Marketplace -> apps
# Page 57: Connecting apps -> Marketplace
# Page 57: Connecting improve -> their
# Page 57: Connecting their -> improve
# Page 57: Connecting their -> security.
# Page 57: Connecting security. -> their
# Page 57: Connecting * -> The
# Page 57: Connecting The -> *
# Page 57: Connecting The -> program
# Page 57: Connecting program -> The
# Page 57: Connecting program -> awarded
# Page 57: Connecting program -> for
# Page 57: Connecting awarded -> program
# Page 57: Connecting awarded -> USD$525,655
# Page 57: Connecting USD$525,655 -> awarded
# Page 57: Connecting USD$525,655 -> for
# Page 57: Connecting for -> USD$525,655
# Page 57: Connecting for -> 1144
# Page 57: Connecting 1144 -> for
# Page 57: Connecting 1144 -> ecosystem
# Page 57: Connecting ecosystem -> 1144
# Page 57: Connecting ecosystem -> vulnerabilities
# Page 57: Connecting ecosystem -> 2020).
# Page 57: Connecting vulnerabilities -> ecosystem
# Page 57: Connecting vulnerabilities -> reported
# Page 57: Connecting reported -> vulnerabilities
# Page 57: Connecting reported -> (vs.
# Page 57: Connecting (vs. -> reported
# Page 57: Connecting (vs. -> USD$602,377
# Page 57: Connecting USD$602,377 -> (vs.
# Page 57: Connecting for -> program
# Page 57: Connecting for -> 830
# Page 57: Connecting 830 -> for
# Page 57: Connecting 830 -> ecosystem
# Page 57: Connecting ecosystem -> 830
# Page 57: Connecting ecosystem -> vulnerabilities
# Page 57: Connecting vulnerabilities -> ecosystem
# Page 57: Connecting vulnerabilities -> in
# Page 57: Connecting in -> vulnerabilities
# Page 57: Connecting in -> fiscal
# Page 57: Connecting fiscal -> in
# Page 57: Connecting fiscal -> year
# Page 57: Connecting year -> fiscal
# Page 57: Connecting year -> 2020).
# Page 57: Connecting 2020). -> ecosystem
# Page 57: Connecting 2020). -> year
# Page 57: Connecting * -> Critical
# Page 57: Connecting Critical -> *
# Page 57: Connecting Critical -> bugs
# Page 57: Connecting bugs -> Critical
# Page 57: Connecting bugs -> were
# Page 57: Connecting were -> bugs
# Page 57: Connecting were -> 8.13%
# Page 57: Connecting 8.13% -> were
# Page 57: Connecting 8.13% -> of
# Page 57: Connecting of -> 8.13%
# Page 57: Connecting of -> the
# Page 57: Connecting the -> of
# Page 57: Connecting the -> total
# Page 57: Connecting total -> the
# Page 57: Connecting total -> number
# Page 57: Connecting number -> total
# Page 57: Connecting number -> of
# Page 57: Connecting of -> number
# Page 57: Connecting of -> bugs
# Page 57: Connecting bugs -> of
# Page 57: Connecting bugs -> reported
# Page 57: Connecting reported -> bugs
# Page 57: Connecting reported -> (vs.
# Page 57: Connecting (vs. -> reported
# Page 57: Connecting (vs. -> 13.3%
# Page 57: Connecting 13.3% -> (vs.
# Page 57: Connecting 13.3% -> in
# Page 57: Connecting in -> 13.3%
# Page 57: Connecting in -> fiscal
# Page 57: Connecting fiscal -> in
# Page 57: Connecting fiscal -> year
# Page 57: Connecting year -> fiscal
# Page 57: Connecting year -> 2020).
# Page 57: Connecting 2020). -> year
# Page 57: Connecting * -> The
# Page 57: Connecting The -> *
# Page 57: Connecting The -> top
# Page 57: Connecting top -> The
# Page 57: Connecting top -> three
# Page 57: Connecting three -> top
# Page 57: Connecting three -> categories
# Page 57: Connecting categories -> three
# Page 57: Connecting categories -> of
# Page 57: Connecting categories -> and
# Page 57: Connecting of -> categories
# Page 57: Connecting of -> bugs
# Page 57: Connecting bugs -> of
# Page 57: Connecting bugs -> were
# Page 57: Connecting bugs -> and
# Page 57: Connecting were -> bugs
# Page 57: Connecting were -> Broken
# Page 57: Connecting Broken -> were
# Page 57: Connecting Broken -> Access
# Page 57: Connecting Access -> Broken
# Page 57: Connecting Access -> Control
# Page 57: Connecting Control -> Access
# Page 57: Connecting Control -> (BAC),
# Page 57: Connecting (BAC), -> Control
# Page 57: Connecting (BAC), -> Broken
# Page 57: Connecting Broken -> (BAC),
# Page 57: Connecting Broken -> Authentication
# Page 57: Connecting Authentication -> Broken
# Page 57: Connecting Authentication -> and
# Page 57: Connecting and -> Authentication
# Page 57: Connecting Session -> Management,
# Page 57: Connecting Management, -> Session
# Page 57: Connecting Management, -> and
# Page 57: Connecting and -> categories
# Page 57: Connecting and -> bugs
# Page 57: Connecting and -> Management,
# Page 57: Connecting and -> Cross-Site
# Page 57: Connecting Cross-Site -> and
# Page 57: Connecting Cross-Site -> Scripting
# Page 57: Connecting Scripting -> Cross-Site
# Page 57: Connecting Scripting -> (XSS).
# Page 57: Connecting (XSS). -> Scripting
# Page 57: Connecting Time -> to
# Page 57: Connecting to -> Time
# Page 57: Connecting to -> resolve
# Page 57: Connecting resolve -> to
# Page 57: Connecting resolve -> bug
# Page 57: Connecting bug -> resolve
# Page 57: Connecting bug -> fixes
# Page 57: Connecting fixes -> bug
# Page 57: Connecting Remediation -> times
# Page 57: Connecting times -> Remediation
# Page 57: Connecting times -> were
# Page 57: Connecting were -> times
# Page 57: Connecting were -> maintained
# Page 57: Connecting maintained -> were
# Page 57: Connecting maintained -> for
# Page 57: Connecting for -> maintained
# Page 57: Connecting for -> accelerated
# Page 57: Connecting accelerated -> for
# Page 57: Connecting accelerated -> security
# Page 57: Connecting security -> accelerated
# Page 57: Connecting security -> bug
# Page 57: Connecting bug -> security
# Page 57: Connecting bug -> fixes
# Page 57: Connecting fixes -> bug
# Page 57: Connecting fixes -> (for
# Page 57: Connecting (for -> fixes
# Page 57: Connecting (for -> cloud-based
# Page 57: Connecting cloud-based -> (for
# Page 57: Connecting cloud-based -> and
# Page 57: Connecting and -> cloud-based
# Page 57: Connecting Atlassian -> infrastructure),
# Page 57: Connecting infrastructure), -> Atlassian
# Page 57: Connecting infrastructure), -> per
# Page 57: Connecting per -> infrastructure),
# Page 57: Connecting per -> our
# Page 57: Connecting our -> per
# Page 57: Connecting our -> Security
# Page 57: Connecting Security -> our
# Page 57: Connecting Security -> Bug-Fix
# Page 57: Connecting Bug-Fix -> Security
# Page 57: Connecting Bug-Fix -> Policy.
# Page 57: Connecting Policy. -> Bug-Fix
# Page 57: Connecting No -> previous
# Page 57: Connecting previous -> No
# Page 57: Connecting previous -> remediation
# Page 57: Connecting remediation -> previous
# Page 57: Connecting remediation -> time
# Page 57: Connecting time -> remediation
# Page 57: Connecting 25 -> weeks
# Page 57: Connecting weeks -> 25
# Page 57: Connecting 25 -> weeks
# Page 57: Connecting weeks -> 25
# Page 57: Connecting 8 -> weeks
# Page 57: Connecting weeks -> 8
# Page 57: Connecting 6 -> weeks
# Page 57: Connecting weeks -> 6
# Page 57: Connecting 6 -> weeks
# Page 57: Connecting weeks -> 6
# Page 57: Connecting 6 -> weeks
# Page 57: Connecting weeks -> 6
# Page 57: Connecting 4 -> weeks
# Page 57: Connecting weeks -> 4
# Page 57: Connecting 4 -> weeks
# Page 57: Connecting weeks -> 4
# Page 57: Connecting 4 -> weeks
# Page 57: Connecting weeks -> 4
# Page 57: Connecting 2 -> weeks
# Page 57: Connecting weeks -> 2
# Page 57: Connecting 2 -> weeks
# Page 57: Connecting weeks -> 2
# Merging Appendix at 281, 281
# Merging | at 666, 281
# Merging Customers at 714, 284
# Merging Bug at 285, 502
# Merging We at 281, 590
# Merging mobile at 284, 655
# Merging ¢ at 282, 786
# Merging * at 282, 930
# Merging * at 282, 1011
# Merging We at 281, 1149
# Merging improve at 284, 1216
# Merging * at 282, 1344
# Merging * at 282, 1488
# Merging * at 282, 1569
# Merging Time at 282, 1767
# Merging Remediation at 285, 1855
# Merging Atlassian at 281, 1922
# Merging LEVEL at 245, 2279
# Merging FY19 at 910, 2284
# Merging FY20 at 1543, 2284
# Merging FY21 at 2186, 2284
# Merging Low at 246, 2481
# Merging No at 694, 2481
# Merging 25 at 1511, 2481
# Merging 25 at 2148, 2481
# Merging Medium at 246, 2577
# Merging 8 at 884, 2583
# Merging 6 at 1522, 2583
# Merging 6 at 2160, 2583
# Merging High at 246, 2678
# Merging 6 at 885, 2684
# Merging 4 at 1520, 2684
# Merging 4 at 2158, 2684
# Merging Critical at 233, 2780
# Merging 4 at 883, 2786
# Merging 2 at 1522, 2786
# Merging 2 at 2159, 2786
#
# --- Processing Page 58 ---
#
# --- Processing Page 59 ---
#
# --- Processing Page 60 ---
#
# --- Processing Page 61 ---
